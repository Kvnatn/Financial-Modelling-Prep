# %% [markdown]
# # FMP Stock Fundamentals Exploration 6 : Stock Fundamental Analysis

# %% [markdown]
# Welcome to this Jupyter Notebook of the Finsloth.
#
# Our goal is to understand **the meaning and the structure of each data given by FMP, how to transform it for actual use in any trading or investing strategies**.

# %% [markdown]
# ## About Financial Modeling Prep
#
# Financial Modeling Prep is a stock market API that provides a wide range of data. Data covers stocks, crypto forex and commodities.
#
# You have addition data such as institutional stock ownership, esg score, price target, etc.
#
# There are several plans including a free one.
#
# I am on a start plan for this notebook. Here are the link for the pricing: https://site.financialmodelingprep.com/developer/docs/pricing/

# %% [markdown]
# ## Stock Fundamental Analysis
#
# A lot of topics found on the web about quantitative finance (or mostly about predicting stocks) uses Technical Analysis. In fact, technical analysis does help understanding the market. But alone, it doesn't help investors build a strong financial strategy.
#
# That is why fundamental analysis is important. Understanding key business metrics can help understand stock price movements, and therefore elaborate a more advanced investement strategy.
#
# Within this notebook, we will explore several categories of stock fundamentals:
# - Financial ratios,
# - Stock Financial ratios,
# - Entreprise Value,
# - Financial Statements Growth,
# - Key Metrics,
# - Financial Growth,
# - Rating,
# - DCF.

# %% [markdown]
# ## Initial Import and API Key

# %% [markdown]
# In this section, we are going to perform classic libraries import to perform our data transformation and visualisation.

# %%
# We import the basics and some specific to APIs libraries

# Basic Data Manipulation Librairies
import pandas as pd
import numpy as np

# requests is another way of sending an API request to FMP
import requests

# json library makes it easier to access JSON format
import json

# %% [markdown]
# For privacy reason, I have hidden my key to access the API.
#
# Here is the link to the dashboard where you can find your private key in case you created an account: https://site.financialmodelingprep.com/developer/docs/dashboard

# %%
# Because I want to share this file on Github, I made sure that it's not showing the actual key.
key='your_key'

# %% [markdown]
# ## Financial Ratios
#
# Financial Ratios are metrics built through different numbers taken from the several existing financial statements.
#
# - Ratio analysis compares line-item data from a company's financial statements to reveal insights regarding profitability, liquidity, operational efficiency, and solvency.
# - Ratio analysis can mark how a company is performing over time, while comparing a company to another within the same industry or sector.
# - Ratio analysis may also be required by external parties that set benchmarks often tied to risk.
# - While ratios offer useful insight into a company, they should be paired with other metrics, to obtain a broader picture of a company's financial health.
# - Examples of ratio analysis include current ratio, gross profit margin ratio, inventory turnover ratio.
#
# source: https://www.investopedia.com/terms/r/ratioanalysis.asp#toc-what-is-ratio-analysis

# %% [markdown]
# ### Trailing Twelve Months Ratio vs Fiscal year
#
# Trailing 12 months (TTM) is a term used to describe the past 12 consecutive months of a company’s performance data, that’s used for reporting financial figures. The 12 months studied do not necessarily coincide with a fiscal-year ending period.
#
# TTM figures are produced for a variety of metrics including earnings, EPS, P/E, and yield.
#
# It can be useful to compare the last 12 months performance to last fiscal-year performance to see how good a company is performing.
#
# Therefore, in this section, we will compute both **Trailing Twelve Months (TTM)** and **Fiscal Year (FY) ratio** and do a little comparison.
#
# We will choose **Microsoft** as our main company (ticker: MSFT)

# %%
# TTM ratio url
url1 = 'https://financialmodelingprep.com/api/v3/ratios-ttm/MSFT?apikey='+key

# Calling our URL
ttm = requests.get(url1).json()

# Inspecting
print(ttm)

# Counting the number of key, values pair
print(len(ttm[0]))
# Out:
# [{'dividendYielTTM': 0.010221745940153326, 'dividendYielPercentageTTM': 1.0221745940153326, 'peRatioTTM': 25.14197, 'pegRatioTTM': 1.2921063063291138, 'payoutRatioTTM': 0.2548258131925541, 'currentRatioTTM': 1.7846069708251824, 'quickRatioTTM': 1.5671735975263457, 'cashRatioTTM': 0.14651563913253823, 'daysOfSalesOutstandingTTM': 81.48113683361075, 'daysOfInventoryOutstandingTTM': 21.80095770151636, 'operatingCycleTTM': 41.89219692076284, 'daysOfPayablesOutstandingTTM': 110.69433359936153, 'cashConversionCycleTTM': -23.83761815441798, 'grossProfitMarginTTM': 0.684016744842891, 'operatingProfitMarginTTM': 0.4205527815604983, 'pretaxProfitMarginTTM': 0.4222323094769758, 'netProfitMarginTTM': 0.3668633681343622, 'effectiveTaxRateTTM': 0.13113383343685794, 'returnOnAssetsTTM': 0.19936958666812848, 'returnOnEquityTTM': 0.4535820183520564, 'returnOnCapitalEmployedTTM': 0.309102973776496, 'netIncomePerEBTTTM': 0.8688661665631421, 'ebtPerEbitTTM': 1.0039936198025976, 'ebitPerRevenueTTM': 0.4205527815604983, 'debtRatioTTM': 0.5435204473193729, 'debtEquityRatioTTM': 1.1906786276134549, 'longTermDebtToCapitalizationTTM': 0.26002052758560934, 'totalDebtToCapitalizationTTM': 0.2689498358295437, 'interestCoverageTTM': 40.41832283082889, 'cashFlowToDebtRatioTTM': 1.4531581524400197, 'companyEquityMultiplierTTM': 2.1906786276134547, 'receivablesTurnoverTTM': 4.479564402069542, 'payablesTurnoverTTM': 3.2973684210526315, 'inventoryTurnoverTTM': 16.742383752004276, 'fixedAssetTurnoverTTM': 2.264752244534302, 'assetTurnoverTTM': 0.5434437013485364, 'operatingCashFlowPerShareTTM': 11.912630452234412, 'freeCashFlowPerShareTTM': 8.716751404870216, 'cashPerShareTTM': 14.015119079475514, 'operatingCashFlowSalesRatioTTM': 0.44905936349422504, 'freeCashFlowOperatingCashFlowRatioTTM': 0.7317234795305217, 'cashFlowCoverageRatiosTTM': 1.4531581524400197, 'shortTermCoverageRatiosTTM': 32.388141142233536, 'capitalExpenditureCoverageRatioTTM': 3.727497278740685, 'dividendPaidAndCapexCoverageRatioTTM': 3.727497278353672, 'priceBookValueRatioTTM': 10.88819565034646, 'priceToBookRatioTTM': 10.88819565034646, 'priceToSalesRatioTTM': 9.145820749483027, 'priceEarningsRatioTTM': 24.929773708378015, 'priceToFreeCashFlowsRatioTTM': 27.83376383367358, 'priceToOperatingCashFlowsRatioTTM': 20.366618520806426, 'priceCashFlowRatioTTM': 20.366618520806426, 'priceEarningsToGrowthRatioTTM': 1.2921063063291138, 'priceSalesRatioTTM': 9.145820749483027, 'dividendYieldTTM': 0.010221745940153326, 'enterpriseValueMultipleTTM': 18.562444557507558, 'priceFairValueTTM': 10.88819565034646, 'dividendPerShareTTM': 2.48}]
# 58

# %% [markdown]
# There are 58 ratios in the JSON taht covers all aspect of business. Let's compute the fiscal year ratio.

# %%
# Fiscal Year Financial Ratios
url2 = 'https://financialmodelingprep.com/api/v3/ratios/MSFT?limit=40&apikey='+key

# Calling our URL
fy = requests.get(url2).json()

# Inspecting
print(fy)

# Counthing the number of key, value pairs
print(len(fy[0]))
# Out:
# [{'symbol': 'MSFT', 'date': '2022-06-30', 'period': 'FY', 'currentRatio': 1.7846069708251824, 'quickRatio': 1.5671735975263457, 'cashRatio': 0.14651563913253823, 'daysOfSalesOutstanding': 81.48113683361075, 'daysOfInventoryOutstanding': 21.80095770151636, 'operatingCycle': 103.2820945351271, 'daysOfPayablesOutstanding': 110.69433359936153, 'cashConversionCycle': -7.412239064234427, 'grossProfitMargin': 0.684016744842891, 'operatingProfitMargin': 0.4205527815604983, 'pretaxProfitMargin': 0.4222323094769758, 'netProfitMargin': 0.3668633681343622, 'effectiveTaxRate': 0.13113383343685794, 'returnOnAssets': 0.19936958666812848, 'returnOnEquity': 0.4367546925099975, 'returnOnCapitalEmployed': 0.309102973776496, 'netIncomePerEBT': 0.8688661665631421, 'ebtPerEbit': 1.0039936198025976, 'ebitPerRevenue': 0.4205527815604983, 'debtRatio': 0.5435204473193729, 'debtEquityRatio': 1.1906786276134549, 'longTermDebtToCapitalization': 0.26002052758560934, 'totalDebtToCapitalization': 0.2689498358295437, 'interestCoverage': 40.41832283082889, 'cashFlowToDebtRatio': 1.4531581524400197, 'companyEquityMultiplier': 2.1906786276134547, 'receivablesTurnover': 4.479564402069542, 'payablesTurnover': 3.2973684210526315, 'inventoryTurnover': 16.742383752004276, 'fixedAssetTurnover': 2.264752244534302, 'assetTurnover': 0.5434437013485364, 'operatingCashFlowPerShare': 11.877668089647813, 'freeCashFlowPerShare': 8.691168623265742, 'cashPerShare': 13.97398612593383, 'payoutRatio': 0.24931947537738183, 'operatingCashFlowSalesRatio': 0.44905936349422504, 'freeCashFlowOperatingCashFlowRatio': 0.7317234795305217, 'cashFlowCoverageRatios': 1.4531581524400197, 'shortTermCoverageRatios': 32.388141142233536, 'capitalExpenditureCoverageRatio': -3.727497278740685, 'dividendPaidAndCapexCoverageRatio': -15.481655364284473, 'dividendPayoutRatio': 0.24931947537738186, 'priceBookValueRatio': 12.636013537361146, 'priceToBookRatio': 12.636013537361146, 'priceToSalesRatio': 10.613945460933072, 'priceEarningsRatio': 28.931603378415687, 'priceToFreeCashFlowsRatio': 32.30175392621837, 'priceToOperatingCashFlowsRatio': 23.635951777831192, 'priceCashFlowRatio': 23.635951777831192, 'priceEarningsToGrowthRatio': 1.486864679954021, 'priceSalesRatio': 10.613945460933072, 'dividendYield': 0.00861754781151831, 'enterpriseValueMultiple': 21.46635507675855, 'priceFairValue': 12.636013537361146}, {'symbol': 'MSFT', 'date': '2021-06-30', 'period': 'FY', 'currentRatio': 2.0799936835218875, 'quickRatio': 1.8991957769832049, 'cashRatio': 0.1604385440517951, 'daysOfSalesOutstanding': 82.6096746942078, 'daysOfInventoryOutstanding': 18.420508500536073, 'operatingCycle': 101.03018319474387, 'daysOfPayablesOutstanding': 105.95985219788636, 'cashConversionCycle': -4.929669003142493, 'grossProfitMargin': 0.689258007710247, 'operatingProfitMargin': 0.415948788729713, 'pretaxProfitMargin': 0.4230046166293846, 'netProfitMargin': 0.36451739564989766, 'effectiveTaxRate': 0.13826615285083402, 'returnOnAssets': 0.18356757015869782, 'returnOnEquity': 0.4315223821731414, 'returnOnCapitalEmployed': 0.28522939597424957, 'netIncomePerEBT': 0.861733847149166, 'ebtPerEbit': 1.0169632129984554, 'ebitPerRevenue': 0.415948788729713, 'debtRatio': 0.5746047534446445, 'debtEquityRatio': 1.3507549933797223, 'longTermDebtToCapitalization': 0.2960122167077361, 'totalDebtToCapitalization': 0.32310273975868004, 'interestCoverage': 29.80221653878943, 'cashFlowToDebtRatio': 1.132275912947252, 'companyEquityMultiplier': 2.3507549933797223, 'receivablesTurnover': 4.418368688063507, 'payablesTurnover': 3.4447009167051377, 'inventoryTurnover': 19.814871016691956, 'fixedAssetTurnover': 2.374023699560753, 'assetTurnover': 0.5035906992351227, 'operatingCashFlowPerShare': 10.16827878627269, 'freeCashFlowPerShare': 7.435802305551875, 'cashPerShare': 17.269643566980257, 'payoutRatio': 0.269638164874084, 'operatingCashFlowSalesRatio': 0.4565465708438437, 'freeCashFlowOperatingCashFlowRatio': 0.7312744331508991, 'cashFlowCoverageRatios': 1. ...
# 57

# %% [markdown]
# There seem to be 57 data entry for each fiscal year, including "symbol", "date", and "period".
#
# This is a little bit problematic as this doesn't match our length of 58 given in the Trailing twelve months.
#
# We need to find a way to merge both tables with the right correspondance. Therefore we are going to do a little bit of data transformation.
#
# Here are the steps we are going to do to exploit data:
# - Transform each JSON into Dataframes,
# - Make sure to match indexes,
# - Join tables on index.

# %%
# Transforming ttm to DataFrame
ttmdf = pd.DataFrame(ttm)

# %%
# Inspecting
ttmdf
# Out:
#    dividendYielTTM  dividendYielPercentageTTM  peRatioTTM  pegRatioTTM  \
# 0         0.010222                   1.022175    25.14197     1.292106
#
#    payoutRatioTTM  currentRatioTTM  quickRatioTTM  cashRatioTTM  \
# 0        0.254826         1.784607       1.567174      0.146516
#
#    daysOfSalesOutstandingTTM  daysOfInventoryOutstandingTTM  ...  \
# 0                  81.481137                      21.800958  ...
#
#    priceEarningsRatioTTM  priceToFreeCashFlowsRatioTTM  \
# 0              24.929774                     27.833764
#
#    priceToOperatingCashFlowsRatioTTM  priceCashFlowRatioTTM  \
# 0                          20.366619              20.366619
#
#    priceEarningsToGrowthRatioTTM  priceSalesRatioTTM  dividendYieldTTM  \
# 0                       1.292106            9.145821          0.010222
#
#    enterpriseValueMultipleTTM  priceFairValueTTM  dividendPerShareTTM
# 0                   18.562445          10.888196                 2.48
#
# [1 rows x 58 columns]

# %% [markdown]
# Some modifications must be made as we can see in this dataframe:
# - we should remove the "TTM" at the end of each metrics title,
# - 0 should be changed with "TTM",
# - Matrix should be transposed.

# %%
# Building a list of all the new titles
new = []
for key in ttm[0].keys():
    new.append(key[:-3])

# Building a list of all old titles
old = []
for key in ttm[0].keys():
    old.append(key)
    
print(new)
print(old)
# Out:
# ['dividendYiel', 'dividendYielPercentage', 'peRatio', 'pegRatio', 'payoutRatio', 'currentRatio', 'quickRatio', 'cashRatio', 'daysOfSalesOutstanding', 'daysOfInventoryOutstanding', 'operatingCycle', 'daysOfPayablesOutstanding', 'cashConversionCycle', 'grossProfitMargin', 'operatingProfitMargin', 'pretaxProfitMargin', 'netProfitMargin', 'effectiveTaxRate', 'returnOnAssets', 'returnOnEquity', 'returnOnCapitalEmployed', 'netIncomePerEBT', 'ebtPerEbit', 'ebitPerRevenue', 'debtRatio', 'debtEquityRatio', 'longTermDebtToCapitalization', 'totalDebtToCapitalization', 'interestCoverage', 'cashFlowToDebtRatio', 'companyEquityMultiplier', 'receivablesTurnover', 'payablesTurnover', 'inventoryTurnover', 'fixedAssetTurnover', 'assetTurnover', 'operatingCashFlowPerShare', 'freeCashFlowPerShare', 'cashPerShare', 'operatingCashFlowSalesRatio', 'freeCashFlowOperatingCashFlowRatio', 'cashFlowCoverageRatios', 'shortTermCoverageRatios', 'capitalExpenditureCoverageRatio', 'dividendPaidAndCapexCoverageRatio', 'priceBookValueRatio', 'priceToBookRatio', 'priceToSalesRatio', 'priceEarningsRatio', 'priceToFreeCashFlowsRatio', 'priceToOperatingCashFlowsRatio', 'priceCashFlowRatio', 'priceEarningsToGrowthRatio', 'priceSalesRatio', 'dividendYield', 'enterpriseValueMultiple', 'priceFairValue', 'dividendPerShare']
# ['dividendYielTTM', 'dividendYielPercentageTTM', 'peRatioTTM', 'pegRatioTTM', 'payoutRatioTTM', 'currentRatioTTM', 'quickRatioTTM', 'cashRatioTTM', 'daysOfSalesOutstandingTTM', 'daysOfInventoryOutstandingTTM', 'operatingCycleTTM', 'daysOfPayablesOutstandingTTM', 'cashConversionCycleTTM', 'grossProfitMarginTTM', 'operatingProfitMarginTTM', 'pretaxProfitMarginTTM', 'netProfitMarginTTM', 'effectiveTaxRateTTM', 'returnOnAssetsTTM', 'returnOnEquityTTM', 'returnOnCapitalEmployedTTM', 'netIncomePerEBTTTM', 'ebtPerEbitTTM', 'ebitPerRevenueTTM', 'debtRatioTTM', 'debtEquityRatioTTM', 'longTermDebtToCapitalizationTTM', 'totalDebtToCapitalizationTTM', 'interestCoverageTTM', 'cashFlowToDebtRatioTTM', 'companyEquityMultiplierTTM', 'receivablesTurnoverTTM', 'payablesTurnoverTTM', 'inventoryTurnoverTTM', 'fixedAssetTurnoverTTM', 'assetTurnoverTTM', 'operatingCashFlowPerShareTTM', 'freeCashFlowPerShareTTM', 'cashPerShareTTM', 'operatingCashFlowSalesRatioTTM', 'freeCashFlowOperatingCashFlowRatioTTM', 'cashFlowCoverageRatiosTTM', 'shortTermCoverageRatiosTTM', 'capitalExpenditureCoverageRatioTTM', 'dividendPaidAndCapexCoverageRatioTTM', 'priceBookValueRatioTTM', 'priceToBookRatioTTM', 'priceToSalesRatioTTM', 'priceEarningsRatioTTM', 'priceToFreeCashFlowsRatioTTM', 'priceToOperatingCashFlowsRatioTTM', 'priceCashFlowRatioTTM', 'priceEarningsToGrowthRatioTTM', 'priceSalesRatioTTM', 'dividendYieldTTM', 'enterpriseValueMultipleTTM', 'priceFairValueTTM', 'dividendPerShareTTM']

# %%
# Building our mapping of new index
change = {old[i]:new[i] for i in range(len(new))}

# %%
# There are some mistakes that need to be taken care of
change['dividendYielTTM'] = 'dividendYield'
change['dividendYielPercentageTTM'] = 'dividendYieldPercentage'

# %%
# Affecting changes to the DataFrame
ttmdf.rename(columns=change, index={0:'ttm'}, inplace=True)

# %%
# Transposing the dataframe to join it with another table
ttmdft = ttmdf.transpose()

# %%
# Building a new 
ttmdft['merger'] = ttmdft.index

# %%
ttmdft.head()
# Out:
#                                ttm                   merger
# dividendYield             0.010222            dividendYield
# dividendYieldPercentage   1.022175  dividendYieldPercentage
# peRatio                  25.141970                  peRatio
# pegRatio                  1.292106                 pegRatio
# payoutRatio               0.254826              payoutRatio

# %%
# Building our DataFrame
fydf = pd.DataFrame(fy)

# %%
# Removing unnecessary columns
fydf.drop(columns=["symbol", "period"], inplace=True)

# %%
# Changing index
fydf.set_index("date", inplace=True)

# %%
# Transposing the dataframe
fydft = fydf.transpose()

# %%
# Adding the index in another column
fydft['mergel'] = fydft.index

# %%
# Inspecting
fydft.head()
# Out:
# date                        2022-06-30  2021-06-30  2020-06-30  2019-06-30  \
# currentRatio                  1.784607    2.079994    2.515765    2.528839
# quickRatio                    1.567174    1.899196    2.330770    2.352967
# cashRatio                     0.146516    0.160439    0.187747    0.163584
# daysOfSalesOutstanding       81.481137   82.609675   81.697829   85.632574
# daysOfInventoryOutstanding   21.800958   18.420509   15.010960   17.548241
#
# date                        2018-06-30  2017-06-30  2016-06-30  2015-06-30  \
# currentRatio                  2.900800    2.477273    2.352882    2.501344
# quickRatio                    2.739861    2.367583    2.215695    2.295198
# cashRatio                     0.204247    0.118756    0.109675    0.112219
# daysOfSalesOutstanding       87.582140   80.312173   78.189229   69.848472
# daysOfInventoryOutstanding   25.333872   23.235311   25.064521   32.060960
#
# date                        2014-06-30  2013-06-30  ...  1995-06-30  \
# currentRatio                  2.504022    2.711762  ...    4.172235
# quickRatio                    2.306915    2.525804  ...    1.887899
# cashRatio                     0.190005    0.101665  ...    1.456570
# daysOfSalesOutstanding       82.152638   81.984226  ...   35.719218
# daysOfInventoryOutstanding   36.047375   34.933577  ...   52.828947
#
# date                        1994-06-30  1993-06-30  1992-06-30  1991-06-30  \
# currentRatio                  4.722892    5.062167    3.959946    3.505453
# quickRatio                    2.138007    2.399645    3.614008    2.251193
# cashRatio                     1.617744    1.799290    1.770866    1.421950
# daysOfSalesOutstanding       37.292966   32.872369  108.982673   48.174297
# daysOfInventoryOutstanding   70.779468   96.172199   88.544197   59.942469
#
# date                        1990-06-30  1989-06-30  1988-06-30  1987-06-30  \
# currentRatio                  3.853854    2.952771    2.923729    4.346939
# quickRatio                    2.287473    1.911839    2.347458    3.816327
# cashRatio                     1.318522    1.211587    1.550847    2.693878
# daysOfSalesOutstanding       55.826432   50.514001   58.054146   58.020231
# daysOfInventoryOutstanding   98.323643   76.650000  133.175676   83.851351
#
# date                                            mergel
# currentRatio                              currentRatio
# quickRatio                                  quickRatio
# cashRatio                                    cashRatio
# daysOfSalesOutstanding          daysOfSalesOutstanding
# daysOfInventoryOutstanding  daysOfInventoryOutstanding
#
# [5 rows x 37 columns]

# %% [markdown]
# For the merging, we are doing something special: we are performing an inner joint on Indexes. Instead of using "how", the documentation indicates that "right_index" and "left_index" must be used.

# %%
# Merging both Dataframes
df = ttmdft.merge(fydft, right_index=True, left_index=True)

# %%
# Inspecting
df.head()
# Out:
#                                        ttm                           merger  \
# assetTurnover                     0.543444                    assetTurnover
# capitalExpenditureCoverageRatio   3.727497  capitalExpenditureCoverageRatio
# cashConversionCycle             -23.837618              cashConversionCycle
# cashFlowCoverageRatios            1.453158           cashFlowCoverageRatios
# cashFlowToDebtRatio               1.453158              cashFlowToDebtRatio
#
#                                  2022-06-30  2021-06-30  2020-06-30  \
# assetTurnover                      0.543444    0.503591    0.474642
# capitalExpenditureCoverageRatio   -3.727497   -3.721269   -3.929473
# cashConversionCycle               -7.412239   -4.929669   -2.545736
# cashFlowCoverageRatios             1.453158    1.132276    0.854602
# cashFlowToDebtRatio                1.453158    1.132276    0.854602
#
#                                  2019-06-30  2018-06-30  2017-06-30  \
# assetTurnover                      0.439157    0.426351    0.373103
# capitalExpenditureCoverageRatio   -3.747576   -3.772696   -4.860007
# cashConversionCycle               23.375874   30.909259   24.818026
# cashFlowCoverageRatios             0.665914    0.536427    0.458350
# cashFlowToDebtRatio                0.665914    0.536427    0.458350
#
#                                  2016-06-30  2015-06-30  ...  1995-06-30  \
# assetTurnover                      0.440489    0.531032  ...    0.823440
# capitalExpenditureCoverageRatio   -3.994367   -4.892328  ...   -4.020202
# cashConversionCycle               26.445635   29.092827  ... -249.437032
# cashFlowCoverageRatios             0.620728    0.823983  ...         NaN
# cashFlowToDebtRatio                0.620728    0.823983  ...         NaN
#
#                                  1994-06-30  1993-06-30  1992-06-30  \
# assetTurnover                      0.866866    0.986334    1.045002
# capitalExpenditureCoverageRatio   -5.730216   -4.550847   -2.864814
# cashConversionCycle             -116.756463  -51.940909    4.255195
# cashFlowCoverageRatios                  NaN         NaN         NaN
# cashFlowToDebtRatio                     NaN         NaN         NaN
#
#                                  1991-06-30  1990-06-30  1989-06-30  \
# assetTurnover                      1.121153    1.070660    1.115043
# capitalExpenditureCoverageRatio   -2.110061   -1.760278   -2.488814
# cashConversionCycle               -1.205061   63.961122   41.997335
# cashFlowCoverageRatios                  NaN         NaN         NaN
# cashFlowToDebtRatio                     NaN         NaN         NaN
#
#                                  1988-06-30  1987-06-30  \
# assetTurnover                      1.198783    1.201389
# capitalExpenditureCoverageRatio   -1.333333   -1.017241
# cashConversionCycle               85.182524   38.290501
# cashFlowCoverageRatios                  NaN         NaN
# cashFlowToDebtRatio                     NaN         NaN
#
#                                                           mergel
# assetTurnover                                      assetTurnover
# capitalExpenditureCoverageRatio  capitalExpenditureCoverageRatio
# cashConversionCycle                          cashConversionCycle
# cashFlowCoverageRatios                    cashFlowCoverageRatios
# cashFlowToDebtRatio                          cashFlowToDebtRatio
#
# [5 rows x 39 columns]

# %% [markdown]
# What is interesting here is that we can compare year on year the different metrics. Furthermore, we can compare the last fiscal year with the last twelve month performance.
#
# What we will do is building two columns that allow us show pourcentage progress on those metrics.

# %%
# Year on year YoY growth of each financial metrics
df["YoY"] = ((df["2022-06-30"]-df['2021-06-30'])/df["2021-06-30"])*100

# TTM to last fiscal results
df["ttm vs FY"] = ((df["ttm"] - df["2022-06-30"])/df["2022-06-30"])*100

# %%
# Building our dataframe
comparables = df[["ttm vs FY", "YoY","ttm","2022-06-30","2021-06-30"]]

# %%
# Inspecting
comparables
# Out:
#                                      ttm vs FY         YoY         ttm  \
# assetTurnover                         0.000000    7.913768    0.543444
# capitalExpenditureCoverageRatio    -200.000000    0.167382    3.727497
# cashConversionCycle                 221.598075   50.359772  -23.837618
# cashFlowCoverageRatios                0.000000   28.339580    1.453158
# cashFlowToDebtRatio                   0.000000   28.339580    1.453158
# cashPerShare                          0.294354  -19.083529   14.015119
# cashRatio                             0.000000   -8.678030    0.146516
# companyEquityMultiplier               0.000000   -6.809573    2.190679
# currentRatio                          0.000000  -14.201327    1.784607
# daysOfInventoryOutstanding            0.000000   18.351552   21.800958
# daysOfPayablesOutstanding             0.000000    4.468184  110.694334
# daysOfSalesOutstanding                0.000000   -1.366109   81.481137
# debtEquityRatio                       0.000000  -11.850881    1.190679
# debtRatio                             0.000000   -5.409685    0.543520
# dividendPaidAndCapexCoverageRatio  -124.076865  -17.265743    3.727497
# dividendYield                        18.615483   12.157784    0.010222
# dividendYield                        18.615483   12.157784    0.010222
# ebitPerRevenue                        0.000000    1.106865    0.420553
# ebtPerEbit                            0.000000   -1.275326    1.003994
# effectiveTaxRate                      0.000000   -5.158399    0.131134
# enterpriseValueMultiple             -13.527730  -18.342267   18.562445
# fixedAssetTurnover                    0.000000   -4.602795    2.264752
# freeCashFlowOperatingCashFlowRatio    0.000000    0.061406    0.731723
# freeCashFlowPerShare                  0.294354   16.882729    8.716751
# grossProfitMargin                     0.000000   -0.760421    0.684017
# interestCoverage                      0.000000   35.621868   40.418323
# inventoryTurnover                     0.000000  -15.505967   16.742384
# longTermDebtToCapitalization          0.000000  -12.158853    0.260021
# netIncomePerEBT                       0.000000    0.827671    0.868866
# netProfitMargin                       0.000000    0.643583    0.366863
# operatingCashFlowPerShare             0.294354   16.811000   11.912630
# operatingCashFlowSalesRatio           0.000000   -1.639966    0.449059
# operatingCycle                      -59.439052    2.228949   41.892197
# operatingProfitMargin                 0.000000    1.106865    0.420553
# payablesTurnover                      0.000000   -4.277077    3.297368
# payoutRatio                           2.208547   -7.535539    0.254826
# pretaxProfitMargin                    0.000000   -0.182577    0.422232
# priceBookValueRatio                 -13.832036  -16.558966   10.888196
# priceCashFlowRatio                  -13.832036  -15.644609   20.366619
# priceEarningsRatio                  -13.832036  -17.558588   24.929774
# priceEarningsToGrowthRatio          -13.098594   67.436145    1.292106
# priceFairValue                      -13.832036  -16.558966   10.888196
# priceSalesRatio                     -13.832036  -17.028009    9.145821
# priceToBookRatio                    -13.832036  -16.558966   10.888196
# priceToFreeCashFlowsRatio           -13.832036  -15.696377   27.833764
# priceToOperatingCashFlowsRatio      -13.832036  -15.644609   20.366619
# priceToSalesRatio                   -13.832036  -17.028009    9.145821
# quickRatio                            0.000000  -17.482251    1.567174
# receivablesTurnover                   0.000000    1.385030    4.479564
# returnOnAssets                        0.000000    8.608283    0.199370
# returnOnCapitalEmployed               0.000000    8.369957    0.309103
# returnOnEquity                        3.852809    1.212524    0.453582
# shortTermCoverageRatios               0.000000  240.679014   32.388141
# totalDebtToCapitalization             0.000000  -16.760274    0.268950
#
#                                     2022-06-30  2021-06-30
# assetTurnover                         0.543444    0.503591
# capitalExpenditureCoverageRatio      -3.727497   -3.721269
# cashConversionCycle                  -7.412239   -4.929669
# cashFlowCoverageRatios                1.453158    1.132276
# cashFlowToDebtRatio                   1.453158    1.132276
# cashPerShare                         13.973986   17.269644
# cashRatio                             0.146516    0.160439
# companyEquityMultiplier               2.190679    2.350755
# currentRatio                          1.784607    2.079994
# daysOfInventoryOutstanding           21.800958   18.420509
# daysOfPayablesOutstanding           110.694334  105.959852
# daysOfSalesOutstanding               81.481137   82.609675
# debtEquityRatio                       1.190679    1.350755
# debtRatio                             0.543520    0.574605
# dividendPaidAndCapexCoverageRatio   -15.481655  -18.712509
# dividendYield                         0.008618    0.007683
# dividendYield                         0.008618    0.007683
# ebitPerRevenue                        0.420553    0.415949
# ebtPerEbit                            1.003994    1.016963
# effectiveTaxRate                      0.131134    0.138266
# enterpriseValueMultiple              21.466355   26.288208
# fixedAssetTurnover                    2.264752    2.374024
# freeCashFlowOperatingCashFlowRatio    0.731723    0.731274
# freeCashFlowPerShare                  8.691169    7.435802
# grossProfitMargin                     0.684017    0.689258
# interestCoverage                     40.418323   29.802217
# inventoryTurnover                    16.742384   19.814871
# longTermDebtToCapitalization          0.260021    0.296012
# netIncomePerEBT                       0.868866    0.861734
# netProfitMargin                       0.366863    0.364517
# operatingCashFlowPerShare            11.877668   10.168279
# operatingCashFlowSalesRatio           0.449059    0.456547
# operatingCycle                      103.282095  101.030183
# operatingProfitMargin                 0.420553    0.415949
# payablesTurnover                      3.297368    3.444701
# payoutRatio                           0.249319    0.269638
# pretaxProfitMargin                    0.422232    0.423005
# priceBookValueRatio                  12.636014   15.143645
# priceCashFlowRatio                   23.635952   28.019492
# priceEarningsRatio                   28.931603   35.093532
# priceEarningsToGrowthRatio            1.486865    0.888019
# priceFairValue                       12.636014   15.143645
# priceSalesRatio                      10.613945   12.792203
# priceToBookRatio                     12.636014   15.143645
# priceToFreeCashFlowsRatio            32.301754   38.315973
# priceToOperatingCashFlowsRatio       23.635952   28.019492
# priceToSalesRatio                    10.613945   12.792203
# quickRatio                            1.567174    1.899196
# receivablesTurnover                   4.479564    4.418369
# returnOnAssets                        0.199370    0.183568
# returnOnCapitalEmployed               0.309103    0.285229
# returnOnEquity                        0.436755    0.431522
# shortTermCoverageRatios              32.388141    9.506938
# totalDebtToCapitalization             0.268950    0.323103

# %% [markdown]
# While these are surely interesting ratios, the point here is not to analyze each one of them, but rather to see what could be doable.
#
# Depending on businesses, industries and many other parameters, those metrics might have a significance and must be carefully observed.

# %% [markdown]
# ## Stock Financial Scores
#
# Stock financial scores helps the user assess whether it should be considered entering in a portfolio or not.
#
# This adds another layer of security whenever investing in a particular stock.
#
# Scores include:
# - Altman Z-score,
# - Piotroski Score,
# - Working Capital,
# - Ebit,
# - etc.
#
# As usual, we will build our url, and explore the call we have made. We will do this exercise for the company Tesla.

# %%
# Building our url
url3 = 'https://financialmodelingprep.com/api/v4/score?symbol=TSLA&apikey='+key

# Requesting our JSON
# sfc stands for stock financial scores
sfc = requests.get(url3).json()

# %%
# Inspecting
sfc
# Out:
# {'Error Message': 'Invalid API KEY. Please retry or visit our documentation to create one FREE https://financialmodelingprep.com/developer/docs'}

# %% [markdown]
# It's not really relevant here to build a DataFrame. Rather, it is interesting to check what this call is talking about.

# %% [markdown]
# ## Company Enterprise Value
#
# Company enterprise value helps user have a better understanding of how much is a company worth looking at many metrics including stock price, number of shares, market cap, etc.
#
# We'll use Hewlett Packard (HP) for this one as it has many years of data.

# %%
# Building our url
url4 = 'https://financialmodelingprep.com/api/v3/enterprise-values/HPQ?limit=100&apikey='+key

# Calling our JSON Api
# cev stands for company entreprise value
cev =  requests.get(url4).json()

# %%
# Inspecting
cev
# Out:
# [{'symbol': 'HPQ',
#   'date': '2021-10-31',
#   'stockPrice': 34.8008682645,
#   'numberOfShares': 1208000000,
#   'marketCapitalization': 42039448863.516,
#   'minusCashAndCashEquivalents': 4299000000,
#   'addTotalDebt': 8778000000,
#   'enterpriseValue': 46518448863.516},
#  {'symbol': 'HPQ',
#   'date': '2020-10-31',
#   'stockPrice': 21.0408442185,
#   'numberOfShares': 1413000000,
#   'marketCapitalization': 29730712880.740498,
#   'minusCashAndCashEquivalents': 4864000000,
#   'addTotalDebt': 6492000000,
#   'enterpriseValue': 31358712880.740498},
#  {'symbol': 'HPQ',
#   'date': '2019-10-31',
#   'stockPrice': 18.573738077,
#   'numberOfShares': 1515000000,
#   'marketCapitalization': 28139213186.655003,
#   'minusCashAndCashEquivalents': 4537000000,
#   'addTotalDebt': 5137000000,
#   'enterpriseValue': 28739213186.655003},
#  {'symbol': 'HPQ',
#   'date': '2018-10-31',
#   'stockPrice': 20.607082451,
#   'numberOfShares': 1615000000,
#   'marketCapitalization': 33280438158.365,
#   'minusCashAndCashEquivalents': 5166000000,
#   'addTotalDebt': 5987000000,
#   'enterpriseValue': 34101438158.365},
#  {'symbol': 'HPQ',
#   'date': '2017-10-31',
#   'stockPrice': 18.7624723218,
#   'numberOfShares': 1688000000,
#   'marketCapitalization': 31671053279.198402,
#   'minusCashAndCashEquivalents': 6997000000,
#   'addTotalDebt': 7819000000,
#   'enterpriseValue': 32493053279.198402},
#  {'symbol': 'HPQ',
#   'date': '2016-10-31',
#   'stockPrice': 13.0694751431,
#   'numberOfShares': 1730000000,
#   'marketCapitalization': 22610191997.563,
#   'minusCashAndCashEquivalents': 6288000000,
#   'addTotalDebt': 6836000000,
#   'enterpriseValue': 23158191997.563},
#  {'symbol': 'HPQ',
#   'date': '2015-10-31',
#   'stockPrice': 10.2347066533,
#   'numberOfShares': 1814000000,
#   'marketCapitalization': 18565757869.0862,
#   'minusCashAndCashEquivalents': 17433000000,
#   'addTotalDebt': 24665000000,
#   'enterpriseValue': 25797757869.0862},
#  {'symbol': 'HPQ',
#   'date': '2014-10-31',
#   'stockPrice': 15.1239306039,
#   'numberOfShares': 1882000000,
#   'marketCapitalization': 28463237396.5398,
#   'minusCashAndCashEquivalents': 15133000000,
#   'addTotalDebt': 19525000000,
#   'enterpriseValue': 32855237396.5398},
#  {'symbol': 'HPQ',
#   'date': '2013-10-31',
#   'stockPrice': 10.3887508675,
#   'numberOfShares': 1934000000,
#   'marketCapitalization': 20091844177.745003,
#   'minusCashAndCashEquivalents': 12163000000,
#   'addTotalDebt': 22587000000,
#   'enterpriseValue': 30515844177.745003},
#  {'symbol': 'HPQ',
#   'date': '2012-10-31',
#   'stockPrice': 4.7983240643,
#   'numberOfShares': 1974000000,
#   'marketCapitalization': 9471891702.9282,
#   'minusCashAndCashEquivalents': 11301000000,
#   'addTotalDebt': 28436000000,
#   'enterpriseValue': 26606891702.9282},
#  {'symbol': 'HPQ',
#   'date': '2011-10-31',
#   'stockPrice': 10.0890856156,
#   'numberOfShares': 2094000000,
#   'marketCapitalization': 21126545279.0664,
#   'minusCashAndCashEquivalents': 8043000000,
#   'addTotalDebt': 30634000000,
#   'enterpriseValue': 43717545279.0664},
#  {'symbol': 'HPQ',
#   'date': '2010-10-31',
#   'stockPrice': 14.9458809173,
#   'numberOfShares': 2319000000,
#   'marketCapitalization': 34659497847.218704,
#   'minusCashAndCashEquivalents': 10929000000,
#   'addTotalDebt': 22304000000,
#   'enterpriseValue': 46034497847.218704},
#  {'symbol': 'HPQ',
#   'date': '2009-10-31',
#   'stockPrice': 17.3671977948,
#   'numberOfShares': 2388000000,
#   'marketCapitalization': 41472868333.9824,
#   'minusCashAndCashEquivalents': 13279000000,
#   'addTotalDebt': 15830000000,
#   'enterpriseValue': 44023868333.9824},
#  {'symbol': 'HPQ',
#   'date': '2008-10-31',
#   'stockPrice': 12.3733711096,
#   'numberOfShares': 2483000000,
#   'marketCapitalization': 30723080465.136803,
#   'minusCashAndCashEquivalents': 10153000000,
#   'addTotalDebt': 17852000000,
#   'enterpriseValue': 38422080465.1368},
#  {'symbol': 'HPQ',
#   'date': '2007-10-31',
#   'stockPrice': 17.8234200978,
#   'numberOfShares': 2630000000,
#   'marketCapitalization': 46875594857.214,
#   'minusCashAndCashEquivalents': 11293000000,
#   'addTotalDebt': 8183000000,
#   'enterpriseValue': 43765594857.214},
#  {'symbol': 'HPQ',
#   'date': '2006-10-31',
#   'stockPrice': 13.646629071,
#   'numberOfShares': 2782000000,
#   'marketCapitalization': 37964922075.521996,
#   'minusCashAndCashEquivalents': 16400000000,
#   'addTotalDebt': 5195000000,
#   'enterpriseValue': 26759922075.521996},
#  {'symbol': 'HPQ',
#   'date': '2005-10-31',
#   'stockPrice': 10.1593849354,
#   'numberOfShares': 2879000000,
#   'marketCapitalization': 29248869229.0166,
#   'minusCashAndCashEquivalents': 13911000000,
#   'addTotalDebt': 5223000000,
#   'enterpriseValue': 20560869229.0166},
#  {'symbol': 'HPQ',
#   'date': '2004-10-31',
#   'stockPrice': 6.7528255904,
#   'numberOfShares': 3024000000,
#   'marketCapitalization': 20420544585.3696,
#   'minusCashAndCashEquivalents': 12663000000,
#   'addTotalDebt': 7134000000,
#   'enterpriseValue': 14891544585.369598},
#  {'symbol': 'HPQ',
#   'date': '2003-10-31',
#   'stockPrice': 7.2551847015,
#   'numberOfShares': 3047000000,
#   'marketCapitalization': 22106547785.4705,
#   'minusCashAndCashEquivalents': 14188000000,
#   'addTotalDebt': 7574000000,
#   'enterpriseValue': 15492547785.4705},
#  {'symbol': 'HPQ',
#   'date': '2002-10-31',
#   'stockPrice': 6.3924065825,
#   'numberOfShares': 2499000000,
#   'marketCapitalization': 15974624049.6675,
#   'minusCashAndCashEquivalents': 11192000000,
#   'addTotalDebt': 7828000000,
#   'enterpriseValue': 12610624049.6675},
#  {'symbol': 'HPQ',
#   'date': '2001-10-31',
#   'stockPrice': 7.097150454,
#   'numberOfShares': 1936000000,
#   'marketCapitalization': 13740083278.944,
#   'minusCashAndCashEquivalents': 4197000000,
#   'addTotalDebt': 5451000000,
#   'enterpriseValue': 14994083278.944},
#  {'symbol': 'HPQ',
#   'date': '2000-10-31',
#   'stockPrice': 10.0427857124,
#   'numberOfShares': 1979000000,
#   'marketCapitalization': 19874672924.8396,
#   'minusCashAndCashEquivalents': 3415000000,
#   'addTotalDebt': 4957000000,
#   'enterpriseValue': 21416672924.8396},
#  {'symbol': 'HPQ',
#   'date': '1999-10-31',
#   'stockPrice': 15.0392291181,
#   'numberOfShares': 2018000000,
#   'marketCapitalization': 30349164360.325798,
#   'minusCashAndCashEquivalents': 5411000000,
#   'addTotalDebt': 4869000000,
#   'enterpriseValue': 29807164360.325798},
#  {'symbol': 'HPQ',
#   'date': '1998-10-31',
#   'stockPrice': 9.9162539379,
#   'numberOfShares': 2068000000,
#   'marketCapitalization': 20506813143.5772,
#   'minusCashAndCashEquivalents': 4046000000,
#   'addTotalDebt': 3308000000,
#   'enterpriseValue': 19768813143.5772},
#  {'symbol': 'HPQ',
#   'date': '1997-10-31',
#   'stockPrice': 9.6895876474,
#   'numberOfShares': 2114000000,
#   'marketCapitalization': 20483788286.6036,
#   'minusCashAndCashEquivalents': 3072000000,
#   'addTotalDebt': 4384000000,
#   'enterpriseValue': 21795788286.6036},
#  {'symbol': 'HPQ',
#   'date': '1996-10-31',
#   'stockPrice': 8.5404054056,
#   'numberOfShares': 2104000000,
#   'marketCapitalization': 17969012973.3824,
#   'minusCashAndCashEquivalents': 2885000000,
#   'addTotalDebt': 4704000000,
#   'enterpriseValue': 19788012973.3824},
#  {'symbol': 'HPQ',
#   'date': '1995-10-31',
#   'stockPrice': 6.5780776602,
#   'numberOfShares': 2104000000,
#   'marketCapitalization': 13840275397.0608,
#   'minusCashAndCashEquivalents': 1973000000,
#   'addTotalDebt': 3877000000,
#   'enterpriseValue': 15744275397.0608},
#  {'symbol': 'HPQ',
#   'date': '1994-10-31',
#   'stockPrice': 3.8735366945,
#   'numberOfShares': 2083387622,
#   'marketCapitalization': 8070078402.684095,
#   'minusCashAndCashEquivalents': 1357000000,
#   'addTotalDebt': 3016000000,
#   'enterpriseValue': 9729078402.684095}]

# %% [markdown]
# We have almost 30 years of value metrics on Hewlett Packard. This allows us to build DataFrames and Draw some graphs.

# %%
# Building our dataframe of cevdf
cevdf = pd.DataFrame(cev)

# Inspecting
cevdf.head()
# Out:
#   symbol        date  stockPrice  numberOfShares  marketCapitalization  \
# 0    HPQ  2021-10-31   34.800868      1208000000          4.203945e+10
# 1    HPQ  2020-10-31   21.040844      1413000000          2.973071e+10
# 2    HPQ  2019-10-31   18.573738      1515000000          2.813921e+10
# 3    HPQ  2018-10-31   20.607082      1615000000          3.328044e+10
# 4    HPQ  2017-10-31   18.762472      1688000000          3.167105e+10
#
#    minusCashAndCashEquivalents  addTotalDebt  enterpriseValue
# 0                   4299000000    8778000000     4.651845e+10
# 1                   4864000000    6492000000     3.135871e+10
# 2                   4537000000    5137000000     2.873921e+10
# 3                   5166000000    5987000000     3.410144e+10
# 4                   6997000000    7819000000     3.249305e+10

# %%
# Setting the new index
cevdf.set_index("date", inplace=True)

# %%
# Inspecting
cevdf.head()
# Out:
#            symbol  stockPrice  numberOfShares  marketCapitalization  \
# date
# 2021-10-31    HPQ   34.800868      1208000000          4.203945e+10
# 2020-10-31    HPQ   21.040844      1413000000          2.973071e+10
# 2019-10-31    HPQ   18.573738      1515000000          2.813921e+10
# 2018-10-31    HPQ   20.607082      1615000000          3.328044e+10
# 2017-10-31    HPQ   18.762472      1688000000          3.167105e+10
#
#             minusCashAndCashEquivalents  addTotalDebt  enterpriseValue
# date
# 2021-10-31                   4299000000    8778000000     4.651845e+10
# 2020-10-31                   4864000000    6492000000     3.135871e+10
# 2019-10-31                   4537000000    5137000000     2.873921e+10
# 2018-10-31                   5166000000    5987000000     3.410144e+10
# 2017-10-31                   6997000000    7819000000     3.249305e+10

# %%
# Removing the symbol column
cevdf.drop(columns=['symbol'], inplace=True)

# %%
# Inspecting
cevdf.head()
# Out:
#             stockPrice  numberOfShares  marketCapitalization  \
# date
# 2021-10-31   34.800868      1208000000          4.203945e+10
# 2020-10-31   21.040844      1413000000          2.973071e+10
# 2019-10-31   18.573738      1515000000          2.813921e+10
# 2018-10-31   20.607082      1615000000          3.328044e+10
# 2017-10-31   18.762472      1688000000          3.167105e+10
#
#             minusCashAndCashEquivalents  addTotalDebt  enterpriseValue
# date
# 2021-10-31                   4299000000    8778000000     4.651845e+10
# 2020-10-31                   4864000000    6492000000     3.135871e+10
# 2019-10-31                   4537000000    5137000000     2.873921e+10
# 2018-10-31                   5166000000    5987000000     3.410144e+10
# 2017-10-31                   6997000000    7819000000     3.249305e+10

# %% [markdown]
# Thanks to this data, it will be easier to check entreprise value, stock price and market capitalization overtime.

# %% [markdown]
# ## Financial Statement Growth

# %% [markdown]
# In one of the previous notebook I've made, I talked about the three financial statements.
#
# In this call, it will be possible to track growth year-over-year of each metrics of the several financial statements.
#
# We will check the financial statements growth of a company called Rev Group (ticker:revg) which manufactures special professional vehicles.

# %% [markdown]
# ### Income statement growth

# %%
# Building url
url5 = "https://financialmodelingprep.com/api/v3/income-statement-growth/REVG?limit=40&apikey="+key

# Calling our url
# isg stands for income statement growth
isg = requests.get(url5).json()

# Inspecting
isg
# Out:
# [{'date': '2021-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthRevenue': 0.0455862977602108,
#   'growthCostOfRevenue': 0.019912152269399706,
#   'growthGrossProfit': 0.27631578947368424,
#   'growthGrossProfitRatio': 0.2206699649830248,
#   'growthResearchAndDevelopmentExpenses': -0.12,
#   'growthGeneralAndAdministrativeExpenses': -1.0,
#   'growthSellingAndMarketingExpenses': 0.0,
#   'growthOtherExpenses': -0.3466666666666667,
#   'growthOperatingExpenses': -0.09285714285714286,
#   'growthCostAndExpenses': -0.0008714596949891067,
#   'growthInterestExpense': 1.692,
#   'growthDepreciationAndAmortization': -0.20398009950248755,
#   'growthEBITDA': 4.409090909090909,
#   'growthEBITDARatio': 4.260458669354836,
#   'growthOperatingIncome': 5.681564245810056,
#   'growthOperatingIncomeRatio': 5.4774537078752905,
#   'growthTotalOtherIncomeExpensesNet': 0.0,
#   'growthIncomeBeforeTax': 2.2108695652173913,
#   'growthIncomeBeforeTaxRatio': 2.158077116935486,
#   'growthIncomeTaxExpense': 0.0,
#   'growthNetIncome': 1.9652173913043478,
#   'growthNetIncomeRatio': 1.9231350806451615,
#   'growthEPS': 2.4583333333333335,
#   'growthEPSDiluted': 2.4375,
#   'growthWeightedAverageShsOut': 0.005451720165281643,
#   'growthWeightedAverageShsOutDil': 0.025501725183929312},
#  {'date': '2020-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthRevenue': -0.05271040479261139,
#   'growthCostOfRevenue': -0.04781820716576049,
#   'growthGrossProfit': -0.09451945988880063,
#   'growthGrossProfitRatio': -0.04413545267225057,
#   'growthResearchAndDevelopmentExpenses': 0.041666666666666664,
#   'growthGeneralAndAdministrativeExpenses': 0.023582538886101356,
#   'growthSellingAndMarketingExpenses': 0.0,
#   'growthOtherExpenses': -0.12790697674418605,
#   'growthOperatingExpenses': 0.012200632625395391,
#   'growthCostAndExpenses': -0.0329512893982808,
#   'growthInterestExpense': -1.7692307692307692,
#   'growthDepreciationAndAmortization': -0.12035010940919037,
#   'growthEBITDA': -1.4935897435897436,
#   'growthEBITDARatio': -1.5210547504025773,
#   'growthOperatingIncome': -2.1257861635220126,
#   'growthOperatingIncomeRatio': -2.1884287225550554,
#   'growthTotalOtherIncomeExpensesNet': 0.13538461538461538,
#   'growthIncomeBeforeTax': -1.7710843373493976,
#   'growthIncomeBeforeTaxRatio': -1.9252768650359005,
#   'growthIncomeTaxExpense': 1.0,
#   'growthNetIncome': -2.7398373983739837,
#   'growthNetIncomeRatio': -2.9479346308614582,
#   'growthEPS': -1.3999999999999997,
#   'growthEPSDiluted': -1.3999999999999997,
#   'growthWeightedAverageShsOut': 0.004072470146720378,
#   'growthWeightedAverageShsOutDil': 0.004072470146720378},
#  {'date': '2019-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthRevenue': 0.009406626632511654,
#   'growthCostOfRevenue': 0.023106546854942234,
#   'growthGrossProfit': -0.09424460431654676,
#   'growthGrossProfitRatio': -0.10268530859050581,
#   'growthResearchAndDevelopmentExpenses': -0.26153846153846155,
#   'growthGeneralAndAdministrativeExpenses': 0.09026258205689278,
#   'growthSellingAndMarketingExpenses': 0.0,
#   'growthOtherExpenses': -0.049723756906077346,
#   'growthOperatingExpenses': 0.06702025072324011,
#   'growthCostAndExpenses': 0.027048080668195786,
#   'growthInterestExpense': 0.26953125,
#   'growthDepreciationAndAmortization': -0.006521739130434782,
#   'growthEBITDA': -0.15447154471544716,
#   'growthEBITDARatio': -0.16235099614381768,
#   'growthOperatingIncome': -0.42805755395683454,
#   'growthOperatingIncomeRatio': -0.4333874665047271,
#   'growthTotalOtherIncomeExpensesNet': -0.26953125,
#   'growthIncomeBeforeTax': -8.545454545454545,
#   'growthIncomeBeforeTaxRatio': -8.475138706615178,
#   'growthIncomeTaxExpense': 0.6759259259259259,
#   'growthNetIncome': -1.9461538461538461,
#   'growthNetIncomeRatio': -1.9373366700695407,
#   'growthEPS': -2.0,
#   'growthEPSDiluted': -2.0,
#   'growthWeightedAverageShsOut': -0.01841281322392334,
#   'growthWeightedAverageShsOutDil': -0.03712617275995712},
#  {'date': '2018-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthRevenue': 0.05005637664626642,
#   'growthCostOfRevenue': 0.06594485345728897,
#   'growthGrossProfit': -0.05636040243852765,
#   'growthGrossProfitRatio': -0.10134387205444613,
#   'growthResearchAndDevelopmentExpenses': 0.5406494429959706,
#   'growthGeneralAndAdministrativeExpenses': -0.02898696994002879,
#   'growthSellingAndMarketingExpenses': 0.0,
#   'growthOtherExpenses': 0.2128115786652372,
#   'growthOperatingExpenses': 0.0,
#   'growthCostAndExpenses': 0.05967268326439904,
#   'growthInterestExpense': 0.2339133368679809,
#   'growthDepreciationAndAmortization': 0.21654501216545013,
#   'growthEBITDA': -0.3203168170933874,
#   'growthEBITDARatio': -0.35271743686998347,
#   'growthOperatingIncome': -0.663796439628483,
#   'growthOperatingIncomeRatio': -0.6798233239197073,
#   'growthTotalOtherIncomeExpensesNet': 0.21633452719870205,
#   'growthIncomeBeforeTax': -0.9560184722416585,
#   'growthIncomeBeforeTaxRatio': -0.9581150795933335,
#   'growthIncomeTaxExpense': -1.579088471849866,
#   'growthNetIncome': -0.5856045392241241,
#   'growthNetIncomeRatio': -0.6053588454941844,
#   'growthEPS': -0.6153846153846154,
#   'growthEPSDiluted': -0.6,
#   'growthWeightedAverageShsOut': 0.05315818986002262,
#   'growthWeightedAverageShsOutDil': 0.044942791253051895},
#  {'date': '2017-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthRevenue': 0.17745803606336244,
#   'growthCostOfRevenue': 0.16338436902294012,
#   'growthGrossProfit': 0.28127133792311604,
#   'growthGrossProfitRatio': 0.08816730505898444,
#   'growthResearchAndDevelopmentExpenses': -0.12377985462097611,
#   'growthGeneralAndAdministrativeExpenses': 0.0,
#   'growthSellingAndMarketingExpenses': 0.0,
#   'growthOtherExpenses': -0.8999691676608979,
#   'growthOperatingExpenses': 0.3466745449941237,
#   'growthCostAndExpenses': 0.17864229434774878,
#   'growthInterestExpense': -0.2884628575348103,
#   'growthDepreciationAndAmortization': 0.5375106737689587,
#   'growthEBITDA': 0.11945068767140235,
#   'growthEBITDARatio': -0.04926489659529502,
#   'growthOperatingIncome': 0.14208367287744644,
#   'growthOperatingIncomeRatio': -0.03004299270331943,
#   'growthTotalOtherIncomeExpensesNet': -0.1203443308868921,
#   'growthIncomeBeforeTax': 0.15674213167449066,
#   'growthIncomeBeforeTaxRatio': -0.01759375175537722,
#   'growthIncomeTaxExpense': 0.42911877394636017,
#   'growthNetIncome': 0.03901566588282052,
#   'growthNetIncomeRatio': -0.11757732839753612,
#   'growthEPS': 0.10374342662206369,
#   'growthEPSDiluted': 0.06438056834365533,
#   'growthWeightedAverageShsOut': -0.052255737201914565,
#   'growthWeightedAverageShsOutDil': -0.029066218935478803},
#  {'date': '2016-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthRevenue': 0.11003405604695113,
#   'growthCostOfRevenue': 0.09203432816505025,
#   'growthGrossProfit': 0.2636765336293789,
#   'growthGrossProfitRatio': 0.13841239982274736,
#   'growthResearchAndDevelopmentExpenses': -0.05699177438307873,
#   'growthGeneralAndAdministrativeExpenses': 0.0,
#   'growthSellingAndMarketingExpenses': 0.0,
#   'growthOtherExpenses': 0.3453627305108436,
#   'growthOperatingExpenses': 0.32765234782458774,
#   'growthCostAndExpenses': 0.10840930114407044,
#   'growthInterestExpense': 0.06915517747139924,
#   'growthDepreciationAndAmortization': 0.288671138126179,
#   'growthEBITDA': 0.19497831657796175,
#   'growthEBITDARatio': 0.0765240129960651,
#   'growthOperatingIncome': 0.166178081309194,
#   'growthOperatingIncomeRatio': 0.05057865112912355,
#   'growthTotalOtherIncomeExpensesNet': -0.06915517747139924,
#   'growthIncomeBeforeTax': 0.24218660232103872,
#   'growthIncomeBeforeTaxRatio': 0.11905269532423671,
#   'growthIncomeTaxExpense': 0.09342270632593214,
#   'growthNetIncome': 0.3197971762031735,
#   'growthNetIncomeRatio': 0.18896998611305862,
#   'growthEPS': 0.3197970220765898,
#   'growthEPSDiluted': 0.31979735067609166,
#   'growthWeightedAverageShsOut': 0.0,
#   'growthWeightedAverageShsOutDil': 0.0},
#  {'date': '2015-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthRevenue': 0.00811392143237295,
#   'growthCostOfRevenue': -0.0030490212000048784,
#   'growthGrossProfit': 0.1146478476344501,
#   'growthGrossProfitRatio': 0.10567647558195145,
#   'growthResearchAndDevelopmentExpenses': -0.3829607250755287,
#   'growthGeneralAndAdministrativeExpenses': 0.0,
#   'growthSellingAndMarketingExpenses': 0.0,
#   'growthOtherExpenses': -0.08054887654423348,
#   'growthOperatingExpenses': -0.09996508515343136,
#   'growthCostAndExpenses': -0.010454349813429518,
#   'growthInterestExpense': 0.04111471654895973,
#   'growthDepreciationAndAmortization': 0.009682027405957357,
#   'growthEBITDA': 0.6272980613083663,
#   'growthEBITDARatio': 0.6142005647498922,
#   'growthOperatingIncome': 1.0041319646200528,
#   'growthOperatingIncomeRatio': 0.9880014768296138,
#   'growthTotalOtherIncomeExpensesNet': -0.04111471654895973,
#   'growthIncomeBeforeTax': 6.278277231862847,
#   'growthIncomeBeforeTaxRatio': 6.219697176209582,
#   'growthIncomeTaxExpense': 2.622154779969651,
#   'growthNetIncome': 14.374327956989248,
#   'growthNetIncomeRatio': 14.250585901189387,
#   'growthEPS': 14.374580067189248,
#   'growthEPSDiluted': 14.374325083149756,
#   'growthWeightedAverageShsOut': 0.0,
#   'growthWeightedAverageShsOutDil': 0.0},
#  {'date': '2014-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthRevenue': 0.46721327546713654,
#   'growthCostOfRevenue': 0.4756214343831785,
#   'growthGrossProfit': 0.3915419238244621,
#   'growthGrossProfitRatio': -0.05157488206244913,
#   'growthResearchAndDevelopmentExpenses': 3.441760601180891,
#   'growthGeneralAndAdministrativeExpenses': 0.0,
#   'growthSellingAndMarketingExpenses': 0.0,
#   'growthOtherExpenses': 0.2725661289131329,
#   'growthOperatingExpenses': 0.33366100993377484,
#   'growthCostAndExpenses': 0.4637164900905341,
#   'growthInterestExpense': 0.128025148566015,
#   'growthDepreciationAndAmortization': 0.3146692634068304,
#   'growthEBITDA': -0.024695944624770247,
#   'growthEBITDARatio': -0.3352676998749839,
#   'growthOperatingIncome': 2.264278187565859,
#   'growthOperatingIncomeRatio': 1.22481505732462,
#   'growthTotalOtherIncomeExpensesNet': -7.463113742906489,
#   'growthIncomeBeforeTax': -0.6468286199512663,
#   'growthIncomeBeforeTaxRatio': -0.7592910410817486,
#   'growthIncomeTaxExpense': 1.2869459200557345,
#   'growthNetIncome': -0.9405418364900503,
#   'growthNetIncomeRatio': -0.9594754460689984,
#   'growthEPS': -0.9405427414666875,
#   'growthEPSDiluted': -0.9405418038554985,
#   'growthWeightedAverageShsOut': 0.0,
#   'growthWeightedAverageShsOutDil': 0.0}]

# %%
# Building our DataFrame
isgdf = pd.DataFrame(isg)

# Inspecting
isgdf.head()
# Out:
#          date symbol period  growthRevenue  growthCostOfRevenue  \
# 0  2021-10-31   REVG     FY       0.045586             0.019912
# 1  2020-10-31   REVG     FY      -0.052710            -0.047818
# 2  2019-10-31   REVG     FY       0.009407             0.023107
# 3  2018-10-31   REVG     FY       0.050056             0.065945
# 4  2017-10-31   REVG     FY       0.177458             0.163384
#
#    growthGrossProfit  growthGrossProfitRatio  \
# 0           0.276316                0.220670
# 1          -0.094519               -0.044135
# 2          -0.094245               -0.102685
# 3          -0.056360               -0.101344
# 4           0.281271                0.088167
#
#    growthResearchAndDevelopmentExpenses  \
# 0                             -0.120000
# 1                              0.041667
# 2                             -0.261538
# 3                              0.540649
# 4                             -0.123780
#
#    growthGeneralAndAdministrativeExpenses  growthSellingAndMarketingExpenses  \
# 0                               -1.000000                                0.0
# 1                                0.023583                                0.0
# 2                                0.090263                                0.0
# 3                               -0.028987                                0.0
# 4                                0.000000                                0.0
#
#    ...  growthTotalOtherIncomeExpensesNet  growthIncomeBeforeTax  \
# 0  ...                           0.000000               2.210870
# 1  ...                           0.135385              -1.771084
# 2  ...                          -0.269531              -8.545455
# 3  ...                           0.216335              -0.956018
# 4  ...                          -0.120344               0.156742
#
#    growthIncomeBeforeTaxRatio  growthIncomeTaxExpense  growthNetIncome  \
# 0                    2.158077                0.000000         1.965217
# 1                   -1.925277                1.000000        -2.739837
# 2                   -8.475139                0.675926        -1.946154
# 3                   -0.958115               -1.579088        -0.585605
# 4                   -0.017594                0.429119         0.039016
#
#    growthNetIncomeRatio  growthEPS  growthEPSDiluted  \
# 0              1.923135   2.458333          2.437500
# 1             -2.947935  -1.400000         -1.400000
# 2             -1.937337  -2.000000         -2.000000
# 3             -0.605359  -0.615385         -0.600000
# 4             -0.117577   0.103743          0.064381
#
#    growthWeightedAverageShsOut  growthWeightedAverageShsOutDil
# 0                     0.005452                        0.025502
# 1                     0.004072                        0.004072
# 2                    -0.018413                       -0.037126
# 3                     0.053158                        0.044943
# 4                    -0.052256                       -0.029066
#
# [5 rows x 29 columns]

# %% [markdown]
# It's important to see year on year progress as it can generate an overview of company's growth in terms of annual general performance.

# %% [markdown]
# ### Balance sheet growth

# %%
# Building our url
url6 = "https://financialmodelingprep.com/api/v3/balance-sheet-statement-growth/REVG?limit=40&apikey="+key

# Calling our url
# bsg stands for balance sheet growth
bsg = requests.get(url6).json()

# Inspecting
bsg
# Out:
# [{'date': '2021-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthCashAndCashEquivalents': 0.20909090909090908,
#   'growthShortTermInvestments': 0.0,
#   'growthCashAndShortTermInvestments': 0.20909090909090908,
#   'growthNetReceivables': 0.08471615720524017,
#   'growthInventory': -0.10297951582867784,
#   'growthOtherCurrentAssets': -0.49714285714285716,
#   'growthTotalCurrentAssets': -0.06280788177339902,
#   'growthPropertyPlantEquipmentNet': 0.05178571428571429,
#   'growthGoodwill': 0.001910828025477707,
#   'growthIntangibleAssets': -0.0713235294117647,
#   'growthGoodwillAndIntangibleAssets': -0.032081911262798635,
#   'growthLongTermInvestments': 0.0,
#   'growthTaxAssets': 0.0,
#   'growthOtherNonCurrentAssets': 0.0,
#   'growthTotalNonCurrentAssets': 0.035357917570498915,
#   'growthOtherAssets': 0.0,
#   'growthTotalAssets': -0.02725844461901021,
#   'growthAccountPayables': -0.31242603550295855,
#   'growthShortTermDebt': 3.176470588235294,
#   'growthTaxPayables': 0.0,
#   'growthDeferredRevenue': 104.3,
#   'growthOtherCurrentLiabilities': -0.6241341596791834,
#   'growthTotalCurrentLiabilities': -0.02237136465324385,
#   'growthLongTermDebt': 226.8,
#   'growthDeferredRevenueNonCurrent': 0.0,
#   'growthDeferrredTaxLiabilitiesNonCurrent': 0.0,
#   'growthOtherNonCurrentLiabilities': 0.040625,
#   'growthTotalNonCurrentLiabilities': 7.5606060606060606,
#   'growthOtherLiabilities': -1.0,
#   'growthTotalLiabilities': -0.14345238095238094,
#   'growthCommonStock': 0.0,
#   'growthRetainedEarnings': 1.7952380952380953,
#   'growthAccumulatedOtherComprehensiveIncomeLoss': 0.9666666666666667,
#   'growthOthertotalStockholdersEquity': 0.012298387096774194,
#   'growthTotalStockholdersEquity': 0.09845437222104594,
#   'growthTotalLiabilitiesAndStockholdersEquity': -0.05638954507353502,
#   'growthTotalInvestments': 0.0,
#   'growthTotalDebt': 86.0,
#   'growthNetDebt': 27.698795180722893},
#  {'date': '2020-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthCashAndCashEquivalents': 2.3333333333333335,
#   'growthShortTermInvestments': 0.0,
#   'growthCashAndShortTermInvestments': 2.3333333333333335,
#   'growthNetReceivables': -0.09664694280078895,
#   'growthInventory': 0.04596805609661083,
#   'growthOtherCurrentAssets': -0.10025706940874037,
#   'growthTotalCurrentAssets': 0.0035842293906810036,
#   'growthPropertyPlantEquipmentNet': -0.1670798215171046,
#   'growthGoodwill': -0.017521902377972465,
#   'growthIntangibleAssets': -0.14946841776110067,
#   'growthGoodwillAndIntangibleAssets': -0.08351579605880513,
#   'growthLongTermInvestments': 0.0,
#   'growthTaxAssets': 0.0,
#   'growthOtherNonCurrentAssets': -1.0,
#   'growthTotalNonCurrentAssets': -0.14312267657992564,
#   'growthOtherAssets': 0.0,
#   'growthTotalAssets': -0.05500705218617771,
#   'growthAccountPayables': -0.15836653386454183,
#   'growthShortTermDebt': -0.5277777777777778,
#   'growthTaxPayables': 0.0,
#   'growthDeferredRevenue': -0.9846035411855273,
#   'growthOtherCurrentLiabilities': 1.6971484759095379,
#   'growthTotalCurrentLiabilities': 0.02522935779816514,
#   'growthLongTermDebt': -0.997344662772172,
#   'growthDeferredRevenueNonCurrent': 0.0,
#   'growthDeferrredTaxLiabilitiesNonCurrent': -1.0,
#   'growthOtherNonCurrentLiabilities': 1.3021582733812949,
#   'growthTotalNonCurrentLiabilities': -0.9186991869918699,
#   'growthOtherLiabilities': 0.0,
#   'growthTotalLiabilities': -0.002256800095023162,
#   'growthCommonStock': -1.0,
#   'growthRetainedEarnings': -2.329113924050633,
#   'growthAccumulatedOtherComprehensiveIncomeLoss': -0.5,
#   'growthOthertotalStockholdersEquity': 0.009977601303196904,
#   'growthTotalStockholdersEquity': -0.06475247524752475,
#   'growthTotalLiabilitiesAndStockholdersEquity': -0.025688618308708888,
#   'growthTotalInvestments': 0.0,
#   'growthTotalDebt': -0.992898474487112,
#   'growthNetDebt': -1.0220217564340675},
#  {'date': '2019-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthCashAndCashEquivalents': -0.7226890756302521,
#   'growthShortTermInvestments': 0.0,
#   'growthCashAndShortTermInvestments': -0.7226890756302521,
#   'growthNetReceivables': -0.0502060696890221,
#   'growthInventory': -0.0011673151750972762,
#   'growthOtherCurrentAssets': -0.22664015904572565,
#   'growthTotalCurrentAssets': -0.04032736330209939,
#   'growthPropertyPlantEquipmentNet': -0.058796080261315914,
#   'growthGoodwill': -0.012360939431396786,
#   'growthIntangibleAssets': -0.08419243986254296,
#   'growthGoodwillAndIntangibleAssets': -0.049643281807372173,
#   'growthLongTermInvestments': 0.0,
#   'growthTaxAssets': 0.0,
#   'growthOtherNonCurrentAssets': 0.16083916083916083,
#   'growthTotalNonCurrentAssets': -0.047787610619469026,
#   'growthOtherAssets': 0.0,
#   'growthTotalAssets': -0.043320786875932105,
#   'growthAccountPayables': -0.07932141219624025,
#   'growthShortTermDebt': 1.7692307692307692,
#   'growthTaxPayables': 0.0,
#   'growthDeferredRevenue': 0.10271646859083192,
#   'growthOtherCurrentLiabilities': 0.27125,
#   'growthTotalCurrentLiabilities': 0.045062320230105465,
#   'growthLongTermDebt': -0.10461245839277224,
#   'growthDeferredRevenueNonCurrent': 0.0,
#   'growthDeferrredTaxLiabilitiesNonCurrent': -0.22613065326633167,
#   'growthOtherNonCurrentLiabilities': -0.22777777777777777,
#   'growthTotalNonCurrentLiabilities': -0.11472191930207197,
#   'growthOtherLiabilities': 0.0,
#   'growthTotalLiabilities': -0.038597693273952266,
#   'growthCommonStock': 0.0,
#   'growthRetainedEarnings': -0.6108374384236454,
#   'growthAccumulatedOtherComprehensiveIncomeLoss': -1.0,
#   'growthOthertotalStockholdersEquity': -0.0012202562538133007,
#   'growthTotalStockholdersEquity': -0.049680090327436956,
#   'growthTotalLiabilitiesAndStockholdersEquity': -0.04278302892473883,
#   'growthTotalInvestments': 0.0,
#   'growthTotalDebt': -0.09883858734297227,
#   'growthNetDebt': -0.08073170731707317},
#  {'date': '2018-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthCashAndCashEquivalents': -0.3328848525619464,
#   'growthShortTermInvestments': 0.0,
#   'growthCashAndShortTermInvestments': -0.3328848525619464,
#   'growthNetReceivables': 0.09726116377928154,
#   'growthInventory': 0.136212918342986,
#   'growthOtherCurrentAssets': 2.761591384983548,
#   'growthTotalCurrentAssets': 0.15996543905606797,
#   'growthPropertyPlantEquipmentNet': -0.012819981297476081,
#   'growthGoodwill': 0.21439561676736593,
#   'growthIntangibleAssets': 0.03998522815941675,
#   'growthGoodwillAndIntangibleAssets': 0.11715517298636433,
#   'growthLongTermInvestments': 0.0,
#   'growthTaxAssets': 0.0,
#   'growthOtherNonCurrentAssets': 0.5220862160723789,
#   'growthTotalNonCurrentAssets': 0.07088703563305535,
#   'growthOtherAssets': 0.0,
#   'growthTotalAssets': 0.12250006377388332,
#   'growthAccountPayables': 0.003833992276783865,
#   'growthShortTermDebt': 0.7333333333333333,
#   'growthTaxPayables': 0.0,
#   'growthDeferredRevenue': 0.22997890868085283,
#   'growthOtherCurrentLiabilities': -0.16915918909936856,
#   'growthTotalCurrentLiabilities': 0.017364946754162003,
#   'growthLongTermDebt': 0.8358394622552978,
#   'growthDeferredRevenueNonCurrent': 0.0,
#   'growthDeferrredTaxLiabilitiesNonCurrent': -0.1166156168153771,
#   'growthOtherNonCurrentLiabilities': -0.11246979931956018,
#   'growthTotalNonCurrentLiabilities': 0.6862011010874802,
#   'growthOtherLiabilities': 0.0,
#   'growthTotalLiabilities': 0.2840326572745721,
#   'growthCommonStock': 0.5625,
#   'growthRetainedEarnings': 0.006120982330929546,
#   'growthAccumulatedOtherComprehensiveIncomeLoss': 0.9875146702624417,
#   'growthOthertotalStockholdersEquity': -0.19672219526659118,
#   'growthTotalStockholdersEquity': -0.07169310320732304,
#   'growthTotalLiabilitiesAndStockholdersEquity': 0.12170289023239203,
#   'growthTotalInvestments': 0.0,
#   'growthTotalDebt': 0.8355049922777403,
#   'growthNetDebt': 0.9338071947060849},
#  {'date': '2017-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthCashAndCashEquivalents': 0.6484613252009981,
#   'growthShortTermInvestments': 0.0,
#   'growthCashAndShortTermInvestments': 0.6484613252009981,
#   'growthNetReceivables': 0.34210627955351774,
#   'growthInventory': 0.3892326637656503,
#   'growthOtherCurrentAssets': 0.1109080335631802,
#   'growthTotalCurrentAssets': 0.37208011628565496,
#   'growthPropertyPlantEquipmentNet': 0.4825845842837825,
#   'growthGoodwill': 0.5766149549741442,
#   'growthIntangibleAssets': 0.35349080941631733,
#   'growthGoodwillAndIntangibleAssets': 0.44390473130757097,
#   'growthLongTermInvestments': 0.0,
#   'growthTaxAssets': 0.0,
#   'growthOtherNonCurrentAssets': 1.1747685185185186,
#   'growthTotalNonCurrentAssets': 0.46845575567300973,
#   'growthOtherAssets': 0.0,
#   'growthTotalAssets': 0.4110294605627101,
#   'growthAccountPayables': 0.6779836423876863,
#   'growthShortTermDebt': 0.0,
#   'growthTaxPayables': 0.0,
#   'growthDeferredRevenue': 0.09297362685017176,
#   'growthOtherCurrentLiabilities': -0.15902738960313023,
#   'growthTotalCurrentLiabilities': 0.23665275449029566,
#   'growthLongTermDebt': -0.10519840649898453,
#   'growthDeferredRevenueNonCurrent': 0.0,
#   'growthDeferrredTaxLiabilitiesNonCurrent': 0.29101954266720154,
#   'growthOtherNonCurrentLiabilities': -0.1446225221425559,
#   'growthTotalNonCurrentLiabilities': -0.08508103997658135,
#   'growthOtherLiabilities': 0.0,
#   'growthTotalLiabilities': 0.08458770075842513,
#   'growthCommonStock': 0.0,
#   'growthRetainedEarnings': 0.27477491707471174,
#   'growthAccumulatedOtherComprehensiveIncomeLoss': -0.3099026903262736,
#   'growthOthertotalStockholdersEquity': 1.1128903094861686,
#   'growthTotalStockholdersEquity': 1.1998647277646264,
#   'growthTotalLiabilitiesAndStockholdersEquity': 0.4110294605627101,
#   'growthTotalInvestments': 0.0,
#   'growthTotalDebt': -0.10226917669114201,
#   'growthNetDebt': -0.1353973387054021},
#  {'date': '2016-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthCashAndCashEquivalents': 1.1781400966183575,
#   'growthShortTermInvestments': 0.0,
#   'growthCashAndShortTermInvestments': 1.1781400966183575,
#   'growthNetReceivables': 0.6030479661061924,
#   'growthInventory': 0.31855508134854754,
#   'growthOtherCurrentAssets': -0.679210084481518,
#   'growthTotalCurrentAssets': 0.31606014230631635,
#   'growthPropertyPlantEquipmentNet': 0.6425150036457457,
#   'growthGoodwill': 0.02030787805614247,
#   'growthIntangibleAssets': 0.04320328334861189,
#   'growthGoodwillAndIntangibleAssets': 0.03380294257614213,
#   'growthLongTermInvestments': 0.0,
#   'growthTaxAssets': 0.0,
#   'growthOtherNonCurrentAssets': 0.7733990147783252,
#   'growthTotalNonCurrentAssets': 0.22495047884654068,
#   'growthOtherAssets': 0.0,
#   'growthTotalAssets': 0.2776547416648822,
#   'growthAccountPayables': 0.8510507505360972,
#   'growthShortTermDebt': 0.0,
#   'growthTaxPayables': 0.0,
#   'growthDeferredRevenue': 1.4014634547397846,
#   'growthOtherCurrentLiabilities': 0.5585745011026109,
#   'growthTotalCurrentLiabilities': 0.8432582364745054,
#   'growthLongTermDebt': 0.20549544714069135,
#   'growthDeferredRevenueNonCurrent': 0.0,
#   'growthDeferrredTaxLiabilitiesNonCurrent': -0.6173800543811946,
#   'growthOtherNonCurrentLiabilities': 0.3166370501999112,
#   'growthTotalNonCurrentLiabilities': 0.07678456265443505,
#   'growthOtherLiabilities': 0.0,
#   'growthTotalLiabilities': 0.3792352387658009,
#   'growthCommonStock': 0.0,
#   'growthRetainedEarnings': 0.2864225626854147,
#   'growthAccumulatedOtherComprehensiveIncomeLoss': -0.30643334828963953,
#   'growthOthertotalStockholdersEquity': 0.10528404105146694,
#   'growthTotalStockholdersEquity': 0.08462198954625408,
#   'growthTotalLiabilitiesAndStockholdersEquity': 0.2776547416648822,
#   'growthTotalInvestments': 0.0,
#   'growthTotalDebt': 0.20415745661477686,
#   'growthNetDebt': 0.18085639163640915},
#  {'date': '2015-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthCashAndCashEquivalents': -0.6031631919482386,
#   'growthShortTermInvestments': 0.0,
#   'growthCashAndShortTermInvestments': -0.6031631919482386,
#   'growthNetReceivables': -0.062350199457608,
#   'growthInventory': 0.011447083348691675,
#   'growthOtherCurrentAssets': 0.200390287597172,
#   'growthTotalCurrentAssets': -0.014711570001126011,
#   'growthPropertyPlantEquipmentNet': 0.05821393383269429,
#   'growthGoodwill': 0.0,
#   'growthIntangibleAssets': -0.06459555989112135,
#   'growthGoodwillAndIntangibleAssets': -0.03911136091912413,
#   'growthLongTermInvestments': 0.0,
#   'growthTaxAssets': 0.0,
#   'growthOtherNonCurrentAssets': -0.18391959798994975,
#   'growthTotalNonCurrentAssets': -0.01297595611865462,
#   'growthOtherAssets': 0.0,
#   'growthTotalAssets': -0.013980702492748201,
#   'growthAccountPayables': -0.18455135752672502,
#   'growthShortTermDebt': 0.0,
#   'growthTaxPayables': 0.0,
#   'growthDeferredRevenue': 0.16686386748105272,
#   'growthOtherCurrentLiabilities': -0.11267061239280106,
#   'growthTotalCurrentLiabilities': -0.09978382922508781,
#   'growthLongTermDebt': -0.05358280715982158,
#   'growthDeferredRevenueNonCurrent': 0.0,
#   'growthDeferrredTaxLiabilitiesNonCurrent': -0.05425134798838656,
#   'growthOtherNonCurrentLiabilities': 0.2259513921982436,
#   'growthTotalNonCurrentLiabilities': -0.03940444370197126,
#   'growthOtherLiabilities': 0.0,
#   'growthTotalLiabilities': -0.06417267073095634,
#   'growthCommonStock': 0.0,
#   'growthRetainedEarnings': 1.9497722368736514,
#   'growthAccumulatedOtherComprehensiveIncomeLoss': -0.2258191246955292,
#   'growthOthertotalStockholdersEquity': 0.05538018006410153,
#   'growthTotalStockholdersEquity': 0.09791915503141632,
#   'growthTotalLiabilitiesAndStockholdersEquity': -0.013980702492748201,
#   'growthTotalInvestments': 0.0,
#   'growthTotalDebt': -0.053770809877488175,
#   'growthNetDebt': -0.02135781407579856},
#  {'date': '2014-10-31',
#   'symbol': 'REVG',
#   'period': 'FY',
#   'growthCashAndCashEquivalents': 0.0,
#   'growthShortTermInvestments': 0.0,
#   'growthCashAndShortTermInvestments': 0.0,
#   'growthNetReceivables': 0.0,
#   'growthInventory': 0.0,
#   'growthOtherCurrentAssets': 0.0,
#   'growthTotalCurrentAssets': 0.0,
#   'growthPropertyPlantEquipmentNet': 0.0,
#   'growthGoodwill': 0.0,
#   'growthIntangibleAssets': 0.0,
#   'growthGoodwillAndIntangibleAssets': 0.0,
#   'growthLongTermInvestments': 0.0,
#   'growthTaxAssets': 0.0,
#   'growthOtherNonCurrentAssets': 0.0,
#   'growthTotalNonCurrentAssets': 0.0,
#   'growthOtherAssets': 0.0,
#   'growthTotalAssets': 0.0,
#   'growthAccountPayables': 0.0,
#   'growthShortTermDebt': 0.0,
#   'growthTaxPayables': 0.0,
#   'growthDeferredRevenue': 0.0,
#   'growthOtherCurrentLiabilities': 0.0,
#   'growthTotalCurrentLiabilities': 0.0,
#   'growthLongTermDebt': 0.0,
#   'growthDeferredRevenueNonCurrent': 0.0,
#   'growthDeferrredTaxLiabilitiesNonCurrent': 0.0,
#   'growthOtherNonCurrentLiabilities': 0.0,
#   'growthTotalNonCurrentLiabilities': 0.0,
#   'growthOtherLiabilities': 0.0,
#   'growthTotalLiabilities': 0.0,
#   'growthCommonStock': 0.0,
#   'growthRetainedEarnings': 0.0,
#   'growthAccumulatedOtherComprehensiveIncomeLoss': 0.0,
#   'growthOthertotalStockholdersEquity': 0.0,
#   'growthTotalStockholdersEquity': 0.0,
#   'growthTotalLiabilitiesAndStockholdersEquity': 0.0,
#   'growthTotalInvestments': 0.0,
#   'growthTotalDebt': 0.0,
#   'growthNetDebt': 0.0}]

# %% [markdown]
# We can see that we have all the growth of every single metrics of the balance sheet over the last few years.
#
# Thise can be translated into a DataFrame that can help us do some datavisualization.

# %%
# building our DataFrame
bsgdf = pd.DataFrame(bsg)

# Inspecting
bsgdf.head()
# Out:
#          date symbol period  growthCashAndCashEquivalents  \
# 0  2021-10-31   REVG     FY                      0.209091
# 1  2020-10-31   REVG     FY                      2.333333
# 2  2019-10-31   REVG     FY                     -0.722689
# 3  2018-10-31   REVG     FY                     -0.332885
# 4  2017-10-31   REVG     FY                      0.648461
#
#    growthShortTermInvestments  growthCashAndShortTermInvestments  \
# 0                         0.0                           0.209091
# 1                         0.0                           2.333333
# 2                         0.0                          -0.722689
# 3                         0.0                          -0.332885
# 4                         0.0                           0.648461
#
#    growthNetReceivables  growthInventory  growthOtherCurrentAssets  \
# 0              0.084716        -0.102980                 -0.497143
# 1             -0.096647         0.045968                 -0.100257
# 2             -0.050206        -0.001167                 -0.226640
# 3              0.097261         0.136213                  2.761591
# 4              0.342106         0.389233                  0.110908
#
#    growthTotalCurrentAssets  ...  growthTotalLiabilities  growthCommonStock  \
# 0                 -0.062808  ...               -0.143452             0.0000
# 1                  0.003584  ...               -0.002257            -1.0000
# 2                 -0.040327  ...               -0.038598             0.0000
# 3                  0.159965  ...                0.284033             0.5625
# 4                  0.372080  ...                0.084588             0.0000
#
#    growthRetainedEarnings  growthAccumulatedOtherComprehensiveIncomeLoss  \
# 0                1.795238                                       0.966667
# 1               -2.329114                                      -0.500000
# 2               -0.610837                                      -1.000000
# 3                0.006121                                       0.987515
# 4                0.274775                                      -0.309903
#
#    growthOthertotalStockholdersEquity  growthTotalStockholdersEquity  \
# 0                            0.012298                       0.098454
# 1                            0.009978                      -0.064752
# 2                           -0.001220                      -0.049680
# 3                           -0.196722                      -0.071693
# 4                            1.112890                       1.199865
#
#    growthTotalLiabilitiesAndStockholdersEquity  growthTotalInvestments  \
# 0                                    -0.056390                     0.0
# 1                                    -0.025689                     0.0
# 2                                    -0.042783                     0.0
# 3                                     0.121703                     0.0
# 4                                     0.411029                     0.0
#
#    growthTotalDebt  growthNetDebt
# 0        86.000000      27.698795
# 1        -0.992898      -1.022022
# 2        -0.098839      -0.080732
# 3         0.835505       0.933807
# 4        -0.102269      -0.135397
#
# [5 rows x 42 columns]

# %% [markdown]
# We won't go further here as the process is pretty similar to clean the data frame.
#
# Finally, we know it's going to same kind of data structure when it comes cashflow growth.

# %% [markdown]
# ### Other kind of growth
#
# There are other kind of growth. For instance, cashflow, or financial ratios. They follow mainly the same logic as our previous link, and thus need to be treated the same way.
#
# Here is a remark that might save user's time:
# - If ones need to observe data, and show it into a presentation, it's better to have in a normal dataframe. Thus, having the dates as column headers.
# - If ones need to compute time series graph, then it's better to have it in a transposed way where the index are datetime objects.

# %% [markdown]
# ## Key Metrics

# %% [markdown]
# While we computed already some of the main ratios that helps us assess a company's health in the previous section, Key Metrics here corresponds to the ones that helps us assess whether or not to invest in.
#
# While the latter is more for investing reasons, the first one is more oriented toward strategy and how to operate the business. Though it's communications for board and executives, it can also hint reasons why ones should invest in a company or not.
#
# Just like financial ratios, it's possible to have metrics in TTM (trailing twelve months) or fiscal year.
#
# For our exploration, we will us Trailing Twelve Months.
#
# The company we will use is Taiwan Semi-Conductor Company.

# %%
# Building our url
url7 = 'https://financialmodelingprep.com/api/v3/key-metrics-ttm/TSM?limit=40&apikey='+key

# Calling our url
# kmttm stands for key metrics trailing twelve months
kmttm = requests.get(url7).json()

# Inspecting
kmttm
# Out:
# [{'revenuePerShareTTM': 362.1377758480632,
#   'netIncomePerShareTTM': 146.98807990730685,
#   'operatingCashFlowPerShareTTM': 271.4963365526768,
#   'freeCashFlowPerShareTTM': 96.13032079572083,
#   'cashPerShareTTM': 279.656220741006,
#   'bookValuePerShareTTM': 481.3825959226415,
#   'tangibleBookValuePerShareTTM': 478.85645462590855,
#   'shareholdersEquityPerShareTTM': 481.3825959226415,
#   'interestDebtPerShareTTM': 173.73811277591844,
#   'marketCapTTM': 405149850062.48004,
#   'enterpriseValueTTM': 47264455062.47998,
#   'peRatioTTM': 16.622725,
#   'priceToSalesRatioTTM': 6.174415278173357,
#   'pocfratioTTM': 8.235798112016752,
#   'pfcfRatioTTM': 0.812717562505812,
#   'pbRatioTTM': 4.644931152349606,
#   'ptbRatioTTM': 4.644931152349606,
#   'evToSalesTTM': 0.02516779564544787,
#   'enterpriseValueOverEBITDATTM': 0.03639846151203636,
#   'evToOperatingCashFlowTTM': 0.03357028552859566,
#   'evToFreeCashFlowTTM': 0.09481097600213952,
#   'earningsYieldTTM': 0.06573738907280341,
#   'freeCashFlowYieldTTM': 1.2304397568532286,
#   'debtToEquityTTM': 0.735264230991878,
#   'debtToAssetsTTM': 0.4223433011435254,
#   'netDebtToEBITDATTM': -0.2756083352364356,
#   'currentRatioTTM': 2.254820150515158,
#   'interestCoverageTTM': 148.1702002449242,
#   'incomeQualityTTM': 1.847063630764392,
#   'dividendYieldTTM': 0.021944812791513287,
#   'dividendYieldPercentageTTM': 2.194481279151329,
#   'payoutRatioTTM': 0.3338254393889854,
#   'salesGeneralAndAdministrativeToRevenueTTM': 0.016506310034753946,
#   'researchAndDevelopementToRevenueTTM': 0.0739112126727581,
#   'intangiblesToTotalAssetsTTM': 0.00495904922287682,
#   'capexToOperatingCashFlowTTM': -0.6459240591739283,
#   'capexToRevenueTTM': -0.48425220303592864,
#   'capexToDepreciationTTM': -2.057418544168251,
#   'stockBasedCompensationToRevenueTTM': 7.689565083874122e-05,
#   'grahamNumberTTM': 1261.762191618508,
#   'roicTTM': 0.23986326451521248,
#   'returnOnTangibleAssetsTTM': 0.17626778571304852,
#   'grahamNetNetTTM': -20.841313669605295,
#   'workingCapitalTTM': 1060625415000,
#   'tangibleAssetValueTTM': 2488910388000,
#   'netCurrentAssetValueTTM': 13.57306587263146,
#   'investedCapitalTTM': 0.35864468412128436,
#   'averageReceivablesTTM': 219036680500,
#   'averagePayablesTTM': 195041364000,
#   'averageInventoryTTM': 208778386500,
#   'daysSalesOutstandingTTM': 43.65043467110645,
#   'daysPayablesOutstandingTTM': 94.29830619326043,
#   'daysOfInventoryOnHandTTM': 93.83399043848146,
#   'receivablesTurnoverTTM': 8.361886949125951,
#   'payablesTurnoverTTM': 3.8706951878005933,
#   'inventoryTurnoverTTM': 3.8898484258675725,
#   'roeTTM': 0.33742596365099553,
#   'capexPerShareTTM': -175.36601575695593,
#   'dividendPerShareTTM': 49.06836036000001,
#   'debtToMarketCapTTM': 4.5303711940580556}]

# %%
# counting the number of metrics
print(len(kmttm[0]))
# Out:
# 60

# %% [markdown]
# There are more than 60 metrics that can be used for decision.

# %% [markdown]
# ## Company Rating
#
# Financial Modeling Prep has provided in its API the ratings made by institutional analysts.
#
# Those ratings are provided by financial modeling prep themselves.
#
# They provide the way their method for calculations: https://site.financialmodelingprep.com/developer/docs/recommendations-formula/
#
# Ratings define whether someone should invest or not in a given stock.

# %%
# Building our url
url8 = 'https://financialmodelingprep.com/api/v3/rating/TSM?apikey='+key

# Calling our url
# cr stands for company rating
cr = requests.get(url8).json()

# inspecting
cr
# Out:
# [{'symbol': 'TSM',
#   'date': '2022-09-19',
#   'rating': 'A+',
#   'ratingScore': 5,
#   'ratingRecommendation': 'Strong Buy',
#   'ratingDetailsDCFScore': 5,
#   'ratingDetailsDCFRecommendation': 'Strong Buy',
#   'ratingDetailsROEScore': 3,
#   'ratingDetailsROERecommendation': 'Neutral',
#   'ratingDetailsROAScore': 3,
#   'ratingDetailsROARecommendation': 'Neutral',
#   'ratingDetailsDEScore': 4,
#   'ratingDetailsDERecommendation': 'Buy',
#   'ratingDetailsPEScore': 5,
#   'ratingDetailsPERecommendation': 'Strong Buy',
#   'ratingDetailsPBScore': 5,
#   'ratingDetailsPBRecommendation': 'Strong Buy'}]

# %% [markdown]
# This comes pretty handy to have the recommandations of analysts, as it facilitate the decision making when it comes to building a portfolio.

# %% [markdown]
# ## Company Discounted cash flow value
#
# Discounted cash flow (DCF) refers to a valuation method that estimates the value of an investment using its expected future cash flows.
#
# DCF analysis attempts to determine the value of an investment today, based on projections of how much money that investment will generate in the future.
#
# It can help those considering whether to acquire a company or buy securities make their decisions. Discounted cash flow analysis can also assist business owners and managers in making capital budgeting or operating expenditures decisions.
#
# Source: https://www.investopedia.com/terms/d/dcf.asp
#
# Thanks to Financial Modelling Prep, we do not have to calculate everything as it's included already in their data.
#
# DCF calculation by FMP: https://site.financialmodelingprep.com/developer/docs/dcf-formula/
#
# In our case, we will only explore the several api calls and check what's in them.

# %% [markdown]
# ## Real time DCF
#
# In this section we will explore 3 data type:
# - DCF (the normal one) that include the stock price and the companies DCF,
# - Advanced Discoutned Cash Flow projection including WACC,unlevered,
# - Levered Cash Flow including WACC.

# %% [markdown]
# ### DCF
#
# Key Facts:
# - Discounted cash flow analysis helps to determine the value of an investment based on its future cash flows.
# - The present value of expected future cash flows is arrived at by using a projected discount rate.
# - If the DCF is higher than the current cost of the investment, the opportunity could result in positive returns and may be worthwhile.
# - Companies typically use the weighted average cost of capital (WACC) for the discount rate because it accounts for the rate of return expected by shareholders.
# - A disadvantage of DCF is its reliance on estimations of future cash flows, which could prove inaccurate.
#
# We will do our analysis with Foxconn company.

# %%
# Building our url:
url8 = 'https://financialmodelingprep.com/api/v3/discounted-cash-flow/2354.TW?apikey='+key

# Calling our url
# dcf stands for Discounted Cash Flow
dcf = requests.get(url8).json()

# Inspecting
dcf
# Out:
# [{'symbol': '2354.TW',
#   'date': '2022-09-20',
#   'dcf': 98.79346246257451,
#   'Stock Price': 48.3}]

# %% [markdown]
# The main advantage of having this API call is that it is easily usable.
#
# The key fact to understand is that if DCF is superior to current stock price, then you might be facing a very good bargain.

# %% [markdown]
# ### Levered Discounted Cash Flow
#
# The Levered DCF Model values a company by discounting the forecasted cash flows that belong only to equity holders, excluding all cash flows to non-equity claims such as debt.
#
# This method requires a deeper understanding of corporate finance and business projection.

# %%
# Building our url:
url9 = 'https://financialmodelingprep.com/api/v4/advanced_levered_discounted_cash_flow?symbol=2354.TW&apikey='+key

# Calling our url
# ldcf stands for Levered Discounted Cash Flow
ldcf = requests.get(url9).json()

# %%
# Inspecing
ldcf
# Out:
# [{'year': '2026',
#   'symbol': '2354.TW',
#   'revenue': 71134410000.0,
#   'revenuePercentage': -7.33,
#   'capitalExpenditure': -746800000.0,
#   'capitalExpenditurePercentage': -1.05,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 4731670000.0,
#   'pvLfcf': 2971870000.0,
#   'sumPvLfcf': 20350470000.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 3984870000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 6.65},
#  {'year': '2025',
#   'symbol': '2354.TW',
#   'revenue': 76760700000.0,
#   'revenuePercentage': -7.33,
#   'capitalExpenditure': -805870000.0,
#   'capitalExpenditurePercentage': -1.05,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 5105920000.0,
#   'pvLfcf': 3367600000.0,
#   'sumPvLfcf': 0.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 4300050000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 6.65},
#  {'year': '2024',
#   'symbol': '2354.TW',
#   'revenue': 82832000000.0,
#   'revenuePercentage': -7.33,
#   'capitalExpenditure': -869610000.0,
#   'capitalExpenditurePercentage': -1.05,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 5509760000.0,
#   'pvLfcf': 3816010000.0,
#   'sumPvLfcf': 0.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 4640160000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 6.65},
#  {'year': '2023',
#   'symbol': '2354.TW',
#   'revenue': 89383500000.0,
#   'revenuePercentage': -7.33,
#   'capitalExpenditure': -938390000.0,
#   'capitalExpenditurePercentage': -1.05,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 5945550000.0,
#   'pvLfcf': 4324140000.0,
#   'sumPvLfcf': 0.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 5007170000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 6.65},
#  {'year': '2022',
#   'symbol': '2354.TW',
#   'revenue': 96453180000.0,
#   'revenuePercentage': -7.33,
#   'capitalExpenditure': -1012610000.0,
#   'capitalExpenditurePercentage': -1.05,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 6415810000.0,
#   'pvLfcf': 4899930000.0,
#   'sumPvLfcf': 0.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 5403200000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 6.65},
#  {'year': '2021',
#   'symbol': '2354.TW',
#   'revenue': 104082030000.0,
#   'revenuePercentage': -0.68,
#   'capitalExpenditure': -1370480000.0,
#   'capitalExpenditurePercentage': -1.32,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 4553490000.0,
#   'pvLfcf': 0.0,
#   'sumPvLfcf': 0.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 3183010000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 4.37},
#  {'year': '2020',
#   'symbol': '2354.TW',
#   'revenue': 104789600000.0,
#   'revenuePercentage': 5.0,
#   'capitalExpenditure': -455080000.0,
#   'capitalExpenditurePercentage': -0.43,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 2433080000.0,
#   'pvLfcf': 0.0,
#   'sumPvLfcf': 0.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 1978000000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 2.32},
#  {'year': '2019',
#   'symbol': '2354.TW',
#   'revenue': 99802130000.0,
#   'revenuePercentage': -29.75,
#   'capitalExpenditure': -1171250000.0,
#   'capitalExpenditurePercentage': -1.17,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 12613620000.0,
#   'pvLfcf': 0.0,
#   'sumPvLfcf': 0.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 11442370000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 12.64},
#  {'year': '2018',
#   'symbol': '2354.TW',
#   'revenue': 142057430000.0,
#   'revenuePercentage': -3.9,
#   'capitalExpenditure': -1916430000.0,
#   'capitalExpenditurePercentage': -1.35,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 11749940000.0,
#   'pvLfcf': 0.0,
#   'sumPvLfcf': 0.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 9833510000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 8.27},
#  {'year': '2017',
#   'symbol': '2354.TW',
#   'revenue': 147815620000.0,
#   'revenuePercentage': 0.0,
#   'capitalExpenditure': -1442070000.0,
#   'capitalExpenditurePercentage': -0.98,
#   'price': 50.6,
#   'beta': 0.713,
#   'dilutedSharesOutstanding': 1420490000.0,
#   'costofDebt': 0.64,
#   'taxRate': 19.93,
#   'afterTaxCostOfDebt': 0.51,
#   'riskFreeRate': 3.082,
#   'marketRiskPremium': 4.72,
#   'costOfEquity': 6.447,
#   'totalDebt': 22964680000.0,
#   'totalEquity': 71876740000.0,
#   'totalCapital': 94841420000.0,
#   'debtWeighting': 24.21,
#   'equityWeighting': 75.79,
#   'wacc': 5.01,
#   'operatingCashFlow': 8354540000.000001,
#   'pvLfcf': 0.0,
#   'sumPvLfcf': 0.0,
#   'longTermGrowthRate': 2.0,
#   'freeCashFlow': 6912480000.0,
#   'terminalValue': 135035500000.0,
#   'presentTerminalValue': 105753480000.0,
#   'enterpriseValue': 126103950000.0,
#   'netDebt': -48760730000.0,
#   'equityValue': 174864680000.0,
#   'equityValuePerShare': 123.1,
#   'freeCashFlowT1': 4064570000.0,
#   'operatingCashFlowPercentage': 5.65}]

# %% [markdown]
# There are more data here as levered discounted cash flow requires more operations to be calculated.

# %% [markdown]
# ## Conclusion
#
# There are many more data points to be explored in the Financial Modelling Prep API that can help build a more accurate strategy when it comes to investing.
#
# One key element is that it proposes many endpoints that are not only on price, but add substential value to market forecasts.
