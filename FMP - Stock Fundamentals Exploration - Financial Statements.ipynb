# %% [markdown]
# # FMP Stock Fundamentals Exploration 2 : Financial Statements

# %% [markdown]
# Welcome to this Jupyter Notebook of the Finsloth.
#
# In this first Notebook of our serie, we are going to explore the first element of FMP Stock Fundamentals which is a Financial Statement.
#
# Our goal is to understand **the meaning and the structure of each data given by FMP, how to transform it for actual use in any trading or investing strategies**.

# %% [markdown]
# ## About Financial Modeling Prep
#
# Financial Modeling Prep is a stock market API that provides a wide range of data. Data covers stocks, crypto forex and commodities.
#
# You have addition data such as institutional stock ownership, esg score, price target, etc.
#
# There are several plans including a free one.
#
# I am on a start plan for this notebook. Here are the link for the pricing: https://site.financialmodelingprep.com/developer/docs/pricing/

# %% [markdown]
# # What are financial statements?

# %% [markdown]
# * Financial statements are written records that convey the business activities and the financial performance of an entity.
# * The **balance sheet** provides an overview of assets, liabilities, and shareholders' equity as a snapshot in time.
# * The **income statement** primarily focuses on a company’s revenues and expenses during a particular period. Once expenses are subtracted from revenues, the statement produces a company's profit figure called net income.
# * The **cash flow statement (CFS)** measures how well a company generates cash to pay its debt obligations, fund its operating expenses, and fund investments.
# * The statement of changes in equity records how profits are retained within a company for future growth or distributed to external parties.

# %% [markdown]
# ## Initial Import and API Key

# %% [markdown]
# In this section, we are going to perform classic libraries import to perform our data transformation and visualisation.

# %%
# We import the basics and some specific to APIs libraries

# Basic Data Manipulation Librairies
import pandas as pd

# requests is another way of sending an API request to FMP
import requests

# json library makes it easier to access JSON format
import json

# %% [markdown]
# For privacy reason, I have hidden my key to access the API.
#
# Here is the link to the dashboard where you can find your private key in case you created an account: https://site.financialmodelingprep.com/developer/docs/dashboard

# %%
# Because I want to share this file on Github, I made sure that it's not showing the actual key.
key=pd.read_csv('/key.txt', header=None)[0][0]

# %% [markdown]
# FMP provides us the right method to extract data from its API according to the coding language you are using.
#
# Here is the function they provided us to extract data with Python.

# %% [markdown]
# ## Financial Statement: Income Statement

# %% [markdown]
# In this section we are going to cover Income Statements.
#
# Income statement provides about the company **its revenue, its expenses and the income**.
#
# More details: https://www.investopedia.com/terms/i/incomestatement.asp
#
# Income statement can be made either **monthly, yearly or by quarter**.
#
# We made our income statement by year.
#
# We chose Apple as an exemple.

# %% [markdown]
# ### Raw exploration
#
# We'll do a raw exploration of the API before diving into how to structure the link for income statement

# %%
# We do our API call from FMP

# First define our url
url='https://financialmodelingprep.com/api/v3/income-statement/AAPL?limit=120&apikey='+key # list of all financial statements

# We do our call using requests and use the json method to get the right format.
# yis stands for yearly income statement
yis=requests.get(url).json()

# %%
print(yis[0])
# Out:
# {'date': '2021-09-25', 'symbol': 'AAPL', 'reportedCurrency': 'USD', 'cik': '0000320193', 'fillingDate': '2021-10-29', 'acceptedDate': '2021-10-28 18:04:28', 'calendarYear': '2021', 'period': 'FY', 'revenue': 365817000000, 'costOfRevenue': 212981000000, 'grossProfit': 152836000000, 'grossProfitRatio': 0.4177935962516778, 'researchAndDevelopmentExpenses': 21914000000, 'generalAndAdministrativeExpenses': 0.0, 'sellingAndMarketingExpenses': 0.0, 'sellingGeneralAndAdministrativeExpenses': 21973000000, 'otherExpenses': 0.0, 'operatingExpenses': 43887000000, 'costAndExpenses': 256868000000, 'interestIncome': 2843000000, 'interestExpense': 2645000000, 'depreciationAndAmortization': 11284000000, 'ebitda': 123136000000, 'ebitdaratio': 0.33660546120054563, 'operatingIncome': 108949000000, 'operatingIncomeRatio': 0.29782377527561593, 'totalOtherIncomeExpensesNet': 258000000, 'incomeBeforeTax': 109207000000, 'incomeBeforeTaxRatio': 0.2985290459437369, 'incomeTaxExpense': 14527000000, 'netIncome': 94680000000, 'netIncomeRatio': 0.2588179335569424, 'eps': 5.67, 'epsdiluted': 5.61, 'weightedAverageShsOut': 16701272000, 'weightedAverageShsOutDil': 16864919000, 'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/0000320193-21-000105-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/aapl-20210925.htm'}

# %% [markdown]
# We can see through the json format that the url contains all the information of an income statement and seems to have a structure along date.
#
# Let's transform this into a **Panda Data Frame**.
#
# Panda's dataframe will give us more room for analysis in general.

# %%
# We use pandas data frame method to transform our JSON in the DataFrame we want.
yis=pd.DataFrame(yis)

# %%
yis.head()
# Out:
#          date symbol reportedCurrency         cik fillingDate  \
# 0  2021-09-25   AAPL              USD  0000320193  2021-10-29
# 1  2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2  2019-09-28   AAPL              USD  0000320193  2019-10-31
# 3  2018-09-29   AAPL              USD  0000320193  2018-11-05
# 4  2017-09-30   AAPL              USD  0000320193  2017-11-03
#
#           acceptedDate calendarYear period       revenue  costOfRevenue  ...  \
# 0  2021-10-28 18:04:28         2021     FY  365817000000   212981000000  ...
# 1  2020-10-29 18:06:25         2020     FY  274515000000   169559000000  ...
# 2  2019-10-30 18:12:36         2019     FY  260174000000   161782000000  ...
# 3  2018-11-05 08:01:40         2018     FY  265595000000   163756000000  ...
# 4  2017-11-03 08:01:37         2017     FY  229234000000   141048000000  ...
#
#    incomeBeforeTaxRatio  incomeTaxExpense    netIncome  netIncomeRatio  \
# 0              0.298529      1.452700e+10  94680000000        0.258818
# 1              0.244398      9.680000e+09  57411000000        0.209136
# 2              0.252666      1.048100e+10  55256000000        0.212381
# 3              0.274489      1.337200e+10  59531000000        0.224142
# 4              0.279579      1.573800e+10  48351000000        0.210924
#
#       eps  epsdiluted  weightedAverageShsOut  weightedAverageShsOutDil  \
# 0  5.6700      5.6100            16701272000               16864919000
# 1  3.3100      3.2800            17352119000               17528214000
# 2  2.9925      2.9725            18471336000               18595652000
# 3  3.0025      2.9775            19821508000               20000436000
# 4  2.3175      2.3025            20868968000               21006768000
#
#                                                 link  \
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                            finalLink
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 38 columns]

# %% [markdown]
# As we can see, dates are leading the sorting of the income statements.
#
# There are two kind of dates:
# - **date** which is the date where the income statement has been made,
# - **accepted date** during which the statements has been approved,
# - **filing date** during which the document has been filed.
#
# We want to get rid of certain information that are not highly relevant such as symbol (we know which symbol we are talking about) for instance.
#
# Here are the columns that we might want to get rid of:
# - **date**, accepted date & filing date: we will only keep the year for modeling,
# - **symbol**: we know which symbols we are talking about,
# - **CIK**: it's a code that corresponds to the symbol,
# - **period**: we know which period it's about.

# %% [markdown]
# ### Manipulating the Income Statement

# %% [markdown]
# We are going to reshape the income statement in order to have fully operational.
#
# We are going to compute two main views:
# - A view for **dataviz** to make all kind of nice reports,
# - A view for **spreadsheets** and official documents.

# %%
# We use drop method(['columns'], axis='columns', inplace=True|False)
yis.drop(['date', 'symbol', 'reportedCurrency','cik','fillingDate', 'acceptedDate', 'period','link','finalLink'],axis='columns',inplace=True)

# %%
# Inspecting the heads of columns
yis.head()
# Out:
#   calendarYear       revenue  costOfRevenue   grossProfit  grossProfitRatio  \
# 0         2021  365817000000   212981000000  152836000000          0.417794
# 1         2020  274515000000   169559000000  104956000000          0.382332
# 2         2019  260174000000   161782000000   98392000000          0.378178
# 3         2018  265595000000   163756000000  101839000000          0.383437
# 4         2017  229234000000   141048000000   88186000000          0.384699
#
#    researchAndDevelopmentExpenses  generalAndAdministrativeExpenses  \
# 0                    2.191400e+10                               0.0
# 1                    1.875200e+10                               0.0
# 2                    1.621700e+10                               0.0
# 3                    1.423600e+10                               0.0
# 4                    1.158100e+10                               0.0
#
#    sellingAndMarketingExpenses  sellingGeneralAndAdministrativeExpenses  \
# 0                          0.0                              21973000000
# 1                          0.0                              19916000000
# 2                          0.0                              18245000000
# 3                          0.0                              16705000000
# 4                          0.0                              15261000000
#
#    otherExpenses  ...  totalOtherIncomeExpensesNet  incomeBeforeTax  \
# 0            0.0  ...                    258000000     109207000000
# 1            0.0  ...                    803000000      67091000000
# 2            0.0  ...                   1807000000      65737000000
# 3            0.0  ...                   2005000000      72903000000
# 4            0.0  ...                   2745000000      64089000000
#
#    incomeBeforeTaxRatio  incomeTaxExpense    netIncome  netIncomeRatio  \
# 0              0.298529      1.452700e+10  94680000000        0.258818
# 1              0.244398      9.680000e+09  57411000000        0.209136
# 2              0.252666      1.048100e+10  55256000000        0.212381
# 3              0.274489      1.337200e+10  59531000000        0.224142
# 4              0.279579      1.573800e+10  48351000000        0.210924
#
#       eps  epsdiluted  weightedAverageShsOut  weightedAverageShsOutDil
# 0  5.6700      5.6100            16701272000               16864919000
# 1  3.3100      3.2800            17352119000               17528214000
# 2  2.9925      2.9725            18471336000               18595652000
# 3  3.0025      2.9775            19821508000               20000436000
# 4  2.3175      2.3025            20868968000               21006768000
#
# [5 rows x 29 columns]

# %%
# We use the set_index() method to change our index to calendar Year
# Note that we haven't overwritten data yet
yis.set_index('calendarYear').head()
# Out:
#                    revenue  costOfRevenue   grossProfit  grossProfitRatio  \
# calendarYear
# 2021          365817000000   212981000000  152836000000          0.417794
# 2020          274515000000   169559000000  104956000000          0.382332
# 2019          260174000000   161782000000   98392000000          0.378178
# 2018          265595000000   163756000000  101839000000          0.383437
# 2017          229234000000   141048000000   88186000000          0.384699
#
#               researchAndDevelopmentExpenses  \
# calendarYear
# 2021                            2.191400e+10
# 2020                            1.875200e+10
# 2019                            1.621700e+10
# 2018                            1.423600e+10
# 2017                            1.158100e+10
#
#               generalAndAdministrativeExpenses  sellingAndMarketingExpenses  \
# calendarYear
# 2021                                       0.0                          0.0
# 2020                                       0.0                          0.0
# 2019                                       0.0                          0.0
# 2018                                       0.0                          0.0
# 2017                                       0.0                          0.0
#
#               sellingGeneralAndAdministrativeExpenses  otherExpenses  \
# calendarYear
# 2021                                      21973000000            0.0
# 2020                                      19916000000            0.0
# 2019                                      18245000000            0.0
# 2018                                      16705000000            0.0
# 2017                                      15261000000            0.0
#
#               operatingExpenses  ...  totalOtherIncomeExpensesNet  \
# calendarYear                     ...
# 2021                43887000000  ...                    258000000
# 2020                38668000000  ...                    803000000
# 2019                34462000000  ...                   1807000000
# 2018                30941000000  ...                   2005000000
# 2017                26842000000  ...                   2745000000
#
#               incomeBeforeTax  incomeBeforeTaxRatio  incomeTaxExpense  \
# calendarYear
# 2021             109207000000              0.298529      1.452700e+10
# 2020              67091000000              0.244398      9.680000e+09
# 2019              65737000000              0.252666      1.048100e+10
# 2018              72903000000              0.274489      1.337200e+10
# 2017              64089000000              0.279579      1.573800e+10
#
#                 netIncome  netIncomeRatio     eps  epsdiluted  \
# calendarYear
# 2021          94680000000        0.258818  5.6700      5.6100
# 2020          57411000000        0.209136  3.3100      3.2800
# 2019          55256000000        0.212381  2.9925      2.9725
# 2018          59531000000        0.224142  3.0025      2.9775
# 2017          48351000000        0.210924  2.3175      2.3025
#
#               weightedAverageShsOut  weightedAverageShsOutDil
# calendarYear
# 2021                    16701272000               16864919000
# 2020                    17352119000               17528214000
# 2019                    18471336000               18595652000
# 2018                    19821508000               20000436000
# 2017                    20868968000               21006768000
#
# [5 rows x 28 columns]

# %%
# For the sake of this exercise, we can see that we haven't rewritten entirely the data.
yis.head()
# Out:
#   calendarYear       revenue  costOfRevenue   grossProfit  grossProfitRatio  \
# 0         2021  365817000000   212981000000  152836000000          0.417794
# 1         2020  274515000000   169559000000  104956000000          0.382332
# 2         2019  260174000000   161782000000   98392000000          0.378178
# 3         2018  265595000000   163756000000  101839000000          0.383437
# 4         2017  229234000000   141048000000   88186000000          0.384699
#
#    researchAndDevelopmentExpenses  generalAndAdministrativeExpenses  \
# 0                    2.191400e+10                               0.0
# 1                    1.875200e+10                               0.0
# 2                    1.621700e+10                               0.0
# 3                    1.423600e+10                               0.0
# 4                    1.158100e+10                               0.0
#
#    sellingAndMarketingExpenses  sellingGeneralAndAdministrativeExpenses  \
# 0                          0.0                              21973000000
# 1                          0.0                              19916000000
# 2                          0.0                              18245000000
# 3                          0.0                              16705000000
# 4                          0.0                              15261000000
#
#    otherExpenses  ...  totalOtherIncomeExpensesNet  incomeBeforeTax  \
# 0            0.0  ...                    258000000     109207000000
# 1            0.0  ...                    803000000      67091000000
# 2            0.0  ...                   1807000000      65737000000
# 3            0.0  ...                   2005000000      72903000000
# 4            0.0  ...                   2745000000      64089000000
#
#    incomeBeforeTaxRatio  incomeTaxExpense    netIncome  netIncomeRatio  \
# 0              0.298529      1.452700e+10  94680000000        0.258818
# 1              0.244398      9.680000e+09  57411000000        0.209136
# 2              0.252666      1.048100e+10  55256000000        0.212381
# 3              0.274489      1.337200e+10  59531000000        0.224142
# 4              0.279579      1.573800e+10  48351000000        0.210924
#
#       eps  epsdiluted  weightedAverageShsOut  weightedAverageShsOutDil
# 0  5.6700      5.6100            16701272000               16864919000
# 1  3.3100      3.2800            17352119000               17528214000
# 2  2.9925      2.9725            18471336000               18595652000
# 3  3.0025      2.9775            19821508000               20000436000
# 4  2.3175      2.3025            20868968000               21006768000
#
# [5 rows x 29 columns]

# %%
# Here, we are entirely rewriting the data to make sure we have the right view.
yis.set_index('calendarYear', inplace=True)

# %%
# Renaming index as 'category'
yis.index.names = ['Category']

# %%
# As you can see, calendarYear is now the official index
yis.head()
# Out:
#                revenue  costOfRevenue   grossProfit  grossProfitRatio  \
# Category
# 2021      365817000000   212981000000  152836000000          0.417794
# 2020      274515000000   169559000000  104956000000          0.382332
# 2019      260174000000   161782000000   98392000000          0.378178
# 2018      265595000000   163756000000  101839000000          0.383437
# 2017      229234000000   141048000000   88186000000          0.384699
#
#           researchAndDevelopmentExpenses  generalAndAdministrativeExpenses  \
# Category
# 2021                        2.191400e+10                               0.0
# 2020                        1.875200e+10                               0.0
# 2019                        1.621700e+10                               0.0
# 2018                        1.423600e+10                               0.0
# 2017                        1.158100e+10                               0.0
#
#           sellingAndMarketingExpenses  \
# Category
# 2021                              0.0
# 2020                              0.0
# 2019                              0.0
# 2018                              0.0
# 2017                              0.0
#
#           sellingGeneralAndAdministrativeExpenses  otherExpenses  \
# Category
# 2021                                  21973000000            0.0
# 2020                                  19916000000            0.0
# 2019                                  18245000000            0.0
# 2018                                  16705000000            0.0
# 2017                                  15261000000            0.0
#
#           operatingExpenses  ...  totalOtherIncomeExpensesNet  \
# Category                     ...
# 2021            43887000000  ...                    258000000
# 2020            38668000000  ...                    803000000
# 2019            34462000000  ...                   1807000000
# 2018            30941000000  ...                   2005000000
# 2017            26842000000  ...                   2745000000
#
#           incomeBeforeTax  incomeBeforeTaxRatio  incomeTaxExpense  \
# Category
# 2021         109207000000              0.298529      1.452700e+10
# 2020          67091000000              0.244398      9.680000e+09
# 2019          65737000000              0.252666      1.048100e+10
# 2018          72903000000              0.274489      1.337200e+10
# 2017          64089000000              0.279579      1.573800e+10
#
#             netIncome  netIncomeRatio     eps  epsdiluted  \
# Category
# 2021      94680000000        0.258818  5.6700      5.6100
# 2020      57411000000        0.209136  3.3100      3.2800
# 2019      55256000000        0.212381  2.9925      2.9725
# 2018      59531000000        0.224142  3.0025      2.9775
# 2017      48351000000        0.210924  2.3175      2.3025
#
#           weightedAverageShsOut  weightedAverageShsOutDil
# Category
# 2021                16701272000               16864919000
# 2020                17352119000               17528214000
# 2019                18471336000               18595652000
# 2018                19821508000               20000436000
# 2017                20868968000               21006768000
#
# [5 rows x 28 columns]

# %% [markdown]
# Normally, in finance, people tend to have the Financial Statements oriented in transposed way of what we see right here:
# - Vertically all the different steps of the financial statements,
# - Horizontally, the dates.
#
# This is practical for human reading.
#
# However, when it comes to ploting time series, it's better to have it organised in a vertical way.

# %%
# for the sake of understanding what bankers usually read, we will transpose our dataframe
yist=yis.transpose()

# %%
# Renaming the index as "Date"
yist.index.names = ['Date']

# %%
# Let's observe what a transposed version of this DataFrame would look like
yist
# Out:
# Category                                         2021          2020  \
# Date
# revenue                                  3.658170e+11  2.745150e+11
# costOfRevenue                            2.129810e+11  1.695590e+11
# grossProfit                              1.528360e+11  1.049560e+11
# grossProfitRatio                         4.177936e-01  3.823325e-01
# researchAndDevelopmentExpenses           2.191400e+10  1.875200e+10
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00
# sellingGeneralAndAdministrativeExpenses  2.197300e+10  1.991600e+10
# otherExpenses                            0.000000e+00  0.000000e+00
# operatingExpenses                        4.388700e+10  3.866800e+10
# costAndExpenses                          2.568680e+11  2.082270e+11
# interestIncome                           2.843000e+09  3.763000e+09
# interestExpense                          2.645000e+09  2.873000e+09
# depreciationAndAmortization              1.128400e+10  1.105600e+10
# ebitda                                   1.231360e+11  8.102000e+10
# ebitdaratio                              3.366055e-01  2.951387e-01
# operatingIncome                          1.089490e+11  6.628800e+10
# operatingIncomeRatio                     2.978238e-01  2.414731e-01
# totalOtherIncomeExpensesNet              2.580000e+08  8.030000e+08
# incomeBeforeTax                          1.092070e+11  6.709100e+10
# incomeBeforeTaxRatio                     2.985290e-01  2.443983e-01
# incomeTaxExpense                         1.452700e+10  9.680000e+09
# netIncome                                9.468000e+10  5.741100e+10
# netIncomeRatio                           2.588179e-01  2.091361e-01
# eps                                      5.670000e+00  3.310000e+00
# epsdiluted                               5.610000e+00  3.280000e+00
# weightedAverageShsOut                    1.670127e+10  1.735212e+10
# weightedAverageShsOutDil                 1.686492e+10  1.752821e+10
#
# Category                                         2019          2018  \
# Date
# revenue                                  2.601740e+11  2.655950e+11
# costOfRevenue                            1.617820e+11  1.637560e+11
# grossProfit                              9.839200e+10  1.018390e+11
# grossProfitRatio                         3.781777e-01  3.834372e-01
# researchAndDevelopmentExpenses           1.621700e+10  1.423600e+10
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00
# sellingGeneralAndAdministrativeExpenses  1.824500e+10  1.670500e+10
# otherExpenses                            0.000000e+00  0.000000e+00
# operatingExpenses                        3.446200e+10  3.094100e+10
# costAndExpenses                          1.962440e+11  1.946970e+11
# interestIncome                           4.961000e+09  5.686000e+09
# interestExpense                          3.576000e+09  3.240000e+09
# depreciationAndAmortization              1.254700e+10  1.090300e+10
# ebitda                                   8.186000e+10  8.704600e+10
# ebitdaratio                              3.146356e-01  3.277396e-01
# operatingIncome                          6.393000e+10  7.089800e+10
# operatingIncomeRatio                     2.457202e-01  2.669403e-01
# totalOtherIncomeExpensesNet              1.807000e+09  2.005000e+09
# incomeBeforeTax                          6.573700e+10  7.290300e+10
# incomeBeforeTaxRatio                     2.526655e-01  2.744894e-01
# incomeTaxExpense                         1.048100e+10  1.337200e+10
# netIncome                                5.525600e+10  5.953100e+10
# netIncomeRatio                           2.123809e-01  2.241420e-01
# eps                                      2.992500e+00  3.002500e+00
# epsdiluted                               2.972500e+00  2.977500e+00
# weightedAverageShsOut                    1.847134e+10  1.982151e+10
# weightedAverageShsOutDil                 1.859565e+10  2.000044e+10
#
# Category                                         2017          2016  \
# Date
# revenue                                  2.292340e+11  2.156390e+11
# costOfRevenue                            1.410480e+11  1.313760e+11
# grossProfit                              8.818600e+10  8.426300e+10
# grossProfitRatio                         3.846986e-01  3.907596e-01
# researchAndDevelopmentExpenses           1.158100e+10  1.004500e+10
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00
# sellingGeneralAndAdministrativeExpenses  1.526100e+10  1.419400e+10
# otherExpenses                            0.000000e+00  0.000000e+00
# operatingExpenses                        2.684200e+10  2.423900e+10
# costAndExpenses                          1.678900e+11  1.556150e+11
# interestIncome                           5.201000e+09  3.999000e+09
# interestExpense                          2.323000e+09  1.456000e+09
# depreciationAndAmortization              1.015700e+10  1.050500e+10
# ebitda                                   7.656900e+10  7.333300e+10
# ebitdaratio                              3.340211e-01  3.400730e-01
# operatingIncome                          6.134400e+10  6.002400e+10
# operatingIncomeRatio                     2.676043e-01  2.783541e-01
# totalOtherIncomeExpensesNet              2.745000e+09  1.348000e+09
# incomeBeforeTax                          6.408900e+10  6.137200e+10
# incomeBeforeTaxRatio                     2.795789e-01  2.846053e-01
# incomeTaxExpense                         1.573800e+10  1.568500e+10
# netIncome                                4.835100e+10  4.568700e+10
# netIncomeRatio                           2.109242e-01  2.118680e-01
# eps                                      2.317500e+00  2.087500e+00
# epsdiluted                               2.302500e+00  2.077500e+00
# weightedAverageShsOut                    2.086897e+10  2.188328e+10
# weightedAverageShsOutDil                 2.100677e+10  2.200112e+10
#
# Category                                         2015          2014  \
# Date
# revenue                                  2.337150e+11  1.827950e+11
# costOfRevenue                            1.400890e+11  1.122580e+11
# grossProfit                              9.362600e+10  7.053700e+10
# grossProfitRatio                         4.005990e-01  3.858804e-01
# researchAndDevelopmentExpenses           8.067000e+09  6.041000e+09
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00
# sellingGeneralAndAdministrativeExpenses  1.432900e+10  1.199300e+10
# otherExpenses                            0.000000e+00  0.000000e+00
# operatingExpenses                        2.239600e+10  1.803400e+10
# costAndExpenses                          1.624850e+11  1.302920e+11
# interestIncome                           2.921000e+09  1.795000e+09
# interestExpense                          7.330000e+08  3.840000e+08
# depreciationAndAmortization              1.125700e+10  7.946000e+09
# ebitda                                   8.450500e+10  6.181300e+10
# ebitdaratio                              3.615729e-01  3.381548e-01
# operatingIncome                          7.123000e+10  5.250300e+10
# operatingIncomeRatio                     3.047729e-01  2.872234e-01
# totalOtherIncomeExpensesNet              1.285000e+09  9.800000e+08
# incomeBeforeTax                          7.251500e+10  5.348300e+10
# incomeBeforeTaxRatio                     3.102711e-01  2.925846e-01
# incomeTaxExpense                         1.912100e+10  1.397300e+10
# netIncome                                5.339400e+10  3.951000e+10
# netIncomeRatio                           2.284577e-01  2.161438e-01
# eps                                      2.320000e+00  1.622500e+00
# epsdiluted                               2.305000e+00  1.612500e+00
# weightedAverageShsOut                    2.301368e+10  2.434229e+10
# weightedAverageShsOutDil                 2.317228e+10  2.449065e+10
#
# Category                                         2013          2012  ...  \
# Date                                                                 ...
# revenue                                  1.709100e+11  1.565080e+11  ...
# costOfRevenue                            1.066060e+11  8.784600e+10  ...
# grossProfit                              6.430400e+10  6.866200e+10  ...
# grossProfitRatio                         3.762448e-01  4.387124e-01  ...
# researchAndDevelopmentExpenses           4.475000e+09  3.381000e+09  ...
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00  ...
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00  ...
# sellingGeneralAndAdministrativeExpenses  1.083000e+10  1.004000e+10  ...
# otherExpenses                            0.000000e+00  0.000000e+00  ...
# operatingExpenses                        1.530500e+10  1.342100e+10  ...
# costAndExpenses                          1.219110e+11  1.012670e+11  ...
# interestIncome                           1.616000e+09  1.088000e+09  ...
# interestExpense                          1.360000e+08  0.000000e+00  ...
# depreciationAndAmortization              6.757000e+09  3.277000e+09  ...
# ebitda                                   5.704800e+10  5.904000e+10  ...
# ebitdaratio                              3.337897e-01  3.772331e-01  ...
# operatingIncome                          4.899900e+10  5.524100e+10  ...
# operatingIncomeRatio                     2.866948e-01  3.529596e-01  ...
# totalOtherIncomeExpensesNet              1.156000e+09  5.220000e+08  ...
# incomeBeforeTax                          5.015500e+10  5.576300e+10  ...
# incomeBeforeTaxRatio                     2.934585e-01  3.562949e-01  ...
# incomeTaxExpense                         1.311800e+10  1.403000e+10  ...
# netIncome                                3.703700e+10  4.173300e+10  ...
# netIncomeRatio                           2.167047e-01  2.666509e-01  ...
# eps                                      1.429643e+00  1.594286e+00  ...
# epsdiluted                               1.419643e+00  1.576786e+00  ...
# weightedAverageShsOut                    2.590927e+10  2.617490e+10  ...
# weightedAverageShsOutDil                 2.608654e+10  2.646994e+10  ...
#
# Category                                         1994          1993  \
# Date
# revenue                                  9.188748e+09  7.977000e+09
# costOfRevenue                            6.844915e+09  5.082700e+09
# grossProfit                              2.343833e+09  2.894300e+09
# grossProfitRatio                         2.550764e-01  3.628306e-01
# researchAndDevelopmentExpenses           5.643030e+08  0.000000e+00
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00
# sellingGeneralAndAdministrativeExpenses  1.384111e+09  2.617800e+09
# otherExpenses                            0.000000e+00  1.661000e+08
# operatingExpenses                        1.948414e+09  2.783900e+09
# costAndExpenses                          8.793329e+09  7.866600e+09
# interestIncome                           4.328400e+07  0.000000e+00
# interestExpense                          3.965300e+07  0.000000e+00
# depreciationAndAmortization              1.679580e+08  1.661000e+08
# ebitda                                   7.078970e+08  3.058000e+08
# ebitdaratio                              7.703955e-02  3.833521e-02
# operatingIncome                          5.222740e+08  1.104000e+08
# operatingIncomeRatio                     5.683843e-02  1.383979e-02
# totalOtherIncomeExpensesNet             -2.198800e+07  2.930000e+07
# incomeBeforeTax                          5.002860e+08  1.397000e+08
# incomeBeforeTaxRatio                     5.444550e-02  1.751285e-02
# incomeTaxExpense                         1.901080e+08  5.310000e+07
# netIncome                                3.101780e+08  8.660000e+07
# netIncomeRatio                           3.375629e-02  1.085621e-02
# eps                                      2.330400e-02  6.607000e-03
# epsdiluted                               2.330400e-02  6.607000e-03
# weightedAverageShsOut                    1.329832e+10  1.310703e+10
# weightedAverageShsOutDil                 1.330672e+10  1.310703e+10
#
# Category                                         1992          1991  \
# Date
# revenue                                  7.086500e+09  6.308800e+09
# costOfRevenue                            3.774200e+09  3.109700e+09
# grossProfit                              3.312300e+09  3.199100e+09
# grossProfitRatio                         4.674099e-01  5.070853e-01
# researchAndDevelopmentExpenses           0.000000e+00  0.000000e+00
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00
# sellingGeneralAndAdministrativeExpenses  2.289400e+09  2.547400e+09
# otherExpenses                            2.172000e+08  2.044000e+08
# operatingExpenses                        2.506600e+09  2.751800e+09
# costAndExpenses                          6.280800e+09  5.861500e+09
# interestIncome                           0.000000e+00  0.000000e+00
# interestExpense                          0.000000e+00  0.000000e+00
# depreciationAndAmortization              2.172000e+08  2.044000e+08
# ebitda                                   1.072700e+09  7.041000e+08
# ebitdaratio                              1.513723e-01  1.116060e-01
# operatingIncome                          8.057000e+08  4.473000e+08
# operatingIncomeRatio                     1.136951e-01  7.090096e-02
# totalOtherIncomeExpensesNet              4.980000e+07  5.240000e+07
# incomeBeforeTax                          8.555000e+08  4.997000e+08
# incomeBeforeTaxRatio                     1.207225e-01  7.920682e-02
# incomeTaxExpense                         3.251000e+08  1.899000e+08
# netIncome                                5.304000e+08  3.098000e+08
# netIncomeRatio                           7.484654e-02  4.910601e-02
# eps                                      3.875000e-02  2.303600e-02
# epsdiluted                               3.875000e-02  2.303600e-02
# weightedAverageShsOut                    1.368774e+10  1.344868e+10
# weightedAverageShsOutDil                 1.368774e+10  1.344868e+10
#
# Category                                         1990          1989  \
# Date
# revenue                                  5.558400e+09  5.284000e+09
# costOfRevenue                            2.403500e+09  2.570000e+09
# grossProfit                              3.154900e+09  2.714000e+09
# grossProfitRatio                         5.675914e-01  5.136260e-01
# researchAndDevelopmentExpenses           0.000000e+00  0.000000e+00
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00
# sellingGeneralAndAdministrativeExpenses  2.240200e+09  1.954900e+09
# otherExpenses                            2.027000e+08  1.248000e+08
# operatingExpenses                        2.442900e+09  2.079700e+09
# costAndExpenses                          4.846400e+09  4.649700e+09
# interestIncome                           0.000000e+00  0.000000e+00
# interestExpense                          0.000000e+00  0.000000e+00
# depreciationAndAmortization              2.027000e+08  1.248000e+08
# ebitda                                   9.812000e+08  8.691000e+08
# ebitdaratio                              1.765256e-01  1.644777e-01
# operatingIncome                          7.120000e+08  6.343000e+08
# operatingIncomeRatio                     1.280944e-01  1.200416e-01
# totalOtherIncomeExpensesNet              6.650000e+07  1.100000e+08
# incomeBeforeTax                          7.785000e+08  7.443000e+08
# incomeBeforeTaxRatio                     1.400583e-01  1.408592e-01
# incomeTaxExpense                         3.036000e+08  2.903000e+08
# netIncome                                4.749000e+08  4.540000e+08
# netIncomeRatio                           8.543826e-02  8.591976e-02
# eps                                      3.375000e-02  3.160700e-02
# epsdiluted                               3.375000e-02  3.160700e-02
# weightedAverageShsOut                    1.407111e+10  1.436384e+10
# weightedAverageShsOutDil                 1.407111e+10  1.436384e+10
#
# Category                                         1988          1987  \
# Date
# revenue                                  4.071400e+09  2.661100e+09
# costOfRevenue                            1.913200e+09  1.225700e+09
# grossProfit                              2.158200e+09  1.435400e+09
# grossProfitRatio                         5.300879e-01  5.394010e-01
# researchAndDevelopmentExpenses           0.000000e+00  0.000000e+00
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00
# sellingGeneralAndAdministrativeExpenses  1.460200e+09  9.934000e+08
# otherExpenses                            7.770000e+07  7.050000e+07
# operatingExpenses                        1.537900e+09  1.063900e+09
# costAndExpenses                          3.451100e+09  2.289600e+09
# interestIncome                           0.000000e+00  0.000000e+00
# interestExpense                          0.000000e+00  0.000000e+00
# depreciationAndAmortization              7.770000e+07  7.050000e+07
# ebitda                                   7.339000e+08  4.809000e+08
# ebitdaratio                              1.802574e-01  1.807147e-01
# operatingIncome                          6.203000e+08  3.715000e+08
# operatingIncomeRatio                     1.523555e-01  1.396039e-01
# totalOtherIncomeExpensesNet              3.590000e+07  3.890000e+07
# incomeBeforeTax                          6.562000e+08  4.104000e+08
# incomeBeforeTaxRatio                     1.611731e-01  1.542219e-01
# incomeTaxExpense                         2.559000e+08  1.929000e+08
# netIncome                                4.003000e+08  2.175000e+08
# netIncomeRatio                           9.831999e-02  8.173312e-02
# eps                                      2.750000e-02  1.482100e-02
# epsdiluted                               2.750000e-02  1.482100e-02
# weightedAverageShsOut                    1.455636e+10  1.467470e+10
# weightedAverageShsOutDil                 1.455636e+10  1.467470e+10
#
# Category                                         1986          1985
# Date
# revenue                                  1.901900e+09  1.918300e+09
# costOfRevenue                            8.400000e+08  1.076000e+09
# grossProfit                              1.061900e+09  8.423000e+08
# grossProfitRatio                         5.583364e-01  4.390867e-01
# researchAndDevelopmentExpenses           0.000000e+00  0.000000e+00
# generalAndAdministrativeExpenses         0.000000e+00  0.000000e+00
# sellingAndMarketingExpenses              0.000000e+00  0.000000e+00
# sellingGeneralAndAdministrativeExpenses  7.373000e+08  6.532000e+08
# otherExpenses                            5.110000e+07  4.180000e+07
# operatingExpenses                        7.884000e+08  6.950000e+08
# costAndExpenses                          1.628400e+09  1.771000e+09
# interestIncome                           0.000000e+00  0.000000e+00
# interestExpense                          0.000000e+00  0.000000e+00
# depreciationAndAmortization              5.110000e+07  4.180000e+07
# ebitda                                   3.609000e+08  1.618000e+08
# ebitdaratio                              1.897576e-01  8.434551e-02
# operatingIncome                          2.735000e+08  1.473000e+08
# operatingIncomeRatio                     1.438036e-01  7.678674e-02
# totalOtherIncomeExpensesNet              3.630000e+07 -2.730000e+07
# incomeBeforeTax                          3.098000e+08  1.200000e+08
# incomeBeforeTaxRatio                     1.628897e-01  6.255539e-02
# incomeTaxExpense                         1.558000e+08  5.880000e+07
# netIncome                                1.540000e+08  6.120000e+07
# netIncomeRatio                           8.097166e-02  3.190325e-02
# eps                                      1.071400e-02  4.464000e-03
# epsdiluted                               1.071400e-02  4.464000e-03
# weightedAverageShsOut                    1.437333e+10  1.370880e+10
# weightedAverageShsOutDil                 1.437333e+10  1.370880e+10
#
# [28 rows x 37 columns]

# %% [markdown]
# This is a more business oriented way of seeing this DataFrame. In fact, what analysts tend to do is checking year over year (Yoy) the progression of a company.

# %% [markdown]
# Here is an example of what an **Income Statement** looks like when introducing the result of a company.

# %% [markdown]
# ![Screenshot%202022-09-02%20at%2018.49.18.png](attachment:Screenshot%202022-09-02%20at%2018.49.18.png)

# %% [markdown]
# ## Financial Statements: balance sheets

# %% [markdown]
# **Balance sheets determine risk**. This financial statement lists everything a company owns and all of its debt. A company will be able to quickly assess whether it has borrowed too much money, whether the assets it owns are not liquid enough, or whether it has enough cash on hand to meet current demands.

# %% [markdown]
# If you want to learn more about balance sheets, here is a link: https://www.investopedia.com/terms/b/balancesheet.asp#toc-importance-of-a-balance-sheet

# %% [markdown]
# ### Key facts about the balance sheets

# %% [markdown]
# - A balance sheet is a financial statement that reports a **company's assets, liabilities, and shareholder equity**.
# - The balance sheet is **one of the three core financial statements** that are used to evaluate a business.
# - It provides a **snapshot of a company's finances (what it owns and owes)** as of the date of publication.
# - The balance sheet adheres to an **equation that equates assets with the sum of liabilities and shareholder equity**.
# - Fundamental analysts use balance sheets to **calculate financial ratios**.

# %% [markdown]
# ### Exploration of balance sheets

# %% [markdown]
# Juste like previous, we are going to explore what's inside a balance sheet statement.

# %%
# We do our API call from FMP on balance sheets
url2='https://financialmodelingprep.com/api/v3/balance-sheet-statement/AAPL?limit=120&apikey='+key

# We do our call using requests and use the json method to get the right format.
# ybs stands for yearly income statement
ybs=requests.get(url2).json()

# %% [markdown]
# We know that json returns a list of dictionnary that contains all the key elements.
#
# In finance, most data is organised by date so it's easy to tell that our balance sheets will be organised year by year.

# %%
# Let's extract the first element of our json
print(ybs[0])
# Out:
# {'date': '2021-09-25', 'symbol': 'AAPL', 'reportedCurrency': 'USD', 'cik': '0000320193', 'fillingDate': '2021-10-29', 'acceptedDate': '2021-10-28 18:04:28', 'calendarYear': '2021', 'period': 'FY', 'cashAndCashEquivalents': 34940000000, 'shortTermInvestments': 27699000000, 'cashAndShortTermInvestments': 62639000000, 'netReceivables': 51506000000, 'inventory': 6580000000, 'otherCurrentAssets': 14111000000, 'totalCurrentAssets': 134836000000, 'propertyPlantEquipmentNet': 39440000000, 'goodwill': 0.0, 'intangibleAssets': 0.0, 'goodwillAndIntangibleAssets': 0.0, 'longTermInvestments': 127877000000, 'taxAssets': 0.0, 'otherNonCurrentAssets': 48849000000, 'totalNonCurrentAssets': 216166000000, 'otherAssets': 0.0, 'totalAssets': 351002000000, 'accountPayables': 54763000000, 'shortTermDebt': 15613000000, 'taxPayables': 0.0, 'deferredRevenue': 7612000000, 'otherCurrentLiabilities': 47493000000, 'totalCurrentLiabilities': 125481000000, 'longTermDebt': 109106000000, 'deferredRevenueNonCurrent': 0.0, 'deferredTaxLiabilitiesNonCurrent': 0.0, 'otherNonCurrentLiabilities': 53325000000, 'totalNonCurrentLiabilities': 162431000000, 'otherLiabilities': 0.0, 'capitalLeaseObligations': 0.0, 'totalLiabilities': 287912000000, 'preferredStock': 0.0, 'commonStock': 57365000000, 'retainedEarnings': 5562000000, 'accumulatedOtherComprehensiveIncomeLoss': 163000000, 'othertotalStockholdersEquity': 0.0, 'totalStockholdersEquity': 63090000000, 'totalLiabilitiesAndStockholdersEquity': 351002000000, 'minorityInterest': 0, 'totalEquity': 63090000000, 'totalLiabilitiesAndTotalEquity': 351002000000, 'totalInvestments': 155576000000, 'totalDebt': 124719000000, 'netDebt': 89779000000, 'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/0000320193-21-000105-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/aapl-20210925.htm'}

# %% [markdown]
# Just like previously, let's turn our json into a DataFrame.

# %%
ybs = pd.DataFrame(ybs)

# %% [markdown]
# Let's explore what's inside of our balance sheet call.

# %%
ybs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 54 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   date                                     37 non-null     object
#  1   symbol                                   37 non-null     object
#  2   reportedCurrency                         37 non-null     object
#  3   cik                                      37 non-null     object
#  4   fillingDate                              37 non-null     object
#  5   acceptedDate                             37 non-null     object
#  6   calendarYear                             37 non-null     object
#  7   period                                   37 non-null     object
#  8   cashAndCashEquivalents                   37 non-null     int64
#  9   shortTermInvestments                     37 non-null     float64
#  10  cashAndShortTermInvestments              37 non-null     int64
#  11  netReceivables                           37 non-null     int64
#  12  inventory                                37 non-null     int64
#  13  otherCurrentAssets                       37 non-null     int64
#  14  totalCurrentAssets                       37 non-null     int64
#  15  propertyPlantEquipmentNet                37 non-null     int64
#  16  goodwill                                 37 non-null     float64
#  17  intangibleAssets                         37 non-null     float64
#  18  goodwillAndIntangibleAssets              37 non-null     float64
#  19  longTermInvestments                      37 non-null     float64
#  20  taxAssets                                37 non-null     float64
#  21  otherNonCurrentAssets                    37 non-null     int64
#  22  totalNonCurrentAssets                    37 non-null     int64
#  23  otherAssets                              37 non-null     float64
#  24  totalAssets                              37 non-null     int64
#  25  accountPayables                          37 non-null     float64
#  26  shortTermDebt                            37 non-null     float64
#  27  taxPayables                              37 non-null     float64
#  28  deferredRevenue                          37 non-null     float64
#  29  otherCurrentLiabilities                  37 non-null     int64
#  30  totalCurrentLiabilities                  37 non-null     int64
#  31  longTermDebt                             37 non-null     float64
#  32  deferredRevenueNonCurrent                37 non-null     float64
#  33  deferredTaxLiabilitiesNonCurrent         37 non-null     float64
#  34  otherNonCurrentLiabilities               37 non-null     float64
#  35  totalNonCurrentLiabilities               37 non-null     int64
#  36  otherLiabilities                         37 non-null     float64
#  37  capitalLeaseObligations                  37 non-null     float64
#  38  totalLiabilities                         37 non-null     int64
#  39  preferredStock                           37 non-null     float64
#  40  commonStock                              37 non-null     float64
#  41  retainedEarnings                         37 non-null     int64
#  42  accumulatedOtherComprehensiveIncomeLoss  37 non-null     float64
#  43  othertotalStockholdersEquity             37 non-null     float64
#  44  totalStockholdersEquity                  37 non-null     int64
#  45  totalLiabilitiesAndStockholdersEquity    37 non-null     int64
#  46  minorityInterest                         37 non-null     int64
#  47  totalEquity                              37 non-null     int64
#  48  totalLiabilitiesAndTotalEquity           37 non-null     int64
#  49  totalInvestments                         37 non-null     float64
#  50  totalDebt                                37 non-null     float64
#  51  netDebt                                  37 non-null     float64
#  52  link                                     37 non-null     object
#  53  finalLink                                37 non-null     object
# dtypes: float64(24), int64(20), object(10)
# memory usage: 15.7+ KB

# %% [markdown]
# As we can see, it's quite complete.
#
# We won't go into details in this one as this notebook is for exploration mainly.
#
# Now, let's observe this Pandas dataframe first rows.

# %%
# Let's call the 5 first rows of our pandas dataframe
ybs.head()
# Out:
#          date symbol reportedCurrency         cik fillingDate  \
# 0  2021-09-25   AAPL              USD  0000320193  2021-10-29
# 1  2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2  2019-09-28   AAPL              USD  0000320193  2019-10-31
# 3  2018-09-29   AAPL              USD  0000320193  2018-11-05
# 4  2017-09-30   AAPL              USD  0000320193  2017-11-03
#
#           acceptedDate calendarYear period  cashAndCashEquivalents  \
# 0  2021-10-28 18:04:28         2021     FY             34940000000
# 1  2020-10-29 18:06:25         2020     FY             38016000000
# 2  2019-10-30 18:12:36         2019     FY             48844000000
# 3  2018-11-05 08:01:40         2018     FY             25913000000
# 4  2017-11-03 08:01:37         2017     FY             20289000000
#
#    shortTermInvestments  ...  totalStockholdersEquity  \
# 0          2.769900e+10  ...              63090000000
# 1          5.292700e+10  ...              65339000000
# 2          5.171300e+10  ...              90488000000
# 3          4.038800e+10  ...             107147000000
# 4          5.389200e+10  ...             134047000000
#
#    totalLiabilitiesAndStockholdersEquity  minorityInterest   totalEquity  \
# 0                           351002000000                 0   63090000000
# 1                           323888000000                 0   65339000000
# 2                           338516000000                 0   90488000000
# 3                           365725000000                 0  107147000000
# 4                           375319000000                 0  134047000000
#
#    totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# 0                    351002000000      1.555760e+11  1.247190e+11
# 1                    323888000000      1.538140e+11  1.124360e+11
# 2                    338516000000      1.570540e+11  1.080470e+11
# 3                    365725000000      2.111870e+11  1.144830e+11
# 4                    375319000000      2.486060e+11  1.156800e+11
#
#         netDebt                                               link  \
# 0  8.977900e+10  https://www.sec.gov/Archives/edgar/data/320193...
# 1  7.442000e+10  https://www.sec.gov/Archives/edgar/data/320193...
# 2  5.920300e+10  https://www.sec.gov/Archives/edgar/data/320193...
# 3  8.857000e+10  https://www.sec.gov/Archives/edgar/data/320193...
# 4  9.539100e+10  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                            finalLink
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 54 columns]

# %% [markdown]
# Just like previously, let's set index to calendar year

# %%
# We change the index to years.
ybs.set_index('calendarYear', inplace=True)
ybs.head()
# Out:
#                     date symbol reportedCurrency         cik fillingDate  \
# calendarYear
# 2021          2021-09-25   AAPL              USD  0000320193  2021-10-29
# 2020          2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2019          2019-09-28   AAPL              USD  0000320193  2019-10-31
# 2018          2018-09-29   AAPL              USD  0000320193  2018-11-05
# 2017          2017-09-30   AAPL              USD  0000320193  2017-11-03
#
#                      acceptedDate period  cashAndCashEquivalents  \
# calendarYear
# 2021          2021-10-28 18:04:28     FY             34940000000
# 2020          2020-10-29 18:06:25     FY             38016000000
# 2019          2019-10-30 18:12:36     FY             48844000000
# 2018          2018-11-05 08:01:40     FY             25913000000
# 2017          2017-11-03 08:01:37     FY             20289000000
#
#               shortTermInvestments  cashAndShortTermInvestments  ...  \
# calendarYear                                                     ...
# 2021                  2.769900e+10                  62639000000  ...
# 2020                  5.292700e+10                  90943000000  ...
# 2019                  5.171300e+10                 100557000000  ...
# 2018                  4.038800e+10                  66301000000  ...
# 2017                  5.389200e+10                  74181000000  ...
#
#               totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# calendarYear
# 2021                      63090000000                           351002000000
# 2020                      65339000000                           323888000000
# 2019                      90488000000                           338516000000
# 2018                     107147000000                           365725000000
# 2017                     134047000000                           375319000000
#
#               minorityInterest   totalEquity  totalLiabilitiesAndTotalEquity  \
# calendarYear
# 2021                         0   63090000000                    351002000000
# 2020                         0   65339000000                    323888000000
# 2019                         0   90488000000                    338516000000
# 2018                         0  107147000000                    365725000000
# 2017                         0  134047000000                    375319000000
#
#               totalInvestments     totalDebt       netDebt  \
# calendarYear
# 2021              1.555760e+11  1.247190e+11  8.977900e+10
# 2020              1.538140e+11  1.124360e+11  7.442000e+10
# 2019              1.570540e+11  1.080470e+11  5.920300e+10
# 2018              2.111870e+11  1.144830e+11  8.857000e+10
# 2017              2.486060e+11  1.156800e+11  9.539100e+10
#
#                                                            link  \
# calendarYear
# 2021          https://www.sec.gov/Archives/edgar/data/320193...
# 2020          https://www.sec.gov/Archives/edgar/data/320193...
# 2019          https://www.sec.gov/Archives/edgar/data/320193...
# 2018          https://www.sec.gov/Archives/edgar/data/320193...
# 2017          https://www.sec.gov/Archives/edgar/data/320193...
#
#                                                       finalLink
# calendarYear
# 2021          https://www.sec.gov/Archives/edgar/data/320193...
# 2020          https://www.sec.gov/Archives/edgar/data/320193...
# 2019          https://www.sec.gov/Archives/edgar/data/320193...
# 2018          https://www.sec.gov/Archives/edgar/data/320193...
# 2017          https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 53 columns]

# %%
# Let's set the index as year in a definitive way and reorder the years
# ybs.set_index('calendarYear', inplace=True)
ybs.sort_index().tail()
# Out:
#                     date symbol reportedCurrency         cik fillingDate  \
# calendarYear
# 2017          2017-09-30   AAPL              USD  0000320193  2017-11-03
# 2018          2018-09-29   AAPL              USD  0000320193  2018-11-05
# 2019          2019-09-28   AAPL              USD  0000320193  2019-10-31
# 2020          2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2021          2021-09-25   AAPL              USD  0000320193  2021-10-29
#
#                      acceptedDate period  cashAndCashEquivalents  \
# calendarYear
# 2017          2017-11-03 08:01:37     FY             20289000000
# 2018          2018-11-05 08:01:40     FY             25913000000
# 2019          2019-10-30 18:12:36     FY             48844000000
# 2020          2020-10-29 18:06:25     FY             38016000000
# 2021          2021-10-28 18:04:28     FY             34940000000
#
#               shortTermInvestments  cashAndShortTermInvestments  ...  \
# calendarYear                                                     ...
# 2017                  5.389200e+10                  74181000000  ...
# 2018                  4.038800e+10                  66301000000  ...
# 2019                  5.171300e+10                 100557000000  ...
# 2020                  5.292700e+10                  90943000000  ...
# 2021                  2.769900e+10                  62639000000  ...
#
#               totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# calendarYear
# 2017                     134047000000                           375319000000
# 2018                     107147000000                           365725000000
# 2019                      90488000000                           338516000000
# 2020                      65339000000                           323888000000
# 2021                      63090000000                           351002000000
#
#               minorityInterest   totalEquity  totalLiabilitiesAndTotalEquity  \
# calendarYear
# 2017                         0  134047000000                    375319000000
# 2018                         0  107147000000                    365725000000
# 2019                         0   90488000000                    338516000000
# 2020                         0   65339000000                    323888000000
# 2021                         0   63090000000                    351002000000
#
#               totalInvestments     totalDebt       netDebt  \
# calendarYear
# 2017              2.486060e+11  1.156800e+11  9.539100e+10
# 2018              2.111870e+11  1.144830e+11  8.857000e+10
# 2019              1.570540e+11  1.080470e+11  5.920300e+10
# 2020              1.538140e+11  1.124360e+11  7.442000e+10
# 2021              1.555760e+11  1.247190e+11  8.977900e+10
#
#                                                            link  \
# calendarYear
# 2017          https://www.sec.gov/Archives/edgar/data/320193...
# 2018          https://www.sec.gov/Archives/edgar/data/320193...
# 2019          https://www.sec.gov/Archives/edgar/data/320193...
# 2020          https://www.sec.gov/Archives/edgar/data/320193...
# 2021          https://www.sec.gov/Archives/edgar/data/320193...
#
#                                                       finalLink
# calendarYear
# 2017          https://www.sec.gov/Archives/edgar/data/320193...
# 2018          https://www.sec.gov/Archives/edgar/data/320193...
# 2019          https://www.sec.gov/Archives/edgar/data/320193...
# 2020          https://www.sec.gov/Archives/edgar/data/320193...
# 2021          https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 53 columns]

# %% [markdown]
# We are going to rename the index from "calendar Year" to "Date" in order to have our data frame more readable.

# %%
# We change the index name of our Data Frame
ybs.index.names = ['Date']

# We are inspecting if these changes have been taken into account
ybs.head()
# Out:
#             date symbol reportedCurrency         cik fillingDate  \
# Date
# 2021  2021-09-25   AAPL              USD  0000320193  2021-10-29
# 2020  2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2019  2019-09-28   AAPL              USD  0000320193  2019-10-31
# 2018  2018-09-29   AAPL              USD  0000320193  2018-11-05
# 2017  2017-09-30   AAPL              USD  0000320193  2017-11-03
#
#              acceptedDate period  cashAndCashEquivalents  \
# Date
# 2021  2021-10-28 18:04:28     FY             34940000000
# 2020  2020-10-29 18:06:25     FY             38016000000
# 2019  2019-10-30 18:12:36     FY             48844000000
# 2018  2018-11-05 08:01:40     FY             25913000000
# 2017  2017-11-03 08:01:37     FY             20289000000
#
#       shortTermInvestments  cashAndShortTermInvestments  ...  \
# Date                                                     ...
# 2021          2.769900e+10                  62639000000  ...
# 2020          5.292700e+10                  90943000000  ...
# 2019          5.171300e+10                 100557000000  ...
# 2018          4.038800e+10                  66301000000  ...
# 2017          5.389200e+10                  74181000000  ...
#
#       totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# Date
# 2021              63090000000                           351002000000
# 2020              65339000000                           323888000000
# 2019              90488000000                           338516000000
# 2018             107147000000                           365725000000
# 2017             134047000000                           375319000000
#
#       minorityInterest   totalEquity  totalLiabilitiesAndTotalEquity  \
# Date
# 2021                 0   63090000000                    351002000000
# 2020                 0   65339000000                    323888000000
# 2019                 0   90488000000                    338516000000
# 2018                 0  107147000000                    365725000000
# 2017                 0  134047000000                    375319000000
#
#       totalInvestments     totalDebt       netDebt  \
# Date
# 2021      1.555760e+11  1.247190e+11  8.977900e+10
# 2020      1.538140e+11  1.124360e+11  7.442000e+10
# 2019      1.570540e+11  1.080470e+11  5.920300e+10
# 2018      2.111870e+11  1.144830e+11  8.857000e+10
# 2017      2.486060e+11  1.156800e+11  9.539100e+10
#
#                                                    link  \
# Date
# 2021  https://www.sec.gov/Archives/edgar/data/320193...
# 2020  https://www.sec.gov/Archives/edgar/data/320193...
# 2019  https://www.sec.gov/Archives/edgar/data/320193...
# 2018  https://www.sec.gov/Archives/edgar/data/320193...
# 2017  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                               finalLink
# Date
# 2021  https://www.sec.gov/Archives/edgar/data/320193...
# 2020  https://www.sec.gov/Archives/edgar/data/320193...
# 2019  https://www.sec.gov/Archives/edgar/data/320193...
# 2018  https://www.sec.gov/Archives/edgar/data/320193...
# 2017  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 53 columns]

# %% [markdown]
# Just like previously, let's remove some columns we actually don't need which will include:
# - symbol,
# - reportedCurrency,
# - cik,
# - fillingDate,
# - acceptedDate,
# - period (we already know it's a full year),
# - link,
# - finalLink.

# %%
# We use our drop method from pandas to remove some columns
ybs.drop(['date', 'symbol', 'reportedCurrency', 'cik', 'fillingDate', 'acceptedDate', 'period', 'link', 'finalLink'], axis='columns', inplace=True)

# %%
# Let's inspect our Data Frame
ybs.head()
# Out:
#       cashAndCashEquivalents  shortTermInvestments  \
# Date
# 2021             34940000000          2.769900e+10
# 2020             38016000000          5.292700e+10
# 2019             48844000000          5.171300e+10
# 2018             25913000000          4.038800e+10
# 2017             20289000000          5.389200e+10
#
#       cashAndShortTermInvestments  netReceivables   inventory  \
# Date
# 2021                  62639000000     51506000000  6580000000
# 2020                  90943000000     37445000000  4061000000
# 2019                 100557000000     45804000000  4106000000
# 2018                  66301000000     48995000000  3956000000
# 2017                  74181000000     35673000000  4855000000
#
#       otherCurrentAssets  totalCurrentAssets  propertyPlantEquipmentNet  \
# Date
# 2021         14111000000        134836000000                39440000000
# 2020         11264000000        143713000000                36766000000
# 2019         12352000000        162819000000                37378000000
# 2018         12087000000        131339000000                41304000000
# 2017         13936000000        128645000000                33783000000
#
#           goodwill  intangibleAssets  ...  \
# Date                                  ...
# 2021  0.000000e+00      0.000000e+00  ...
# 2020  0.000000e+00      0.000000e+00  ...
# 2019  0.000000e+00      0.000000e+00  ...
# 2018  0.000000e+00      0.000000e+00  ...
# 2017  5.717000e+09      2.298000e+09  ...
#
#       accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# Date
# 2021                             1.630000e+08                           0.0
# 2020                            -4.060000e+08                           0.0
# 2019                            -5.840000e+08                           0.0
# 2018                            -3.454000e+09                           0.0
# 2017                            -1.500000e+08                           0.0
#
#       totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# Date
# 2021              63090000000                           351002000000
# 2020              65339000000                           323888000000
# 2019              90488000000                           338516000000
# 2018             107147000000                           365725000000
# 2017             134047000000                           375319000000
#
#       minorityInterest   totalEquity  totalLiabilitiesAndTotalEquity  \
# Date
# 2021                 0   63090000000                    351002000000
# 2020                 0   65339000000                    323888000000
# 2019                 0   90488000000                    338516000000
# 2018                 0  107147000000                    365725000000
# 2017                 0  134047000000                    375319000000
#
#       totalInvestments     totalDebt       netDebt
# Date
# 2021      1.555760e+11  1.247190e+11  8.977900e+10
# 2020      1.538140e+11  1.124360e+11  7.442000e+10
# 2019      1.570540e+11  1.080470e+11  5.920300e+10
# 2018      2.111870e+11  1.144830e+11  8.857000e+10
# 2017      2.486060e+11  1.156800e+11  9.539100e+10
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Normal vs. Transposed version of Balance Sheets: when to use each one of them

# %% [markdown]
# Both views can be quite useful for the type of analysis you try to perform. However, it's wise to understand which one is mostly adapted.
#
# Here is a good way to separate both views.
#
# Use **Normal** view when:
# - computing ratios,
# - slicing through data,
# - data analysis,
# - plotting timeseries of result.
#
# Use **Transposed** view when:
# - summing up result,
# - show in a more traditional way.

# %% [markdown]
# #### Transposed version of yearly balance sheets

# %% [markdown]
# We will transpose the balance sheets using the transpose method for dataframe. However, before doing that, we will first slice into our data to get only the last ten years of results.
#
# We could perform that using the head method. But for the sake of this exercise, we'll use **the loc method** that allows to call "visible" elements in our dataframe, instead of counting every single index.

# %%
# Slicing from 2021 up to 2011 using the loc function
ybs10 = ybs.loc['2021':'2011',:]

# Inspecting our slice
ybs10
# Out:
#       cashAndCashEquivalents  shortTermInvestments  \
# Date
# 2021             34940000000          2.769900e+10
# 2020             38016000000          5.292700e+10
# 2019             48844000000          5.171300e+10
# 2018             25913000000          4.038800e+10
# 2017             20289000000          5.389200e+10
# 2016             20484000000          4.667100e+10
# 2015             21120000000          2.048100e+10
# 2014             13844000000          1.123300e+10
# 2013             14259000000          2.628700e+10
# 2012             10746000000          1.838300e+10
# 2011              9815000000          1.613700e+10
#
#       cashAndShortTermInvestments  netReceivables   inventory  \
# Date
# 2021                  62639000000     51506000000  6580000000
# 2020                  90943000000     37445000000  4061000000
# 2019                 100557000000     45804000000  4106000000
# 2018                  66301000000     48995000000  3956000000
# 2017                  74181000000     35673000000  4855000000
# 2016                  67155000000     29299000000  2132000000
# 2015                  41601000000     30343000000  2349000000
# 2014                  25077000000     27219000000  2111000000
# 2013                  40546000000     20641000000  1764000000
# 2012                  29129000000     18692000000   791000000
# 2011                  25952000000     11717000000   776000000
#
#       otherCurrentAssets  totalCurrentAssets  propertyPlantEquipmentNet  \
# Date
# 2021         14111000000        134836000000                39440000000
# 2020         11264000000        143713000000                36766000000
# 2019         12352000000        162819000000                37378000000
# 2018         12087000000        131339000000                41304000000
# 2017         13936000000        128645000000                33783000000
# 2016          8283000000        106869000000                27010000000
# 2015         15085000000         89378000000                22471000000
# 2014         14124000000         68531000000                20624000000
# 2013         10335000000         73286000000                16597000000
# 2012          9041000000         57653000000                15452000000
# 2011          6543000000         44988000000                 7777000000
#
#           goodwill  intangibleAssets  ...  \
# Date                                  ...
# 2021  0.000000e+00      0.000000e+00  ...
# 2020  0.000000e+00      0.000000e+00  ...
# 2019  0.000000e+00      0.000000e+00  ...
# 2018  0.000000e+00      0.000000e+00  ...
# 2017  5.717000e+09      2.298000e+09  ...
# 2016  5.414000e+09      3.206000e+09  ...
# 2015  5.116000e+09      3.893000e+09  ...
# 2014  4.616000e+09      4.142000e+09  ...
# 2013  1.577000e+09      4.179000e+09  ...
# 2012  1.135000e+09      4.224000e+09  ...
# 2011  8.960000e+08      3.536000e+09  ...
#
#       accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# Date
# 2021                             1.630000e+08                           0.0
# 2020                            -4.060000e+08                           0.0
# 2019                            -5.840000e+08                           0.0
# 2018                            -3.454000e+09                           0.0
# 2017                            -1.500000e+08                           0.0
# 2016                             6.340000e+08                           0.0
# 2015                            -3.450000e+08                           0.0
# 2014                             1.082000e+09                           0.0
# 2013                            -4.710000e+08                           0.0
# 2012                             4.990000e+08                           0.0
# 2011                             4.430000e+08                           0.0
#
#       totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# Date
# 2021              63090000000                           351002000000
# 2020              65339000000                           323888000000
# 2019              90488000000                           338516000000
# 2018             107147000000                           365725000000
# 2017             134047000000                           375319000000
# 2016             128249000000                           321686000000
# 2015             119355000000                           290479000000
# 2014             111547000000                           231839000000
# 2013             123549000000                           207000000000
# 2012             118210000000                           176064000000
# 2011              76615000000                           116371000000
#
#       minorityInterest   totalEquity  totalLiabilitiesAndTotalEquity  \
# Date
# 2021                 0   63090000000                    351002000000
# 2020                 0   65339000000                    323888000000
# 2019                 0   90488000000                    338516000000
# 2018                 0  107147000000                    365725000000
# 2017                 0  134047000000                    375319000000
# 2016                 0  128249000000                    321686000000
# 2015                 0  119355000000                    290479000000
# 2014                 0  111547000000                    231839000000
# 2013                 0  123549000000                    207000000000
# 2012                 0  118210000000                    176064000000
# 2011                 0   76615000000                    116371000000
#
#       totalInvestments     totalDebt       netDebt
# Date
# 2021      1.555760e+11  1.247190e+11  8.977900e+10
# 2020      1.538140e+11  1.124360e+11  7.442000e+10
# 2019      1.570540e+11  1.080470e+11  5.920300e+10
# 2018      2.111870e+11  1.144830e+11  8.857000e+10
# 2017      2.486060e+11  1.156800e+11  9.539100e+10
# 2016      2.171010e+11  8.703200e+10  6.654800e+10
# 2015      1.845460e+11  6.446200e+10  4.334200e+10
# 2014      1.413950e+11  3.529500e+10  2.145100e+10
# 2013      1.325020e+11  1.696000e+10  2.701000e+09
# 2012      1.105050e+11  0.000000e+00 -1.074600e+10
# 2011      7.175500e+10  0.000000e+00 -9.815000e+09
#
# [11 rows x 44 columns]

# %%
# We'll call it yearly balance sheets transposed or ybst
ybst = ybs10.transpose()

# %%
# Using the info method to check up whether the changes have been correctly made
ybst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, cashAndCashEquivalents to netDebt
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2021    44 non-null     float64
#  1   2020    44 non-null     float64
#  2   2019    44 non-null     float64
#  3   2018    44 non-null     float64
#  4   2017    44 non-null     float64
#  5   2016    44 non-null     float64
#  6   2015    44 non-null     float64
#  7   2014    44 non-null     float64
#  8   2013    44 non-null     float64
#  9   2012    44 non-null     float64
#  10  2011    44 non-null     float64
# dtypes: float64(11)
# memory usage: 5.2+ KB

# %% [markdown]
# We can attest that the number of rows and columns have remained the same.

# %% [markdown]
# ### Performing accounting operations: ratios

# %% [markdown]
# The power of having financial statements is that we can perform financial ratios that provides key input about the health of the company. This type of analysis is referred as fundamentals as it try to grasp company's performance not on stock market data, but purely on what is happening inside the company.
#
# We will compute the current ratio as an example.

# %%
# Let's quickly recall our Balance Sheets
ybs10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 2021 to 2011
# Data columns (total 44 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   cashAndCashEquivalents                   11 non-null     int64
#  1   shortTermInvestments                     11 non-null     float64
#  2   cashAndShortTermInvestments              11 non-null     int64
#  3   netReceivables                           11 non-null     int64
#  4   inventory                                11 non-null     int64
#  5   otherCurrentAssets                       11 non-null     int64
#  6   totalCurrentAssets                       11 non-null     int64
#  7   propertyPlantEquipmentNet                11 non-null     int64
#  8   goodwill                                 11 non-null     float64
#  9   intangibleAssets                         11 non-null     float64
#  10  goodwillAndIntangibleAssets              11 non-null     float64
#  11  longTermInvestments                      11 non-null     float64
#  12  taxAssets                                11 non-null     float64
#  13  otherNonCurrentAssets                    11 non-null     int64
#  14  totalNonCurrentAssets                    11 non-null     int64
#  15  otherAssets                              11 non-null     float64
#  16  totalAssets                              11 non-null     int64
#  17  accountPayables                          11 non-null     float64
#  18  shortTermDebt                            11 non-null     float64
#  19  taxPayables                              11 non-null     float64
#  20  deferredRevenue                          11 non-null     float64
#  21  otherCurrentLiabilities                  11 non-null     int64
#  22  totalCurrentLiabilities                  11 non-null     int64
#  23  longTermDebt                             11 non-null     float64
#  24  deferredRevenueNonCurrent                11 non-null     float64
#  25  deferredTaxLiabilitiesNonCurrent         11 non-null     float64
#  26  otherNonCurrentLiabilities               11 non-null     float64
#  27  totalNonCurrentLiabilities               11 non-null     int64
#  28  otherLiabilities                         11 non-null     float64
#  29  capitalLeaseObligations                  11 non-null     float64
#  30  totalLiabilities                         11 non-null     int64
#  31  preferredStock                           11 non-null     float64
#  32  commonStock                              11 non-null     float64
#  33  retainedEarnings                         11 non-null     int64
#  34  accumulatedOtherComprehensiveIncomeLoss  11 non-null     float64
#  35  othertotalStockholdersEquity             11 non-null     float64
#  36  totalStockholdersEquity                  11 non-null     int64
#  37  totalLiabilitiesAndStockholdersEquity    11 non-null     int64
#  38  minorityInterest                         11 non-null     int64
#  39  totalEquity                              11 non-null     int64
#  40  totalLiabilitiesAndTotalEquity           11 non-null     int64
#  41  totalInvestments                         11 non-null     float64
#  42  totalDebt                                11 non-null     float64
#  43  netDebt                                  11 non-null     float64
# dtypes: float64(24), int64(20)
# memory usage: 4.2+ KB

# %% [markdown]
# ### Current Ratio

# %% [markdown]
# Current ratio helps assess if a company has **enough cash and short term assets to pay the bills in the short term**.
#
# |Current Ratio = Current Assets / Current Liabilities|
# |----------------------------------------------------|
#
# A rule of thumb reference for this ratio would be 1.5 or higher to tell if the company has a good current ratio.
#
# A ratio under 1 would signify that the company is at risk of being short of liquidity.
#
# Ratio varies according to business. A higher ratio would also require further investigation.
#
# source: https://www.investopedia.com/terms/c/currentratio.asp

# %% [markdown]
# #### Computing the current ratio
#
# We will create a new column to our existing normal (non-transposed) dataframe **ybs** called **"currentRatio"** (we try to respect Financial Model Prep way of writing as much as possible) by **dividing columns "totalCurrentAssets" by "totalCurrentLiabilities"**.

# %%
# We apply our formula to add our new column to our dataframe
ybs10['currentRatio'] = ybs10['totalCurrentAssets'] / ybs10['totalCurrentLiabilities']
ybs10['currentRatio']
# Out:
# /var/folders/sn/wq_2w76s333b7xmhtx39fzs80000gn/T/ipykernel_46158/3540243556.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ybs10['currentRatio'] = ybs10['totalCurrentAssets'] / ybs10['totalCurrentLiabilities']
# Date
# 2021    1.074553
# 2020    1.363604
# 2019    1.540126
# 2018    1.123843
# 2017    1.276063
# 2016    1.352669
# 2015    1.108771
# 2014    1.080113
# 2013    1.678639
# 2012    1.495849
# 2011    1.608438
# Name: currentRatio, dtype: float64

# %% [markdown]
# We want to see how well Apple is performing on current ratio.
#
# Let's first investigate how many times current ratio was inferior to 1.5 in the last 10 years and then how many times it was superior on the same period.

# %%
# The method consist of slicing through the column using our 1.5 reference value
below1pt5 = ybs10[ybs10['currentRatio'] < 1.5]

# Let's have a look now at our new dataframe
below1pt5
# Out:
#       cashAndCashEquivalents  shortTermInvestments  \
# Date
# 2021             34940000000          2.769900e+10
# 2020             38016000000          5.292700e+10
# 2018             25913000000          4.038800e+10
# 2017             20289000000          5.389200e+10
# 2016             20484000000          4.667100e+10
# 2015             21120000000          2.048100e+10
# 2014             13844000000          1.123300e+10
# 2012             10746000000          1.838300e+10
#
#       cashAndShortTermInvestments  netReceivables   inventory  \
# Date
# 2021                  62639000000     51506000000  6580000000
# 2020                  90943000000     37445000000  4061000000
# 2018                  66301000000     48995000000  3956000000
# 2017                  74181000000     35673000000  4855000000
# 2016                  67155000000     29299000000  2132000000
# 2015                  41601000000     30343000000  2349000000
# 2014                  25077000000     27219000000  2111000000
# 2012                  29129000000     18692000000   791000000
#
#       otherCurrentAssets  totalCurrentAssets  propertyPlantEquipmentNet  \
# Date
# 2021         14111000000        134836000000                39440000000
# 2020         11264000000        143713000000                36766000000
# 2018         12087000000        131339000000                41304000000
# 2017         13936000000        128645000000                33783000000
# 2016          8283000000        106869000000                27010000000
# 2015         15085000000         89378000000                22471000000
# 2014         14124000000         68531000000                20624000000
# 2012          9041000000         57653000000                15452000000
#
#           goodwill  intangibleAssets  ...  othertotalStockholdersEquity  \
# Date                                  ...
# 2021  0.000000e+00      0.000000e+00  ...                           0.0
# 2020  0.000000e+00      0.000000e+00  ...                           0.0
# 2018  0.000000e+00      0.000000e+00  ...                           0.0
# 2017  5.717000e+09      2.298000e+09  ...                           0.0
# 2016  5.414000e+09      3.206000e+09  ...                           0.0
# 2015  5.116000e+09      3.893000e+09  ...                           0.0
# 2014  4.616000e+09      4.142000e+09  ...                           0.0
# 2012  1.135000e+09      4.224000e+09  ...                           0.0
#
#       totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# Date
# 2021              63090000000                           351002000000
# 2020              65339000000                           323888000000
# 2018             107147000000                           365725000000
# 2017             134047000000                           375319000000
# 2016             128249000000                           321686000000
# 2015             119355000000                           290479000000
# 2014             111547000000                           231839000000
# 2012             118210000000                           176064000000
#
#       minorityInterest   totalEquity  totalLiabilitiesAndTotalEquity  \
# Date
# 2021                 0   63090000000                    351002000000
# 2020                 0   65339000000                    323888000000
# 2018                 0  107147000000                    365725000000
# 2017                 0  134047000000                    375319000000
# 2016                 0  128249000000                    321686000000
# 2015                 0  119355000000                    290479000000
# 2014                 0  111547000000                    231839000000
# 2012                 0  118210000000                    176064000000
#
#       totalInvestments     totalDebt       netDebt  currentRatio
# Date
# 2021      1.555760e+11  1.247190e+11  8.977900e+10      1.074553
# 2020      1.538140e+11  1.124360e+11  7.442000e+10      1.363604
# 2018      2.111870e+11  1.144830e+11  8.857000e+10      1.123843
# 2017      2.486060e+11  1.156800e+11  9.539100e+10      1.276063
# 2016      2.171010e+11  8.703200e+10  6.654800e+10      1.352669
# 2015      1.845460e+11  6.446200e+10  4.334200e+10      1.108771
# 2014      1.413950e+11  3.529500e+10  2.145100e+10      1.080113
# 2012      1.105050e+11  0.000000e+00 -1.074600e+10      1.495849
#
# [8 rows x 45 columns]

# %%
# Counting how many times in the last year
below1pt5.index.value_counts().sum()
# Out:
# 8

# %% [markdown]
# Eight out of eleven which is a little below 20% are under 1.5. We won't go further into the the analysis as this is not the goal of this notebook.

# %% [markdown]
# ## Financial Statement: cashflow report

# %% [markdown]
# The cash flow statement (CFS) measures how well a company generates cash to pay its debt obligations, fund its operating expenses, and fund investments.
#
# The CFS allows investors to understand how a company's operations are running, where its money is coming from, and how money is being spent. The CFS also provides insight as to whether a company is on a solid financial footing.
#
# source: https://www.investopedia.com/terms/f/financial-statements.asp#toc-cash-flow-statement

# %% [markdown]
# ### Extracting cashflow report

# %%
# Importing the right url to our notebook
url3 = "https://financialmodelingprep.com/api/v3/cash-flow-statement/AAPL?limit=120&apikey="+key

# We will then establish our call
ycr = requests.get(url3).json()

# %% [markdown]
# As usual, we will explore what's in our JSON request by first checking the first element of our list and then by transforming our JSON into a Pandas

# %%
# Let's call the first element in our JSON
ycr[0]
# Out:
# {'date': '2021-09-25',
#  'symbol': 'AAPL',
#  'reportedCurrency': 'USD',
#  'cik': '0000320193',
#  'fillingDate': '2021-10-29',
#  'acceptedDate': '2021-10-28 18:04:28',
#  'calendarYear': '2021',
#  'period': 'FY',
#  'netIncome': 94680000000,
#  'depreciationAndAmortization': 11284000000,
#  'deferredIncomeTax': -4774000000,
#  'stockBasedCompensation': 7906000000,
#  'changeInWorkingCapital': -4911000000,
#  'accountsReceivables': -10125000000,
#  'inventory': -2642000000,
#  'accountsPayables': 12326000000,
#  'otherWorkingCapital': 1676000000,
#  'otherNonCashItems': -147000000,
#  'netCashProvidedByOperatingActivities': 104038000000,
#  'investmentsInPropertyPlantAndEquipment': -11085000000,
#  'acquisitionsNet': -33000000,
#  'purchasesOfInvestments': -109689000000,
#  'salesMaturitiesOfInvestments': 106870000000,
#  'otherInvestingActivites': -608000000,
#  'netCashUsedForInvestingActivites': -14545000000,
#  'debtRepayment': -8750000000,
#  'commonStockIssued': 1105000000,
#  'commonStockRepurchased': -85971000000,
#  'dividendsPaid': -14467000000,
#  'otherFinancingActivites': 14730000000,
#  'netCashUsedProvidedByFinancingActivities': -93353000000,
#  'effectOfForexChangesOnCash': 0.0,
#  'netChangeInCash': -3860000000,
#  'cashAtEndOfPeriod': 35929000000,
#  'cashAtBeginningOfPeriod': 39789000000,
#  'operatingCashFlow': 104038000000,
#  'capitalExpenditure': -11085000000,
#  'freeCashFlow': 92953000000,
#  'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/0000320193-21-000105-index.htm',
#  'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/aapl-20210925.htm'}

# %% [markdown]
# We can see that the call actually contains all key info about the cashflow of Apple. Furthermore, the call contains info that may be removed when doing analysis such as date, symbol, cik, etc.
#
# We'll now compute the Pandas DataFrame of our call.

# %%
# Calling Pandas dataframe function on our API call
ycr = pd.DataFrame(ycr)

# Inspecting what's inside our dataframe
ycr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 40 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   date                                      33 non-null     object
#  1   symbol                                    33 non-null     object
#  2   reportedCurrency                          33 non-null     object
#  3   cik                                       33 non-null     object
#  4   fillingDate                               33 non-null     object
#  5   acceptedDate                              33 non-null     object
#  6   calendarYear                              33 non-null     object
#  7   period                                    33 non-null     object
#  8   netIncome                                 33 non-null     int64
#  9   depreciationAndAmortization               33 non-null     int64
#  10  deferredIncomeTax                         33 non-null     float64
#  11  stockBasedCompensation                    33 non-null     float64
#  12  changeInWorkingCapital                    33 non-null     int64
#  13  accountsReceivables                       33 non-null     float64
#  14  inventory                                 33 non-null     int64
#  15  accountsPayables                          33 non-null     float64
#  16  otherWorkingCapital                       33 non-null     float64
#  17  otherNonCashItems                         33 non-null     float64
#  18  netCashProvidedByOperatingActivities      33 non-null     int64
#  19  investmentsInPropertyPlantAndEquipment    33 non-null     int64
#  20  acquisitionsNet                           33 non-null     float64
#  21  purchasesOfInvestments                    33 non-null     int64
#  22  salesMaturitiesOfInvestments              33 non-null     int64
#  23  otherInvestingActivites                   33 non-null     float64
#  24  netCashUsedForInvestingActivites          33 non-null     float64
#  25  debtRepayment                             33 non-null     float64
#  26  commonStockIssued                         33 non-null     int64
#  27  commonStockRepurchased                    33 non-null     float64
#  28  dividendsPaid                             33 non-null     float64
#  29  otherFinancingActivites                   33 non-null     float64
#  30  netCashUsedProvidedByFinancingActivities  33 non-null     int64
#  31  effectOfForexChangesOnCash                33 non-null     float64
#  32  netChangeInCash                           33 non-null     int64
#  33  cashAtEndOfPeriod                         33 non-null     float64
#  34  cashAtBeginningOfPeriod                   33 non-null     int64
#  35  operatingCashFlow                         33 non-null     int64
#  36  capitalExpenditure                        33 non-null     int64
#  37  freeCashFlow                              33 non-null     int64
#  38  link                                      33 non-null     object
#  39  finalLink                                 33 non-null     object
# dtypes: float64(15), int64(15), object(10)
# memory usage: 10.4+ KB

# %% [markdown]
# It appears that we have the data of cashflow report for 33 years of Apple report.

# %%
# Inspecting the first five row of our DataFrame
ycr.head()
# Out:
#          date symbol reportedCurrency         cik fillingDate  \
# 0  2021-09-25   AAPL              USD  0000320193  2021-10-29
# 1  2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2  2019-09-28   AAPL              USD  0000320193  2019-10-31
# 3  2018-09-29   AAPL              USD  0000320193  2018-11-05
# 4  2017-09-30   AAPL              USD  0000320193  2017-11-03
#
#           acceptedDate calendarYear period    netIncome  \
# 0  2021-10-28 18:04:28         2021     FY  94680000000
# 1  2020-10-29 18:06:25         2020     FY  57411000000
# 2  2019-10-30 18:12:36         2019     FY  55256000000
# 3  2018-11-05 08:01:40         2018     FY  59531000000
# 4  2017-11-03 08:01:37         2017     FY  48351000000
#
#    depreciationAndAmortization  ...  netCashUsedProvidedByFinancingActivities  \
# 0                  11284000000  ...                              -93353000000
# 1                  11056000000  ...                              -86820000000
# 2                  12547000000  ...                              -90976000000
# 3                  10903000000  ...                              -87876000000
# 4                  10157000000  ...                              -17347000000
#
#    effectOfForexChangesOnCash  netChangeInCash  cashAtEndOfPeriod  \
# 0                         0.0      -3860000000       3.592900e+10
# 1                         0.0     -10435000000       3.978900e+10
# 2                         0.0      24311000000       5.022400e+10
# 3                         0.0       5624000000       2.591300e+10
# 4                         0.0       -195000000       2.028900e+10
#
#    cashAtBeginningOfPeriod  operatingCashFlow  capitalExpenditure  \
# 0              39789000000       104038000000        -11085000000
# 1              50224000000        80674000000         -7309000000
# 2              25913000000        69391000000        -10495000000
# 3              20289000000        77434000000        -13313000000
# 4              20484000000        63598000000        -12795000000
#
#    freeCashFlow                                               link  \
# 0   92953000000  https://www.sec.gov/Archives/edgar/data/320193...
# 1   73365000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2   58896000000  https://www.sec.gov/Archives/edgar/data/320193...
# 3   64121000000  https://www.sec.gov/Archives/edgar/data/320193...
# 4   50803000000  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                            finalLink
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 40 columns]

# %%
# Inspecting the last five row of our DataFrame
ycr.tail()
# Out:
#           date symbol reportedCurrency         cik fillingDate acceptedDate  \
# 28  1993-09-30   AAPL              USD  0000320193  1993-09-30   1993-09-30
# 29  1992-09-30   AAPL              USD  0000320193  1992-09-30   1992-09-30
# 30  1991-09-30   AAPL              USD  0000320193  1991-09-30   1991-09-30
# 31  1990-09-30   AAPL              USD  0000320193  1990-09-30   1990-09-30
# 32  1989-09-30   AAPL              USD  0000320193  1989-09-30   1989-09-30
#
#    calendarYear period  netIncome  depreciationAndAmortization  ...  \
# 28         1993     FY   86600000                    166100000  ...
# 29         1992     FY  530400000                    217200000  ...
# 30         1991     FY  309800000                    204400000  ...
# 31         1990     FY  474900000                    202700000  ...
# 32         1989     FY  454000000                    124800000  ...
#
#     netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 28                                 346900000                         0.0
# 29                                 -76700000                         0.0
# 30                                  42500000                         0.0
# 31                                -454000000                         0.0
# 32                                 -38300000                         0.0
#
#     netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 28        346900000                0.0                498600000
# 29        -76700000                0.0                604100000
# 30         42500000                0.0                374700000
# 31       -454000000                0.0                438300000
# 32        -38300000                0.0                372400000
#
#     operatingCashFlow  capitalExpenditure  freeCashFlow  link  finalLink
# 28         -661800000          -213100000    -874900000
# 29          883700000          -194900000     688800000
# 30          128700000          -218300000     -89600000
# 31          963900000          -224300000     739600000
# 32          507300000          -239000000     268300000
#
# [5 rows x 40 columns]

# %%
# Let's drop the columns we don't use
ycr.drop(['date','symbol', 'reportedCurrency','cik', 'fillingDate', 'acceptedDate', 'period','link', 'finalLink'], axis='columns', inplace=True)

# %%
# Let's also change the index to calendarYear
ycr.set_index('calendarYear', inplace=True)

# %%
# Inspecting dataframe
ycr.head()
# Out:
#                 netIncome  depreciationAndAmortization  deferredIncomeTax  \
# calendarYear
# 2021          94680000000                  11284000000      -4.774000e+09
# 2020          57411000000                  11056000000      -2.150000e+08
# 2019          55256000000                  12547000000      -3.400000e+08
# 2018          59531000000                  10903000000      -3.259000e+10
# 2017          48351000000                  10157000000       5.966000e+09
#
#               stockBasedCompensation  changeInWorkingCapital  \
# calendarYear
# 2021                    7.906000e+09             -4911000000
# 2020                    6.829000e+09              5690000000
# 2019                    6.068000e+09             -3488000000
# 2018                    5.340000e+09             34694000000
# 2017                    4.840000e+09             -5550000000
#
#               accountsReceivables   inventory  accountsPayables  \
# calendarYear
# 2021                -1.012500e+10 -2642000000      1.232600e+10
# 2020                 6.917000e+09  -127000000     -4.062000e+09
# 2019                 2.450000e+08  -289000000     -1.923000e+09
# 2018                -5.322000e+09   828000000      9.175000e+09
# 2017                -2.093000e+09 -2723000000      9.618000e+09
#
#               otherWorkingCapital  otherNonCashItems  ...  dividendsPaid  \
# calendarYear                                          ...
# 2021                 1.676000e+09       -147000000.0  ...  -1.446700e+10
# 2020                 2.081000e+09        -97000000.0  ...  -1.408100e+10
# 2019                -6.250000e+08       -652000000.0  ...  -1.411900e+10
# 2018                -4.400000e+07       -444000000.0  ...  -1.371200e+10
# 2017                -6.260000e+08       -166000000.0  ...  -1.276900e+10
#
#               otherFinancingActivites  \
# calendarYear
# 2021                     1.473000e+10
# 2020                     1.136800e+10
# 2019                    -1.936000e+09
# 2018                     4.405000e+09
# 2017                     3.126700e+10
#
#               netCashUsedProvidedByFinancingActivities  \
# calendarYear
# 2021                                      -93353000000
# 2020                                      -86820000000
# 2019                                      -90976000000
# 2018                                      -87876000000
# 2017                                      -17347000000
#
#               effectOfForexChangesOnCash  netChangeInCash  cashAtEndOfPeriod  \
# calendarYear
# 2021                                 0.0      -3860000000       3.592900e+10
# 2020                                 0.0     -10435000000       3.978900e+10
# 2019                                 0.0      24311000000       5.022400e+10
# 2018                                 0.0       5624000000       2.591300e+10
# 2017                                 0.0       -195000000       2.028900e+10
#
#               cashAtBeginningOfPeriod  operatingCashFlow  capitalExpenditure  \
# calendarYear
# 2021                      39789000000       104038000000        -11085000000
# 2020                      50224000000        80674000000         -7309000000
# 2019                      25913000000        69391000000        -10495000000
# 2018                      20289000000        77434000000        -13313000000
# 2017                      20484000000        63598000000        -12795000000
#
#               freeCashFlow
# calendarYear
# 2021           92953000000
# 2020           73365000000
# 2019           58896000000
# 2018           64121000000
# 2017           50803000000
#
# [5 rows x 30 columns]

# %% [markdown]
# We won't go further in the exploration of data of cashflow as it requires a more in-depth understanding of the topic to bring to life some concrete analysis.
#
# Here is a brief explanation of cashflow report: https://corporatefinanceinstitute.com/resources/knowledge/accounting/statement-of-cash-flows/

# %% [markdown]
# # Conclusion

# %% [markdown]
# Financial Model Prep provides all the key information on the different financial statements.
#
# Financial statements provide key information company's performance and might highly useful when performing Financial Analysis on business and perform key ratios.
#
# It is useful when providing more input to analyze a stock's price.
