# %% [markdown]
# # Balance Sheets - Financial Statements

# %% [markdown]
# Welcome to this Jupyter Notebook of the Finsloth.
#
# In this first Notebook of our series, we are going to explore the first element of FMP Stock Fundamentals which is a Financial Statement.
#
# Our goal is to understand **the meaning and the structure of each data given by FMP, how to transform it for actual use in any trading or investing strategies**.

# %% [markdown]
# ## About Financial Modeling Prep
#
# Financial Modeling Prep is a stock market API that provides a wide range of data. Data covers stocks, crypto forex and commodities.
#
# You have addition data such as institutional stock ownership, esg score, price target, etc.
#
# There are several plans including a free one.
#
# I am on a start plan for this notebook. Here are the link for the pricing: https://site.financialmodelingprep.com/developer/docs/pricing/

# %% [markdown]
# ## What are financial statements?

# %% [markdown]
# * Financial statements are written records that convey the business activities and the financial performance of an entity.
# * The **balance sheet** provides an overview of assets, liabilities, and shareholders' equity as a snapshot in time.
# * The **income statement** primarily focuses on a company’s revenues and expenses during a particular period. Once expenses are subtracted from revenues, the statement produces a company's profit figure called net income.
# * The **cash flow statement (CFS)** measures how well a company generates cash to pay its debt obligations, fund its operating expenses, and fund investments.
# * The statement of changes in equity records how profits are retained within a company for future growth or distributed to external parties.

# %% [markdown]
# ## Initial Import and API Key

# %% [markdown]
# In this section, we are going to perform classic libraries import to perform our data transformation and visualisation.

# %%
# We import the basics and some specific to APIs libraries

# Basic Data Manipulation Librairies
import pandas as pd

# requests is another way of sending an API request to FMP
import requests

# json library makes it easier to access JSON format
import json

# %% [markdown]
# For privacy reason, I have hidden my key to access the API.
#
# Here is the link to the dashboard where you can find your private key in case you created an account: https://site.financialmodelingprep.com/developer/docs/dashboard

# %%
# Because I want to share this file on Github, I made sure that it's not showing the actual key.
key=key

# %% [markdown]
# FMP provides us the right method to extract data from its API according to the coding language you are using.
#
# Here is the function they provided us to extract data with Python.

# %% [markdown]
# ## Financial Statements: balance sheets

# %% [markdown]
# **Balance sheets determine risk**. This financial statement lists everything a company owns and all of its debt. A company will be able to quickly assess whether it has borrowed too much money, whether the assets it owns are not liquid enough, or whether it has enough cash on hand to meet current demands.

# %% [markdown]
# If you want to learn more about balance sheets, here is a link: https://www.investopedia.com/terms/b/balancesheet.asp#toc-importance-of-a-balance-sheet

# %% [markdown]
# ### Key facts about the balance sheets

# %% [markdown]
# - A balance sheet is a financial statement that reports a **company's assets, liabilities, and shareholder equity**.
# - The balance sheet is **one of the three core financial statements** that are used to evaluate a business.
# - It provides a **snapshot of a company's finances (what it owns and owes)** as of the date of publication.
# - The balance sheet adheres to an **equation that equates assets with the sum of liabilities and shareholder equity**.
# - Fundamental analysts use balance sheets to **calculate financial ratios**.

# %% [markdown]
# ### Exploration of balance sheets

# %% [markdown]
# Juste like previous, we are going to explore what's inside a balance sheet statement.

# %%
# We do our API call from FMP on balance sheets
url2='https://financialmodelingprep.com/api/v3/balance-sheet-statement/AAPL?limit=120&apikey='+key

# We do our call using requests and use the json method to get the right format.
# ybs stands for yearly income statement
ybs=requests.get(url2).json()

# %% [markdown]
# We know that json returns a list of dictionnary that contains all the key elements.
#
# In finance, most data is organised by date so it's easy to tell that our balance sheets will be organised year by year.

# %%
ybs = pd.DataFrame(ybs)

# %% [markdown]
# Let's explore what's inside of our balance sheet call.

# %%
ybs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 54 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   date                                     38 non-null     object
#  1   symbol                                   38 non-null     object
#  2   reportedCurrency                         38 non-null     object
#  3   cik                                      38 non-null     object
#  4   fillingDate                              38 non-null     object
#  5   acceptedDate                             38 non-null     object
#  6   calendarYear                             38 non-null     object
#  7   period                                   38 non-null     object
#  8   cashAndCashEquivalents                   38 non-null     int64
#  9   shortTermInvestments                     38 non-null     int64
#  10  cashAndShortTermInvestments              38 non-null     int64
#  11  netReceivables                           38 non-null     int64
#  12  inventory                                38 non-null     int64
#  13  otherCurrentAssets                       38 non-null     int64
#  14  totalCurrentAssets                       38 non-null     int64
#  15  propertyPlantEquipmentNet                38 non-null     int64
#  16  goodwill                                 38 non-null     int64
#  17  intangibleAssets                         38 non-null     int64
#  18  goodwillAndIntangibleAssets              38 non-null     int64
#  19  longTermInvestments                      38 non-null     int64
#  20  taxAssets                                38 non-null     int64
#  21  otherNonCurrentAssets                    38 non-null     int64
#  22  totalNonCurrentAssets                    38 non-null     int64
#  23  otherAssets                              38 non-null     int64
#  24  totalAssets                              38 non-null     int64
#  25  accountPayables                          38 non-null     int64
#  26  shortTermDebt                            38 non-null     int64
#  27  taxPayables                              38 non-null     int64
#  28  deferredRevenue                          38 non-null     int64
#  29  otherCurrentLiabilities                  38 non-null     int64
#  30  totalCurrentLiabilities                  38 non-null     int64
#  31  longTermDebt                             38 non-null     int64
#  32  deferredRevenueNonCurrent                38 non-null     int64
#  33  deferredTaxLiabilitiesNonCurrent         38 non-null     int64
#  34  otherNonCurrentLiabilities               38 non-null     int64
#  35  totalNonCurrentLiabilities               38 non-null     int64
#  36  otherLiabilities                         38 non-null     int64
#  37  capitalLeaseObligations                  38 non-null     int64
#  38  totalLiabilities                         38 non-null     int64
#  39  preferredStock                           38 non-null     int64
#  40  commonStock                              38 non-null     int64
#  41  retainedEarnings                         38 non-null     int64
#  42  accumulatedOtherComprehensiveIncomeLoss  38 non-null     int64
#  43  othertotalStockholdersEquity             38 non-null     int64
#  44  totalStockholdersEquity                  38 non-null     int64
#  45  totalEquity                              38 non-null     int64
#  46  totalLiabilitiesAndStockholdersEquity    38 non-null     int64
#  47  minorityInterest                         38 non-null     int64
#  48  totalLiabilitiesAndTotalEquity           38 non-null     int64
#  49  totalInvestments                         38 non-null     int64
#  50  totalDebt                                38 non-null     int64
#  51  netDebt                                  38 non-null     int64
#  52  link                                     38 non-null     object
#  53  finalLink                                38 non-null     object
# dtypes: int64(44), object(10)
# memory usage: 16.2+ KB

# %% [markdown]
# As we can see, it's quite complete.
#
# We won't go into details in this one as this notebook is for exploration mainly.
#
# Now, let's observe this Pandas dataframe first rows.

# %%
# Let's call the 5 first rows of our pandas dataframe
ybs.head()
# Out:
#          date symbol reportedCurrency         cik fillingDate  \
# 0  2022-09-24   AAPL              USD  0000320193  2022-10-28
# 1  2021-09-25   AAPL              USD  0000320193  2021-10-29
# 2  2020-09-26   AAPL              USD  0000320193  2020-10-30
# 3  2019-09-28   AAPL              USD  0000320193  2019-10-31
# 4  2018-09-29   AAPL              USD  0000320193  2018-11-05
#
#           acceptedDate calendarYear period  cashAndCashEquivalents  \
# 0  2022-10-27 18:01:14         2022     FY             23646000000
# 1  2021-10-28 18:04:28         2021     FY             34940000000
# 2  2020-10-29 18:06:25         2020     FY             38016000000
# 3  2019-10-30 18:12:36         2019     FY             48844000000
# 4  2018-11-05 08:01:40         2018     FY             25913000000
#
#    shortTermInvestments  ...  totalStockholdersEquity   totalEquity  \
# 0           24658000000  ...              50672000000   50672000000
# 1           27699000000  ...              63090000000   63090000000
# 2           52927000000  ...              65339000000   65339000000
# 3           51713000000  ...              90488000000   90488000000
# 4           40388000000  ...             107147000000  107147000000
#
#    totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# 0                           352755000000                 0
# 1                           351002000000                 0
# 2                           323888000000                 0
# 3                           338516000000                 0
# 4                           365725000000                 0
#
#    totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# 0                    352755000000      145463000000  120069000000
# 1                    351002000000      155576000000  124719000000
# 2                    323888000000      153814000000  112436000000
# 3                    338516000000      157054000000  108047000000
# 4                    365725000000      211187000000  114483000000
#
#        netDebt                                               link  \
# 0  96423000000  https://www.sec.gov/Archives/edgar/data/320193...
# 1  89779000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2  74420000000  https://www.sec.gov/Archives/edgar/data/320193...
# 3  59203000000  https://www.sec.gov/Archives/edgar/data/320193...
# 4  88570000000  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                            finalLink
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 54 columns]

# %% [markdown]
# Just like previously, let's set index to calendar year

# %%
# We change the index to years.
ybs.set_index('calendarYear', inplace=True)
ybs.head()
# Out:
#                     date symbol reportedCurrency         cik fillingDate  \
# calendarYear
# 2022          2022-09-24   AAPL              USD  0000320193  2022-10-28
# 2021          2021-09-25   AAPL              USD  0000320193  2021-10-29
# 2020          2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2019          2019-09-28   AAPL              USD  0000320193  2019-10-31
# 2018          2018-09-29   AAPL              USD  0000320193  2018-11-05
#
#                      acceptedDate period  cashAndCashEquivalents  \
# calendarYear
# 2022          2022-10-27 18:01:14     FY             23646000000
# 2021          2021-10-28 18:04:28     FY             34940000000
# 2020          2020-10-29 18:06:25     FY             38016000000
# 2019          2019-10-30 18:12:36     FY             48844000000
# 2018          2018-11-05 08:01:40     FY             25913000000
#
#               shortTermInvestments  cashAndShortTermInvestments  ...  \
# calendarYear                                                     ...
# 2022                   24658000000                  48304000000  ...
# 2021                   27699000000                  62639000000  ...
# 2020                   52927000000                  90943000000  ...
# 2019                   51713000000                 100557000000  ...
# 2018                   40388000000                  66301000000  ...
#
#               totalStockholdersEquity   totalEquity  \
# calendarYear
# 2022                      50672000000   50672000000
# 2021                      63090000000   63090000000
# 2020                      65339000000   65339000000
# 2019                      90488000000   90488000000
# 2018                     107147000000  107147000000
#
#               totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# calendarYear
# 2022                                   352755000000                 0
# 2021                                   351002000000                 0
# 2020                                   323888000000                 0
# 2019                                   338516000000                 0
# 2018                                   365725000000                 0
#
#               totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# calendarYear
# 2022                            352755000000      145463000000  120069000000
# 2021                            351002000000      155576000000  124719000000
# 2020                            323888000000      153814000000  112436000000
# 2019                            338516000000      157054000000  108047000000
# 2018                            365725000000      211187000000  114483000000
#
#                   netDebt                                               link  \
# calendarYear
# 2022          96423000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2021          89779000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2020          74420000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2019          59203000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2018          88570000000  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                                       finalLink
# calendarYear
# 2022          https://www.sec.gov/Archives/edgar/data/320193...
# 2021          https://www.sec.gov/Archives/edgar/data/320193...
# 2020          https://www.sec.gov/Archives/edgar/data/320193...
# 2019          https://www.sec.gov/Archives/edgar/data/320193...
# 2018          https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 53 columns]

# %%
# Let's set the index as year in a definitive way and reorder the years
# ybs.set_index('calendarYear', inplace=True)
ybs.sort_index().tail()
# Out:
#                     date symbol reportedCurrency         cik fillingDate  \
# calendarYear
# 2018          2018-09-29   AAPL              USD  0000320193  2018-11-05
# 2019          2019-09-28   AAPL              USD  0000320193  2019-10-31
# 2020          2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2021          2021-09-25   AAPL              USD  0000320193  2021-10-29
# 2022          2022-09-24   AAPL              USD  0000320193  2022-10-28
#
#                      acceptedDate period  cashAndCashEquivalents  \
# calendarYear
# 2018          2018-11-05 08:01:40     FY             25913000000
# 2019          2019-10-30 18:12:36     FY             48844000000
# 2020          2020-10-29 18:06:25     FY             38016000000
# 2021          2021-10-28 18:04:28     FY             34940000000
# 2022          2022-10-27 18:01:14     FY             23646000000
#
#               shortTermInvestments  cashAndShortTermInvestments  ...  \
# calendarYear                                                     ...
# 2018                   40388000000                  66301000000  ...
# 2019                   51713000000                 100557000000  ...
# 2020                   52927000000                  90943000000  ...
# 2021                   27699000000                  62639000000  ...
# 2022                   24658000000                  48304000000  ...
#
#               totalStockholdersEquity   totalEquity  \
# calendarYear
# 2018                     107147000000  107147000000
# 2019                      90488000000   90488000000
# 2020                      65339000000   65339000000
# 2021                      63090000000   63090000000
# 2022                      50672000000   50672000000
#
#               totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# calendarYear
# 2018                                   365725000000                 0
# 2019                                   338516000000                 0
# 2020                                   323888000000                 0
# 2021                                   351002000000                 0
# 2022                                   352755000000                 0
#
#               totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# calendarYear
# 2018                            365725000000      211187000000  114483000000
# 2019                            338516000000      157054000000  108047000000
# 2020                            323888000000      153814000000  112436000000
# 2021                            351002000000      155576000000  124719000000
# 2022                            352755000000      145463000000  120069000000
#
#                   netDebt                                               link  \
# calendarYear
# 2018          88570000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2019          59203000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2020          74420000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2021          89779000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2022          96423000000  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                                       finalLink
# calendarYear
# 2018          https://www.sec.gov/Archives/edgar/data/320193...
# 2019          https://www.sec.gov/Archives/edgar/data/320193...
# 2020          https://www.sec.gov/Archives/edgar/data/320193...
# 2021          https://www.sec.gov/Archives/edgar/data/320193...
# 2022          https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 53 columns]

# %% [markdown]
# We are going to rename the index from "calendar Year" to "Date" in order to have our data frame more readable.

# %%
# We change the index name of our Data Frame
ybs.index.names = ['Date']

# We are inspecting if these changes have been taken into account
ybs.head()
# Out:
#             date symbol reportedCurrency         cik fillingDate  \
# Date
# 2022  2022-09-24   AAPL              USD  0000320193  2022-10-28
# 2021  2021-09-25   AAPL              USD  0000320193  2021-10-29
# 2020  2020-09-26   AAPL              USD  0000320193  2020-10-30
# 2019  2019-09-28   AAPL              USD  0000320193  2019-10-31
# 2018  2018-09-29   AAPL              USD  0000320193  2018-11-05
#
#              acceptedDate period  cashAndCashEquivalents  \
# Date
# 2022  2022-10-27 18:01:14     FY             23646000000
# 2021  2021-10-28 18:04:28     FY             34940000000
# 2020  2020-10-29 18:06:25     FY             38016000000
# 2019  2019-10-30 18:12:36     FY             48844000000
# 2018  2018-11-05 08:01:40     FY             25913000000
#
#       shortTermInvestments  cashAndShortTermInvestments  ...  \
# Date                                                     ...
# 2022           24658000000                  48304000000  ...
# 2021           27699000000                  62639000000  ...
# 2020           52927000000                  90943000000  ...
# 2019           51713000000                 100557000000  ...
# 2018           40388000000                  66301000000  ...
#
#       totalStockholdersEquity   totalEquity  \
# Date
# 2022              50672000000   50672000000
# 2021              63090000000   63090000000
# 2020              65339000000   65339000000
# 2019              90488000000   90488000000
# 2018             107147000000  107147000000
#
#       totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# Date
# 2022                           352755000000                 0
# 2021                           351002000000                 0
# 2020                           323888000000                 0
# 2019                           338516000000                 0
# 2018                           365725000000                 0
#
#       totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# Date
# 2022                    352755000000      145463000000  120069000000
# 2021                    351002000000      155576000000  124719000000
# 2020                    323888000000      153814000000  112436000000
# 2019                    338516000000      157054000000  108047000000
# 2018                    365725000000      211187000000  114483000000
#
#           netDebt                                               link  \
# Date
# 2022  96423000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2021  89779000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2020  74420000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2019  59203000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2018  88570000000  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                               finalLink
# Date
# 2022  https://www.sec.gov/Archives/edgar/data/320193...
# 2021  https://www.sec.gov/Archives/edgar/data/320193...
# 2020  https://www.sec.gov/Archives/edgar/data/320193...
# 2019  https://www.sec.gov/Archives/edgar/data/320193...
# 2018  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 53 columns]

# %% [markdown]
# Just like previously, let's remove some columns we actually don't need which will include:
# - symbol,
# - reportedCurrency,
# - cik,
# - fillingDate,
# - acceptedDate,
# - period (we already know it's a full year),
# - link,
# - finalLink.

# %%
# We use our drop method from pandas to remove some columns
ybs.drop(['date', 'symbol', 'reportedCurrency', 'cik', 'fillingDate', 'acceptedDate', 'period', 'link', 'finalLink'], axis='columns', inplace=True)

# %%
# Let's inspect our Data Frame
ybs.head()
# Out:
#       cashAndCashEquivalents  shortTermInvestments  \
# Date
# 2022             23646000000           24658000000
# 2021             34940000000           27699000000
# 2020             38016000000           52927000000
# 2019             48844000000           51713000000
# 2018             25913000000           40388000000
#
#       cashAndShortTermInvestments  netReceivables   inventory  \
# Date
# 2022                  48304000000     60932000000  4946000000
# 2021                  62639000000     51506000000  6580000000
# 2020                  90943000000     37445000000  4061000000
# 2019                 100557000000     45804000000  4106000000
# 2018                  66301000000     48995000000  3956000000
#
#       otherCurrentAssets  totalCurrentAssets  propertyPlantEquipmentNet  \
# Date
# 2022         21223000000        135405000000                42117000000
# 2021         14111000000        134836000000                39440000000
# 2020         11264000000        143713000000                36766000000
# 2019         12352000000        162819000000                37378000000
# 2018         12087000000        131339000000                41304000000
#
#       goodwill  intangibleAssets  ...  \
# Date                              ...
# 2022         0                 0  ...
# 2021         0                 0  ...
# 2020         0                 0  ...
# 2019         0                 0  ...
# 2018         0                 0  ...
#
#       accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# Date
# 2022                             -11109000000                             0
# 2021                                163000000                             0
# 2020                               -406000000                             0
# 2019                               -584000000                             0
# 2018                              -3454000000                             0
#
#       totalStockholdersEquity   totalEquity  \
# Date
# 2022              50672000000   50672000000
# 2021              63090000000   63090000000
# 2020              65339000000   65339000000
# 2019              90488000000   90488000000
# 2018             107147000000  107147000000
#
#       totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# Date
# 2022                           352755000000                 0
# 2021                           351002000000                 0
# 2020                           323888000000                 0
# 2019                           338516000000                 0
# 2018                           365725000000                 0
#
#       totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# Date
# 2022                    352755000000      145463000000  120069000000
# 2021                    351002000000      155576000000  124719000000
# 2020                    323888000000      153814000000  112436000000
# 2019                    338516000000      157054000000  108047000000
# 2018                    365725000000      211187000000  114483000000
#
#           netDebt
# Date
# 2022  96423000000
# 2021  89779000000
# 2020  74420000000
# 2019  59203000000
# 2018  88570000000
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Normal vs. Transposed version of Balance Sheets: when to use each one of them

# %% [markdown]
# Both views can be quite useful for the type of analysis you try to perform. However, it's wise to understand which one is mostly adapted.
#
# Here is a good way to separate both views.
#
# Use **Normal** view when:
# - computing ratios,
# - slicing through data,
# - data analysis,
# - plotting timeseries of result.
#
# Use **Transposed** view when:
# - summing up result,
# - show in a more traditional way.

# %% [markdown]
# #### Transposed version of yearly balance sheets

# %% [markdown]
# We will transpose the balance sheets using the transpose method for dataframe. However, before doing that, we will first slice into our data to get only the last ten years of results.
#
# We could perform that using the head method. But for the sake of this exercise, we'll use **the loc method** that allows to call "visible" elements in our dataframe, instead of counting every single index.

# %%
# Slicing from 2021 up to 2011 using the loc function
ybs10 = ybs.loc['2021':'2011',:]

# Inspecting our slice
ybs10
# Out:
#       cashAndCashEquivalents  shortTermInvestments  \
# Date
# 2021             34940000000           27699000000
# 2020             38016000000           52927000000
# 2019             48844000000           51713000000
# 2018             25913000000           40388000000
# 2017             20289000000           53892000000
# 2016             20484000000           46671000000
# 2015             21120000000           20481000000
# 2014             13844000000           11233000000
# 2013             14259000000           26287000000
# 2012             10746000000           18383000000
# 2011              9815000000           16137000000
#
#       cashAndShortTermInvestments  netReceivables   inventory  \
# Date
# 2021                  62639000000     51506000000  6580000000
# 2020                  90943000000     37445000000  4061000000
# 2019                 100557000000     45804000000  4106000000
# 2018                  66301000000     48995000000  3956000000
# 2017                  74181000000     35673000000  4855000000
# 2016                  67155000000     29299000000  2132000000
# 2015                  41601000000     30343000000  2349000000
# 2014                  25077000000     27219000000  2111000000
# 2013                  40546000000     20641000000  1764000000
# 2012                  29129000000     18692000000   791000000
# 2011                  25952000000     11717000000   776000000
#
#       otherCurrentAssets  totalCurrentAssets  propertyPlantEquipmentNet  \
# Date
# 2021         14111000000        134836000000                39440000000
# 2020         11264000000        143713000000                36766000000
# 2019         12352000000        162819000000                37378000000
# 2018         12087000000        131339000000                41304000000
# 2017         13936000000        128645000000                33783000000
# 2016          8283000000        106869000000                27010000000
# 2015         15085000000         89378000000                22471000000
# 2014         14124000000         68531000000                20624000000
# 2013         10335000000         73286000000                16597000000
# 2012          9041000000         57653000000                15452000000
# 2011          6543000000         44988000000                 7777000000
#
#         goodwill  intangibleAssets  ...  \
# Date                                ...
# 2021           0                 0  ...
# 2020           0                 0  ...
# 2019           0                 0  ...
# 2018           0                 0  ...
# 2017  5717000000        2298000000  ...
# 2016  5414000000        3206000000  ...
# 2015  5116000000        3893000000  ...
# 2014  4616000000        4142000000  ...
# 2013  1577000000        4179000000  ...
# 2012  1135000000        4224000000  ...
# 2011   896000000        3536000000  ...
#
#       accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# Date
# 2021                                163000000                             0
# 2020                               -406000000                             0
# 2019                               -584000000                             0
# 2018                              -3454000000                             0
# 2017                               -150000000                             0
# 2016                                634000000                             0
# 2015                               -345000000                             0
# 2014                               1082000000                             0
# 2013                               -471000000                             0
# 2012                                499000000                             0
# 2011                                443000000                             0
#
#       totalStockholdersEquity   totalEquity  \
# Date
# 2021              63090000000   63090000000
# 2020              65339000000   65339000000
# 2019              90488000000   90488000000
# 2018             107147000000  107147000000
# 2017             134047000000  134047000000
# 2016             128249000000  128249000000
# 2015             119355000000  119355000000
# 2014             111547000000  111547000000
# 2013             123549000000  123549000000
# 2012             118210000000  118210000000
# 2011              76615000000   76615000000
#
#       totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# Date
# 2021                           351002000000                 0
# 2020                           323888000000                 0
# 2019                           338516000000                 0
# 2018                           365725000000                 0
# 2017                           375319000000                 0
# 2016                           321686000000                 0
# 2015                           290479000000                 0
# 2014                           231839000000                 0
# 2013                           207000000000                 0
# 2012                           176064000000                 0
# 2011                           116371000000                 0
#
#       totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# Date
# 2021                    351002000000      155576000000  124719000000
# 2020                    323888000000      153814000000  112436000000
# 2019                    338516000000      157054000000  108047000000
# 2018                    365725000000      211187000000  114483000000
# 2017                    375319000000      248606000000  115680000000
# 2016                    321686000000      217101000000   87032000000
# 2015                    290479000000      184546000000   64462000000
# 2014                    231839000000      141395000000   35295000000
# 2013                    207000000000      132502000000   16960000000
# 2012                    176064000000      110505000000             0
# 2011                    116371000000       71755000000             0
#
#           netDebt
# Date
# 2021  89779000000
# 2020  74420000000
# 2019  59203000000
# 2018  88570000000
# 2017  95391000000
# 2016  66548000000
# 2015  43342000000
# 2014  21451000000
# 2013   2701000000
# 2012 -10746000000
# 2011  -9815000000
#
# [11 rows x 44 columns]

# %%
# We'll call it yearly balance sheets transposed or ybst
ybst = ybs10.transpose()

# %%
# Using the info method to check up whether the changes have been correctly made
ybst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, cashAndCashEquivalents to netDebt
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2021    44 non-null     int64
#  1   2020    44 non-null     int64
#  2   2019    44 non-null     int64
#  3   2018    44 non-null     int64
#  4   2017    44 non-null     int64
#  5   2016    44 non-null     int64
#  6   2015    44 non-null     int64
#  7   2014    44 non-null     int64
#  8   2013    44 non-null     int64
#  9   2012    44 non-null     int64
#  10  2011    44 non-null     int64
# dtypes: int64(11)
# memory usage: 5.2+ KB

# %% [markdown]
# We can attest that the number of rows and columns have remained the same.

# %%
# Showing our DataFrame
ybst
# Out:
# Date                                             2021          2020  \
# cashAndCashEquivalents                    34940000000   38016000000
# shortTermInvestments                      27699000000   52927000000
# cashAndShortTermInvestments               62639000000   90943000000
# netReceivables                            51506000000   37445000000
# inventory                                  6580000000    4061000000
# otherCurrentAssets                        14111000000   11264000000
# totalCurrentAssets                       134836000000  143713000000
# propertyPlantEquipmentNet                 39440000000   36766000000
# goodwill                                            0             0
# intangibleAssets                                    0             0
# goodwillAndIntangibleAssets                         0             0
# longTermInvestments                      127877000000  100887000000
# taxAssets                                           0             0
# otherNonCurrentAssets                     48849000000   42522000000
# totalNonCurrentAssets                    216166000000  180175000000
# otherAssets                                         0             0
# totalAssets                              351002000000  323888000000
# accountPayables                           54763000000   42296000000
# shortTermDebt                             15613000000   13769000000
# taxPayables                                         0             0
# deferredRevenue                            7612000000    6643000000
# otherCurrentLiabilities                   47493000000   42684000000
# totalCurrentLiabilities                  125481000000  105392000000
# longTermDebt                             109106000000   98667000000
# deferredRevenueNonCurrent                           0             0
# deferredTaxLiabilitiesNonCurrent                    0             0
# otherNonCurrentLiabilities                53325000000   54490000000
# totalNonCurrentLiabilities               162431000000  153157000000
# otherLiabilities                                    0             0
# capitalLeaseObligations                             0             0
# totalLiabilities                         287912000000  258549000000
# preferredStock                                      0             0
# commonStock                               57365000000   50779000000
# retainedEarnings                           5562000000   14966000000
# accumulatedOtherComprehensiveIncomeLoss     163000000    -406000000
# othertotalStockholdersEquity                        0             0
# totalStockholdersEquity                   63090000000   65339000000
# totalEquity                               63090000000   65339000000
# totalLiabilitiesAndStockholdersEquity    351002000000  323888000000
# minorityInterest                                    0             0
# totalLiabilitiesAndTotalEquity           351002000000  323888000000
# totalInvestments                         155576000000  153814000000
# totalDebt                                124719000000  112436000000
# netDebt                                   89779000000   74420000000
#
# Date                                             2019          2018  \
# cashAndCashEquivalents                    48844000000   25913000000
# shortTermInvestments                      51713000000   40388000000
# cashAndShortTermInvestments              100557000000   66301000000
# netReceivables                            45804000000   48995000000
# inventory                                  4106000000    3956000000
# otherCurrentAssets                        12352000000   12087000000
# totalCurrentAssets                       162819000000  131339000000
# propertyPlantEquipmentNet                 37378000000   41304000000
# goodwill                                            0             0
# intangibleAssets                                    0             0
# goodwillAndIntangibleAssets                         0             0
# longTermInvestments                      105341000000  170799000000
# taxAssets                                           0             0
# otherNonCurrentAssets                     32978000000   22283000000
# totalNonCurrentAssets                    175697000000  234386000000
# otherAssets                                         0             0
# totalAssets                              338516000000  365725000000
# accountPayables                           46236000000   55888000000
# shortTermDebt                             16240000000   20748000000
# taxPayables                                         0             0
# deferredRevenue                            5522000000    7543000000
# otherCurrentLiabilities                   37720000000   32687000000
# totalCurrentLiabilities                  105718000000  116866000000
# longTermDebt                              91807000000   93735000000
# deferredRevenueNonCurrent                           0    2797000000
# deferredTaxLiabilitiesNonCurrent                    0     426000000
# otherNonCurrentLiabilities                50503000000   44754000000
# totalNonCurrentLiabilities               142310000000  141712000000
# otherLiabilities                                    0             0
# capitalLeaseObligations                             0             0
# totalLiabilities                         248028000000  258578000000
# preferredStock                                      0             0
# commonStock                               45174000000   40201000000
# retainedEarnings                          45898000000   70400000000
# accumulatedOtherComprehensiveIncomeLoss    -584000000   -3454000000
# othertotalStockholdersEquity                        0             0
# totalStockholdersEquity                   90488000000  107147000000
# totalEquity                               90488000000  107147000000
# totalLiabilitiesAndStockholdersEquity    338516000000  365725000000
# minorityInterest                                    0             0
# totalLiabilitiesAndTotalEquity           338516000000  365725000000
# totalInvestments                         157054000000  211187000000
# totalDebt                                108047000000  114483000000
# netDebt                                   59203000000   88570000000
#
# Date                                             2017          2016  \
# cashAndCashEquivalents                    20289000000   20484000000
# shortTermInvestments                      53892000000   46671000000
# cashAndShortTermInvestments               74181000000   67155000000
# netReceivables                            35673000000   29299000000
# inventory                                  4855000000    2132000000
# otherCurrentAssets                        13936000000    8283000000
# totalCurrentAssets                       128645000000  106869000000
# propertyPlantEquipmentNet                 33783000000   27010000000
# goodwill                                   5717000000    5414000000
# intangibleAssets                           2298000000    3206000000
# goodwillAndIntangibleAssets                8015000000    8620000000
# longTermInvestments                      194714000000  170430000000
# taxAssets                                           0             0
# otherNonCurrentAssets                     10162000000    8757000000
# totalNonCurrentAssets                    246674000000  214817000000
# otherAssets                                         0             0
# totalAssets                              375319000000  321686000000
# accountPayables                           49049000000   37294000000
# shortTermDebt                             18473000000   11605000000
# taxPayables                                         0             0
# deferredRevenue                            7548000000    8080000000
# otherCurrentLiabilities                   25744000000   22027000000
# totalCurrentLiabilities                  100814000000   79006000000
# longTermDebt                              97207000000   75427000000
# deferredRevenueNonCurrent                  2836000000    2930000000
# deferredTaxLiabilitiesNonCurrent          31504000000   26019000000
# otherNonCurrentLiabilities                 8911000000   10055000000
# totalNonCurrentLiabilities               140458000000  114431000000
# otherLiabilities                                    0             0
# capitalLeaseObligations                             0             0
# totalLiabilities                         241272000000  193437000000
# preferredStock                                      0             0
# commonStock                               35867000000   31251000000
# retainedEarnings                          98330000000   96364000000
# accumulatedOtherComprehensiveIncomeLoss    -150000000     634000000
# othertotalStockholdersEquity                        0             0
# totalStockholdersEquity                  134047000000  128249000000
# totalEquity                              134047000000  128249000000
# totalLiabilitiesAndStockholdersEquity    375319000000  321686000000
# minorityInterest                                    0             0
# totalLiabilitiesAndTotalEquity           375319000000  321686000000
# totalInvestments                         248606000000  217101000000
# totalDebt                                115680000000   87032000000
# netDebt                                   95391000000   66548000000
#
# Date                                             2015          2014  \
# cashAndCashEquivalents                    21120000000   13844000000
# shortTermInvestments                      20481000000   11233000000
# cashAndShortTermInvestments               41601000000   25077000000
# netReceivables                            30343000000   27219000000
# inventory                                  2349000000    2111000000
# otherCurrentAssets                        15085000000   14124000000
# totalCurrentAssets                        89378000000   68531000000
# propertyPlantEquipmentNet                 22471000000   20624000000
# goodwill                                   5116000000    4616000000
# intangibleAssets                           3893000000    4142000000
# goodwillAndIntangibleAssets                9009000000    8758000000
# longTermInvestments                      164065000000  130162000000
# taxAssets                                           0             0
# otherNonCurrentAssets                      5556000000    3764000000
# totalNonCurrentAssets                    201101000000  163308000000
# otherAssets                                         0             0
# totalAssets                              290479000000  231839000000
# accountPayables                           35490000000   30196000000
# shortTermDebt                             10999000000    6308000000
# taxPayables                                         0    1209000000
# deferredRevenue                            8940000000    8491000000
# otherCurrentLiabilities                   25181000000   17244000000
# totalCurrentLiabilities                   80610000000   63448000000
# longTermDebt                              53463000000   28987000000
# deferredRevenueNonCurrent                  3624000000    3031000000
# deferredTaxLiabilitiesNonCurrent          24062000000   20259000000
# otherNonCurrentLiabilities                 9365000000    4567000000
# totalNonCurrentLiabilities                90514000000   56844000000
# otherLiabilities                                    0             0
# capitalLeaseObligations                             0             0
# totalLiabilities                         171124000000  120292000000
# preferredStock                                      0             0
# commonStock                               27416000000   23313000000
# retainedEarnings                          92284000000   87152000000
# accumulatedOtherComprehensiveIncomeLoss    -345000000    1082000000
# othertotalStockholdersEquity                        0             0
# totalStockholdersEquity                  119355000000  111547000000
# totalEquity                              119355000000  111547000000
# totalLiabilitiesAndStockholdersEquity    290479000000  231839000000
# minorityInterest                                    0             0
# totalLiabilitiesAndTotalEquity           290479000000  231839000000
# totalInvestments                         184546000000  141395000000
# totalDebt                                 64462000000   35295000000
# netDebt                                   43342000000   21451000000
#
# Date                                             2013          2012  \
# cashAndCashEquivalents                    14259000000   10746000000
# shortTermInvestments                      26287000000   18383000000
# cashAndShortTermInvestments               40546000000   29129000000
# netReceivables                            20641000000   18692000000
# inventory                                  1764000000     791000000
# otherCurrentAssets                        10335000000    9041000000
# totalCurrentAssets                        73286000000   57653000000
# propertyPlantEquipmentNet                 16597000000   15452000000
# goodwill                                   1577000000    1135000000
# intangibleAssets                           4179000000    4224000000
# goodwillAndIntangibleAssets                5756000000    5359000000
# longTermInvestments                      106215000000   92122000000
# taxAssets                                           0             0
# otherNonCurrentAssets                      5146000000    5478000000
# totalNonCurrentAssets                    133714000000  118411000000
# otherAssets                                         0             0
# totalAssets                              207000000000  176064000000
# accountPayables                           22367000000   21175000000
# shortTermDebt                                       0             0
# taxPayables                                1200000000    1535000000
# deferredRevenue                            7435000000    5953000000
# otherCurrentLiabilities                   12656000000    9879000000
# totalCurrentLiabilities                   43658000000   38542000000
# longTermDebt                              16960000000             0
# deferredRevenueNonCurrent                  2625000000    2648000000
# deferredTaxLiabilitiesNonCurrent          16489000000   13847000000
# otherNonCurrentLiabilities                 3719000000    2817000000
# totalNonCurrentLiabilities                39793000000   19312000000
# otherLiabilities                                    0             0
# capitalLeaseObligations                             0             0
# totalLiabilities                          83451000000   57854000000
# preferredStock                                      0             0
# commonStock                               19764000000   16422000000
# retainedEarnings                         104256000000  101289000000
# accumulatedOtherComprehensiveIncomeLoss    -471000000     499000000
# othertotalStockholdersEquity                        0             0
# totalStockholdersEquity                  123549000000  118210000000
# totalEquity                              123549000000  118210000000
# totalLiabilitiesAndStockholdersEquity    207000000000  176064000000
# minorityInterest                                    0             0
# totalLiabilitiesAndTotalEquity           207000000000  176064000000
# totalInvestments                         132502000000  110505000000
# totalDebt                                 16960000000             0
# netDebt                                    2701000000  -10746000000
#
# Date                                             2011
# cashAndCashEquivalents                     9815000000
# shortTermInvestments                      16137000000
# cashAndShortTermInvestments               25952000000
# netReceivables                            11717000000
# inventory                                   776000000
# otherCurrentAssets                         6543000000
# totalCurrentAssets                        44988000000
# propertyPlantEquipmentNet                  7777000000
# goodwill                                    896000000
# intangibleAssets                           3536000000
# goodwillAndIntangibleAssets                4432000000
# longTermInvestments                       55618000000
# taxAssets                                           0
# otherNonCurrentAssets                      3556000000
# totalNonCurrentAssets                     71383000000
# otherAssets                                         0
# totalAssets                              116371000000
# accountPayables                           14632000000
# shortTermDebt                                       0
# taxPayables                                1140000000
# deferredRevenue                            4091000000
# otherCurrentLiabilities                    8107000000
# totalCurrentLiabilities                   27970000000
# longTermDebt                                        0
# deferredRevenueNonCurrent                  1686000000
# deferredTaxLiabilitiesNonCurrent           8159000000
# otherNonCurrentLiabilities                 1941000000
# totalNonCurrentLiabilities                11786000000
# otherLiabilities                                    0
# capitalLeaseObligations                             0
# totalLiabilities                          39756000000
# preferredStock                                      0
# commonStock                               13331000000
# retainedEarnings                          62841000000
# accumulatedOtherComprehensiveIncomeLoss     443000000
# othertotalStockholdersEquity                        0
# totalStockholdersEquity                   76615000000
# totalEquity                               76615000000
# totalLiabilitiesAndStockholdersEquity    116371000000
# minorityInterest                                    0
# totalLiabilitiesAndTotalEquity           116371000000
# totalInvestments                          71755000000
# totalDebt                                           0
# netDebt                                   -9815000000

# %% [markdown]
# ### Performing accounting operations: ratios

# %% [markdown]
# The power of having financial statements is that we can perform financial ratios that provides key input about the health of the company. This type of analysis is referred as fundamentals as it try to grasp company's performance not on stock market data, but purely on what is happening inside the company.
#
# We will compute the current ratio as an example.

# %%
# Let's quickly recall our Balance Sheets
ybs10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 2021 to 2011
# Data columns (total 44 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   cashAndCashEquivalents                   11 non-null     int64
#  1   shortTermInvestments                     11 non-null     float64
#  2   cashAndShortTermInvestments              11 non-null     int64
#  3   netReceivables                           11 non-null     int64
#  4   inventory                                11 non-null     int64
#  5   otherCurrentAssets                       11 non-null     int64
#  6   totalCurrentAssets                       11 non-null     int64
#  7   propertyPlantEquipmentNet                11 non-null     int64
#  8   goodwill                                 11 non-null     float64
#  9   intangibleAssets                         11 non-null     float64
#  10  goodwillAndIntangibleAssets              11 non-null     float64
#  11  longTermInvestments                      11 non-null     float64
#  12  taxAssets                                11 non-null     float64
#  13  otherNonCurrentAssets                    11 non-null     int64
#  14  totalNonCurrentAssets                    11 non-null     int64
#  15  otherAssets                              11 non-null     float64
#  16  totalAssets                              11 non-null     int64
#  17  accountPayables                          11 non-null     float64
#  18  shortTermDebt                            11 non-null     float64
#  19  taxPayables                              11 non-null     float64
#  20  deferredRevenue                          11 non-null     float64
#  21  otherCurrentLiabilities                  11 non-null     int64
#  22  totalCurrentLiabilities                  11 non-null     int64
#  23  longTermDebt                             11 non-null     float64
#  24  deferredRevenueNonCurrent                11 non-null     float64
#  25  deferredTaxLiabilitiesNonCurrent         11 non-null     float64
#  26  otherNonCurrentLiabilities               11 non-null     float64
#  27  totalNonCurrentLiabilities               11 non-null     int64
#  28  otherLiabilities                         11 non-null     float64
#  29  capitalLeaseObligations                  11 non-null     float64
#  30  totalLiabilities                         11 non-null     int64
#  31  preferredStock                           11 non-null     float64
#  32  commonStock                              11 non-null     float64
#  33  retainedEarnings                         11 non-null     int64
#  34  accumulatedOtherComprehensiveIncomeLoss  11 non-null     float64
#  35  othertotalStockholdersEquity             11 non-null     float64
#  36  totalStockholdersEquity                  11 non-null     int64
#  37  totalLiabilitiesAndStockholdersEquity    11 non-null     int64
#  38  minorityInterest                         11 non-null     int64
#  39  totalEquity                              11 non-null     int64
#  40  totalLiabilitiesAndTotalEquity           11 non-null     int64
#  41  totalInvestments                         11 non-null     float64
#  42  totalDebt                                11 non-null     float64
#  43  netDebt                                  11 non-null     float64
# dtypes: float64(24), int64(20)
# memory usage: 4.2+ KB

# %% [markdown]
# ### Current Ratio

# %% [markdown]
# Current ratio helps assess if a company has **enough cash and short term assets to pay the bills in the short term**.
#
# |Current Ratio = Current Assets / Current Liabilities|
# |----------------------------------------------------|
#
# A rule of thumb reference for this ratio would be 1.5 or higher to tell if the company has a good current ratio.
#
# A ratio under 1 would signify that the company is at risk of being short of liquidity.
#
# Ratio varies according to business. A higher ratio would also require further investigation.
#
# source: https://www.investopedia.com/terms/c/currentratio.asp

# %% [markdown]
# #### Computing the current ratio
#
# We will create a new column to our existing normal (non-transposed) dataframe **ybs** called **"currentRatio"** (we try to respect Financial Model Prep way of writing as much as possible) by **dividing columns "totalCurrentAssets" by "totalCurrentLiabilities"**.

# %%
# We apply our formula to add our new column to our dataframe
ybs10['currentRatio'] = ybs10['totalCurrentAssets'] / ybs10['totalCurrentLiabilities']
ybs10['currentRatio']
# Out:
# /var/folders/sn/wq_2w76s333b7xmhtx39fzs80000gn/T/ipykernel_46158/3540243556.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ybs10['currentRatio'] = ybs10['totalCurrentAssets'] / ybs10['totalCurrentLiabilities']
# Date
# 2021    1.074553
# 2020    1.363604
# 2019    1.540126
# 2018    1.123843
# 2017    1.276063
# 2016    1.352669
# 2015    1.108771
# 2014    1.080113
# 2013    1.678639
# 2012    1.495849
# 2011    1.608438
# Name: currentRatio, dtype: float64

# %% [markdown]
# We want to see how well Apple is performing on current ratio.
#
# Let's first investigate how many times current ratio was inferior to 1.5 in the last 10 years and then how many times it was superior on the same period.

# %%
# The method consist of slicing through the column using our 1.5 reference value
below1pt5 = ybs10[ybs10['currentRatio'] < 1.5]

# Let's have a look now at our new dataframe
below1pt5
# Out:
#       cashAndCashEquivalents  shortTermInvestments  \
# Date
# 2021             34940000000          2.769900e+10
# 2020             38016000000          5.292700e+10
# 2018             25913000000          4.038800e+10
# 2017             20289000000          5.389200e+10
# 2016             20484000000          4.667100e+10
# 2015             21120000000          2.048100e+10
# 2014             13844000000          1.123300e+10
# 2012             10746000000          1.838300e+10
#
#       cashAndShortTermInvestments  netReceivables   inventory  \
# Date
# 2021                  62639000000     51506000000  6580000000
# 2020                  90943000000     37445000000  4061000000
# 2018                  66301000000     48995000000  3956000000
# 2017                  74181000000     35673000000  4855000000
# 2016                  67155000000     29299000000  2132000000
# 2015                  41601000000     30343000000  2349000000
# 2014                  25077000000     27219000000  2111000000
# 2012                  29129000000     18692000000   791000000
#
#       otherCurrentAssets  totalCurrentAssets  propertyPlantEquipmentNet  \
# Date
# 2021         14111000000        134836000000                39440000000
# 2020         11264000000        143713000000                36766000000
# 2018         12087000000        131339000000                41304000000
# 2017         13936000000        128645000000                33783000000
# 2016          8283000000        106869000000                27010000000
# 2015         15085000000         89378000000                22471000000
# 2014         14124000000         68531000000                20624000000
# 2012          9041000000         57653000000                15452000000
#
#           goodwill  intangibleAssets  ...  othertotalStockholdersEquity  \
# Date                                  ...
# 2021  0.000000e+00      0.000000e+00  ...                           0.0
# 2020  0.000000e+00      0.000000e+00  ...                           0.0
# 2018  0.000000e+00      0.000000e+00  ...                           0.0
# 2017  5.717000e+09      2.298000e+09  ...                           0.0
# 2016  5.414000e+09      3.206000e+09  ...                           0.0
# 2015  5.116000e+09      3.893000e+09  ...                           0.0
# 2014  4.616000e+09      4.142000e+09  ...                           0.0
# 2012  1.135000e+09      4.224000e+09  ...                           0.0
#
#       totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# Date
# 2021              63090000000                           351002000000
# 2020              65339000000                           323888000000
# 2018             107147000000                           365725000000
# 2017             134047000000                           375319000000
# 2016             128249000000                           321686000000
# 2015             119355000000                           290479000000
# 2014             111547000000                           231839000000
# 2012             118210000000                           176064000000
#
#       minorityInterest   totalEquity  totalLiabilitiesAndTotalEquity  \
# Date
# 2021                 0   63090000000                    351002000000
# 2020                 0   65339000000                    323888000000
# 2018                 0  107147000000                    365725000000
# 2017                 0  134047000000                    375319000000
# 2016                 0  128249000000                    321686000000
# 2015                 0  119355000000                    290479000000
# 2014                 0  111547000000                    231839000000
# 2012                 0  118210000000                    176064000000
#
#       totalInvestments     totalDebt       netDebt  currentRatio
# Date
# 2021      1.555760e+11  1.247190e+11  8.977900e+10      1.074553
# 2020      1.538140e+11  1.124360e+11  7.442000e+10      1.363604
# 2018      2.111870e+11  1.144830e+11  8.857000e+10      1.123843
# 2017      2.486060e+11  1.156800e+11  9.539100e+10      1.276063
# 2016      2.171010e+11  8.703200e+10  6.654800e+10      1.352669
# 2015      1.845460e+11  6.446200e+10  4.334200e+10      1.108771
# 2014      1.413950e+11  3.529500e+10  2.145100e+10      1.080113
# 2012      1.105050e+11  0.000000e+00 -1.074600e+10      1.495849
#
# [8 rows x 45 columns]

# %%
# Counting how many times in the last year
below1pt5.index.value_counts().sum()
# Out:
# 8

# %% [markdown]
# Eight out of eleven which is a little below 20% are under 1.5. We won't go further into the the analysis as this is not the goal of this notebook.
